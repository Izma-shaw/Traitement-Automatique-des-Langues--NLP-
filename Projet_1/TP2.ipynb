# %% [markdown]
# TP  2 : Introduction à la bibliothèque spaCy et à l'analyse linguistique de texte
# ====

# %% [markdown]
# 1 - Introduction
# ------
#
# L'objectif de ce TP est de se familiariser avec la bilbiothèque spaCy et de comprendre les différentes analyses linguistiques possibles au niveau du mot et notamment le couplage texte - ontologie.
#
# N'hésitez pas à regarder régulièrement la documentation de ces librairies, des exemples d\'utilisation accompagnent généralement l\'explication de chaque fonction.
#
# - spaCy: https://spacy.io/api
# - NLTK: https://www.nltk.org/
# - WordCloud : https://amueller.github.io/word_cloud/
# - Counter : https://docs.python.org/3/library/collections.html
# - Python 3: https://docs.python.org/3/
# - Matplotilb: https://matplotlib.org/contents.html

# %%
# A exécuter si ces librairies ne sont pas sur vos machines

# !pip install --user spacy
# !pip install --user nltk
# !pip install --user wordcloud
# !python3 -m spacy download en_core_web_lg
# !python3 -m spacy download fr_core_news_sm
# !pip install --upgrade --user Pillow
# Out:
# Requirement already satisfied: spacy in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (58.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from spacy) (1.26.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: colorama in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: nltk in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: wordcloud in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (1.26.3)
# Requirement already satisfied: pillow in c:\users\ismael\appdata\roaming\python\python310\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ismael\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Python est introuvable. Ex�cutez sans argument pour proc�der � l
# Python est introuvable. Ex�cutez sans argument pour proc�der � l
# Requirement already satisfied: Pillow in c:\users\ismael\appdata\roaming\python\python310\site-packages (10.2.0)

# %%
import spacy
import matplotlib.pyplot as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

from wordcloud import WordCloud
from collections import Counter

# %% [markdown]
# 2 - Génération de nuages de mots avec une motivation linguistique
# -----

# %% [markdown]
# Importer le modèle de langue français.

# %%
# Pour impoter le moduèle : !python -m spacy download fr_core_news_sm
nlp = spacy.load("fr_core_news_sm")
# si vous voulez utiliser un autre modèle voici quelques liens intéressants
# Tous les modèles : https://spacy.io/models
# Anglais : https://spacy.io/models/en
# Italien : https://spacy.io/models/it

# %% [markdown]
# Lire l'un des deux textes proposés dans ce TP: sport.text ou sante.text.

# %%
text_path1 = "sport.txt"
text_path2 = "sante.txt"

text1 = ""
with open(text_path1, encoding='utf-8') as f:
    text1 = f.read()
    
text2 = ""
with open(text_path2, encoding='utf-8') as f:
    text2 = f.read()

# %% [markdown]
# Transformer le texte en un objet "nlp" de la bibliothèque spaCy qui vous permet d'accéder facilement aux objets textuels.

# %%
doc = nlp(text1)
doc2 = nlp(text2)

# %% [markdown]
# Fonction qui retourne la fréquence des 50 mots les plus fréquents dans un document.

# %%
freq_list = Counter(token.text for token in doc if "\n" not in token.text)
freq_list.most_common(50)
# Out:
# [(',', 51),
#  ('.', 40),
#  ('de', 35),
#  ('les', 19),
#  ('le', 19),
#  ('en', 14),
#  ('a', 13),
#  ('du', 12),
#  ('la', 12),
#  ('"', 12),
#  ('des', 11),
#  ('Bleus', 9),
#  ('dans', 9),
#  ("l'", 9),
#  ('se', 9),
#  ('et', 9),
#  ('pour', 8),
#  ('sur', 8),
#  ("d'", 7),
#  (':', 6),
#  ('une', 6),
#  ('monde', 6),
#  ('Lucas', 6),
#  ('France', 5),
#  ("L'", 5),
#  ('Hernandez', 5),
#  ('équipe', 5),
#  ('est', 5),
#  ('que', 5),
#  ('par', 5),
#  ('plus', 5),
#  ('un', 5),
#  ('qui', 5),
#  ('-', 4),
#  ('Australie', 4),
#  ('cette', 4),
#  ('Coupe', 4),
#  ('mois', 4),
#  ('La', 4),
#  ('après', 4),
#  ('but', 4),
#  ('blessure', 4),
#  ('Didier', 4),
#  ('Deschamps', 4),
#  ('pas', 4),
#  ('match', 3),
#  ('contre', 3),
#  ('victoire', 3),
#  ('(', 3),
#  (')', 3)]

# %% [markdown]
# [Q1] Programmer la suite d'instructions pour calculer les 40 mots les plus fréquents du fichier sante.txt.

# %%
# Insérer votre code ici
freq = Counter(token.text for token in doc2 if "\n" not in token.text)
freq.most_common(40)
# Out:
# [('de', 52),
#  (',', 50),
#  ('les', 39),
#  ('la', 35),
#  ('.', 35),
#  ('"', 22),
#  ('et', 21),
#  ('en', 20),
#  ('le', 20),
#  ('à', 19),
#  ('grippe', 17),
#  ('vaccination', 16),
#  ("l'", 16),
#  ('est', 16),
#  ('personnes', 12),
#  ('contre', 10),
#  ('une', 10),
#  ('a', 10),
#  ('des', 9),
#  ('?', 8),
#  ('(', 8),
#  (')', 8),
#  ("d'", 7),
#  ('faire', 7),
#  ('moins', 7),
#  ('Covid-19', 7),
#  ('sur', 6),
#  ('campagne', 6),
#  ('que', 6),
#  ('vacciner', 6),
#  ('octobre', 6),
#  ('par', 6),
#  ('du', 6),
#  ('vous', 6),
#  ('-', 6),
#  ('un', 6),
#  ('pas', 6),
#  ('plus', 5),
#  ('fragiles', 5),
#  ('deux', 5)]

# %% [markdown]
# Fonction qui génère un nuage de mots à partir d'une liste de mots ordonnés par leur fréquence.

# %%
def generate_wordcloud(freq_list):
    wordcloud = WordCloud(max_font_size=40).generate_from_frequencies(freq_list)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")

# %% [markdown]
# Génerer le nuage de mots

# %%
generate_wordcloud(freq_list)

# %% [markdown]
# [Q2] Générer le nuage de mots du fichier sante.txt.

# %%
# Insérer votre code ici
generate_wordcloud(freq)

# %% [markdown]
# Fonction qui ne compte que les fréquences des mots qui ne sont pas de mots vides. Rappel, un mot vide est un mot qui n'a pas de sens dénotatif particulier. Ce sont les déterminants, les prépositions etc.

# %%
freq_list = Counter(token.text for token in doc if not token.is_stop and "\n" not in token.text)

# %%
generate_wordcloud(freq_list)

# %% [markdown]
# [Q3] Générer le nuage de mots pour tous les mots sauf ceux qui sont un mot vide ou une ponctuation.

# %%
# insérer votre code ici
#ponct = ["'", ",", "!", ";", "?"]
#freq_list = Counter(token.text for token in doc if not token.is_stop and "\n" not in token.text and token.text not in ponct)
freq_list = Counter(token.text for token in doc if not token.is_stop and "\n" not in token.text and not token.is_punct)

generate_wordcloud(freq_list)

# %% [markdown]
# Fonction qui génère un nuage de lemmes, i.e. du radical d'un mot.

# %%
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct and "\n" not in token.lemma_)
generate_wordcloud(freq_list)

# %% [markdown]
# Fonction qui génère un nuage de lemmes nominaux, i.e. seulement les noms.

# %%
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.pos_ == "NOUN" and "\n" not in token.lemma_)
generate_wordcloud(freq_list)

# %% [markdown]
# [Q4] Générer le nuage de lemmes adjectivaux pour le texte sante.txt.

# %%
# Insérer votre code ici
freq_sant = Counter(token.lemma_ for token in doc2 if not token.is_stop and not token.is_punct and token.pos_ == "ADJ" and "\n" not in token.lemma_)
generate_wordcloud(freq_list)

# %% [markdown]
# Fonction qui génère un nuage d'entités nommées de type personne.

# %%
freq_list = Counter(token.text for token in doc if not token.is_stop and not token.is_punct and token.ent_type_ == "PER")
generate_wordcloud(freq_list)

# %% [markdown]
# [Q5] Générer le nuage d'entités nommées de type Localisation pour le texte sante.txt.

# %%
nlp.get_pipe("ner").labels
# Out:
# ('LOC', 'MISC', 'ORG', 'PER')

# %%
# insérer votre code ici
freq_list = Counter(token.text for token in doc2 if not token.is_stop and not token.is_punct and token.ent_type_ == "LOC")
generate_wordcloud(freq_list)

# %% [markdown]
# Fonction qui génère un nuage de mots qui sont compléments d'objet.

# %%
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.dep_ == "obj")
generate_wordcloud(freq_list)

# %% [markdown]
# [Q6] Générer le nuage des noms qui sont un sujet pour le texte sport.txt.

# %%
# insérer votre code ici
freq_list = Counter(token.lemma_ for token in doc if not token.is_stop and not token.is_punct and token.dep_ == "nsubj" and "\n" not in token.lemma_)
generate_wordcloud(freq_list)

# %% [markdown]
# 3 - Liste des informations linguistiques et leur visualisation
# -----

# %% [markdown]
# Fonction qui montre toutes les informations linguistiques disponibles pour chacune des phrases d'un texte.

# %%
print('\n'.join(['\t'.join([str(token.i), token.text, token.lemma_, token.pos_, str(token.morph), 
                            str(token.head.i), token.dep_, token.ent_type_, token.ent_iob_]) for sent in doc.sents
                 for token in sent]))
# Out:
# 0	France	France	PROPN	Gender=Fem|Number=Sing	0	ROOT		O
# 1	-	-	PROPN		1	ROOT		O
# 2	Australie	Australie	PROPN		2	ROOT		O
# 3	:	:	PUNCT		2	punct		O
# 4	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	6	det		O
# 5	première	premier	ADJ	Gender=Fem|NumType=Ord|Number=Sing	6	amod		O
# 6	demi-heure	demi-heure	NOUN	Gender=Fem|Number=Sing	2	nmod		O
# 7	fondatrice	fondateur	ADJ	Number=Sing	6	amod		O
# 8	pour	pour	ADP		10	case		O
# 9	les	le	DET	Definite=Def|Number=Plur|PronType=Art	10	det		O
# 10	Bleus	bleu	NOUN	Gender=Masc|Number=Sing	6	nmod	ORG	B
# 11	dans	dans	ADP		13	case		O
# 12	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	13	det		O
# 13	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	6	nmod	MISC	B
# 14	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	case	MISC	I
# 15	monde	monde	NOUN	Gender=Masc|Number=Sing	13	nmod	MISC	I
# 16	2022	2022	NUM	NumType=Card	6	nmod	MISC	I
# 17	?	?	PUNCT		2	punct		O
# 18
#
#
#
# 	SPACE		17	dep		O
# 19	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	20	det		O
# 20	entame	entame	NOUN	Gender=Fem|Number=Sing	41	nsubj		O
# 21	de	de	ADP		22	case		O
# 22	match	match	NOUN	Gender=Masc|Number=Sing	20	nmod		O
# 23	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	24	case		O
# 24	Bleus	Bleus	PROPN		22	nmod	ORG	B
# 25	,	,	PUNCT		20	punct		O
# 26	ratée	rater	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	20	acl		O
# 27	mardi	mardi	NOUN	Gender=Masc|Number=Sing	26	nmod		O
# 28	contre	contre	ADP		30	case		O
# 29	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	30	det		O
# 30	Australie	Australie	PROPN	Gender=Fem|Number=Sing	20	nmod	LOC	B
# 31	malgré	malgré	ADP		33	case		O
# 32	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	33	det		O
# 33	victoire	victoire	NOUN	Gender=Fem|Number=Sing	20	nmod		O
# 34	finale	final	ADJ	Gender=Fem|Number=Sing	33	amod		O
# 35	(	(	PUNCT		33	punct		O
# 36	4	4	NUM	NumType=Card	33	nmod		O
# 37	-	-	NUM	NumType=Card	33	nmod		O
# 38	1	1	NOUN	NumType=Card	33	nmod		O
# 39	)	)	PUNCT		33	punct		O
# 40	,	,	PUNCT		41	punct		O
# 41	pourrait	pouvoir	VERB	Mood=Cnd|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	41	ROOT		O
# 42	servir	servir	ADJ	Gender=Masc|Number=Sing	41	xcomp		O
# 43	de	de	ADP		44	case		O
# 44	déclic	déclic	NOUN	Gender=Masc|Number=Sing	42	obl:arg		O
# 45	pour	pour	ADP		47	case		O
# 46	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	47	det		O
# 47	reste	reste	NOUN	Gender=Masc|Number=Sing	42	obl:mod		O
# 48	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	49	case		O
# 49	Mondial	Mondial	PROPN		47	nmod	LOC	B
# 50	.	.	PUNCT		41	punct		O
# 51
#
#
#
# 	SPACE		50	dep		O
# 52	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	53	det		O
# 53	incompréhension	incompréhension	NOUN	Gender=Fem|Number=Sing	53	ROOT		O
# 54	d'	de	ADP		55	case		O
# 55	Hugo	Hugo	PROPN		53	nmod	PER	B
# 56	Lloris	Lloris	PROPN		55	flat:name	PER	I
# 57	.	.	PUNCT		53	punct		O
# 58	Le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	59	det		O
# 59	regard	regard	NOUN	Gender=Masc|Number=Sing	59	ROOT		O
# 60	noir	noir	ADJ	Gender=Masc|Number=Sing	59	amod		O
# 61	de	de	ADP		62	case		O
# 62	Benjamin	Benjamin	PROPN	Gender=Fem|Number=Sing	59	nmod	PER	B
# 63	Pavard	Pavard	PROPN	Gender=Masc|Number=Sing	62	flat:name	PER	I
# 64	.	.	PUNCT		59	punct		O
# 65	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	66	det		O
# 66	inquiétude	inquiétude	NOUN	Gender=Fem|Number=Sing	66	ROOT		O
# 67	autour	autour	ADV		66	dep		O
# 68	de	de	ADP		69	case		O
# 69	Lucas	Lucas	PROPN	Gender=Masc|Number=Sing	66	nmod	PER	B
# 70	Hernandez	Hernandez	PROPN		69	flat:name	PER	I
# 71	.	.	PUNCT		66	punct		O
# 72	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	73	det		O
# 73	équipe	équipe	NOUN	Gender=Fem|Number=Sing	78	nsubj		O
# 74	de	de	ADP		75	case	LOC	B
# 75	France	France	PROPN	Gender=Fem|Number=Sing	73	nmod	LOC	I
# 76	n'	ne	ADV	Polarity=Neg	78	advmod		O
# 77	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	78	aux:pass		O
# 78	entrée	entrer	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	78	ROOT		O
# 79	que	que	SCONJ		90	mark		O
# 80	depuis	depuis	ADP		82	case		O
# 81	neuf	neuf	ADJ	Gender=Masc|Number=Sing	82	amod		O
# 82	minutes	minute	NOUN	Gender=Fem|Number=Plur	90	nmod		O
# 83	dans	dans	ADP		85	case		O
# 84	sa	son	DET	Gender=Fem|Number=Sing|Poss=Yes	85	det		O
# 85	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	82	nmod	MISC	B
# 86	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	87	case	MISC	I
# 87	monde	monde	NOUN	Gender=Masc|Number=Sing	85	nmod	MISC	I
# 88	2022	2022	NUM	NumType=Card	87	nmod	MISC	I
# 89	,	,	PUNCT		82	punct		O
# 90	mardi	mardi	NOUN	Gender=Masc|Number=Sing	78	obl:mod		O
# 91	22	22	NUM	NumType=Card	90	nmod		O
# 92	novembre	novembre	NOUN	Gender=Masc|Number=Sing	91	nmod		O
# 93	,	,	PUNCT		78	punct		O
# 94	qu'	que	SCONJ		97	mark		O
# 95	elle	lui	PRON	Gender=Fem|Number=Sing|Person=3	97	nsubj		O
# 96	se	se	PRON	Person=3|Reflex=Yes	97	expl:comp		O
# 97	trouve	trouver	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	78	ccomp		O
# 98	déjà	déjà	ADV		97	advmod		O
# 99	en	en	ADP		100	case		O
# 100	pleine	pleine	NOUN	Gender=Fem|Number=Sing	97	obl:arg		O
# 101	tourmente	tourment	ADJ	Gender=Fem|Number=Sing	100	amod		O
# 102	.	.	PUNCT		78	punct		O
# 103	Menés	mener	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	110	obl:mod		O
# 104	par	par	ADP		106	case		O
# 105	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	106	det		O
# 106	Australie	Australie	PROPN	Gender=Fem|Number=Sing	103	obl:agent	LOC	B
# 107	,	,	PUNCT		110	punct		O
# 108	les	le	DET	Definite=Def|Number=Plur|PronType=Art	109	det		O
# 109	Bleus	bleu	NOUN	Gender=Masc|Number=Sing	110	nsubj	ORG	B
# 110	voient	voir	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	110	ROOT		O
# 111	les	le	DET	Definite=Def|Number=Plur|PronType=Art	112	det		O
# 112	spectres	spectre	NOUN	Gender=Masc|Number=Plur	110	obj		O
# 113	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	115	case		O
# 114	derniers	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Plur	115	amod		O
# 115	mois	mois	NOUN	Gender=Masc|Number=Plur	112	nmod		O
# 116	resurgir	resurgir	VERB	VerbForm=Inf	115	acl		O
# 117	soudainement	soudainement	ADV		110	advmod		O
# 118	:	:	PUNCT		117	punct		O
# 119	les	le	DET	Definite=Def|Number=Plur|PronType=Art	120	det		O
# 120	blessures	blessure	NOUN	Gender=Masc|Number=Plur	110	obj		O
# 121	,	,	PUNCT		124	punct		O
# 122	les	le	DET	Definite=Def|Number=Plur|PronType=Art	124	det		O
# 123	mauvais	mauvais	ADJ	Gender=Masc|Number=Plur	124	amod		O
# 124	résultats	résultat	NOUN	Gender=Masc|Number=Plur	120	conj		O
# 125	,	,	PUNCT		120	punct		O
# 126	les	le	DET	Definite=Def|Number=Plur|PronType=Art	127	det		O
# 127	doutes	doute	NOUN	Gender=Masc|Number=Plur	120	nmod		O
# 128	.	.	PUNCT		110	punct		O
# 129	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	130	det	LOC	B
# 130	France	France	PROPN	Gender=Fem|Number=Sing	132	nsubj	LOC	I
# 131	se	se	PRON	Person=3|Reflex=Yes	132	expl:comp		O
# 132	prend	prendre	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	132	ROOT		O
# 133	de	de	ADP		135	case		O
# 134	plein	plein	ADJ	Gender=Masc|Number=Sing	135	amod		O
# 135	fouet	fouet	NOUN	Gender=Masc|Number=Sing	132	obl:mod		O
# 136	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	137	det		O
# 137	mur	mur	NOUN	Gender=Masc|Number=Sing	132	obj		O
# 138	sur	sur	ADP		139	case		O
# 139	lequel	lequel	PRON	Gender=Masc|Number=Sing|PronType=Rel	141	obl:mod		O
# 140	se	se	PRON	Person=3|Reflex=Yes	141	expl:comp		O
# 141	brisent	briser	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	132	conj		O
# 142	les	le	DET	Definite=Def|Number=Plur|PronType=Art	143	det		O
# 143	ambitions	ambition	NOUN	Gender=Fem|Number=Plur	141	obj		O
# 144	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	145	case		O
# 145	champions	champion	NOUN	Gender=Masc|Number=Plur	143	nmod		O
# 146	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	147	case		O
# 147	monde	monde	NOUN	Gender=Masc|Number=Sing	145	nmod		O
# 148	en	en	ADP		149	case		O
# 149	titre	titre	NOUN	Gender=Masc|Number=Sing	143	nmod		O
# 150	lors	lors	ADV		149	advmod		O
# 151	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	153	case		O
# 152	dernières	dernier	ADJ	Number=Plur	153	amod		O
# 153	éditions	édition	NOUN	Gender=Fem|Number=Plur	150	obl:arg		O
# 154	.	.	PUNCT		132	punct		O
# 155
#
#
#
# 	SPACE		154	dep		O
# 156	Devancés	devancer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	132	xcomp	LOC	B
# 157	au	au	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	158	case		O
# 158	tableau	tableau	NOUN	Gender=Masc|Number=Sing	156	obl:arg		O
# 159	d'	de	ADP		160	case		O
# 160	affichage	affichage	NOUN	Gender=Masc|Number=Sing	158	nmod		O
# 161	après	après	ADP		163	case		O
# 162	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	163	det		O
# 163	but	but	NOUN	Gender=Masc|Number=Sing	156	obl:mod		O
# 164	de	de	ADP		165	case		O
# 165	Craig	Craig	PROPN		163	nmod	PER	B
# 166	Goodwin	Goodwin	PROPN	Gender=Masc|Number=Sing	165	flat:name	PER	I
# 167	,	,	PUNCT		163	punct		O
# 168	les	le	DET	Definite=Def|Number=Plur|PronType=Art	169	det		O
# 169	Bleus	bleu	NOUN	Gender=Masc|Number=Sing	170	nsubj	ORG	B
# 170	doivent	devoir	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	132	advcl		O
# 171	en	en	ADP		173	mark		O
# 172	plus	plus	ADV		173	advmod		O
# 173	digérer	digérer	VERB	VerbForm=Inf	170	xcomp		O
# 174	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	175	det		O
# 175	blessure	blessure	NOUN	Gender=Fem|Number=Sing	173	obj		O
# 176	de	de	ADP		177	case		O
# 177	Lucas	Lucas	PROPN	Gender=Masc|Number=Sing	175	nmod	PER	B
# 178	Hernandez	Hernandez	PROPN		177	flat:name	PER	I
# 179	.	.	PUNCT		132	punct		O
# 180	"	"	PUNCT		182	punct		O
# 181	Je	je	PRON	Number=Sing|Person=1	182	nsubj		O
# 182	pense	penser	VERB	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	182	ROOT		O
# 183	que	que	SCONJ		185	mark		O
# 184	ça	cela	PRON	Number=Sing|Person=3	185	nsubj		O
# 185	va	aller	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	182	ccomp		O
# 186	être	être	AUX	VerbForm=Inf	189	cop		O
# 187	malheureusement	malheureusement	ADV		189	advmod		O
# 188	assez	assez	ADV		189	advmod		O
# 189	grave	grave	ADJ	Number=Sing	185	xcomp		O
# 190	"	"	PUNCT		185	punct		O
# 191	,	,	PUNCT		193	punct		O
# 192	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	193	aux:tense		O
# 193	confirmé	confirmer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	182	advcl		O
# 194	Didier	Didier	PROPN	Gender=Masc|Number=Sing	193	obj	PER	B
# 195	Deschamps	Deschamps	PROPN	Gender=Masc|Number=Sing	194	flat:name	PER	I
# 196	en	en	ADP		197	case		O
# 197	conférence	conférence	NOUN	Gender=Fem|Number=Sing	193	obl:mod		O
# 198	de	de	ADP		199	case		O
# 199	presse	presse	NOUN	Gender=Fem|Number=Sing	197	nmod		O
# 200	après	après	ADP		202	case		O
# 201	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	202	det		O
# 202	match	match	NOUN	Gender=Masc|Number=Sing	193	obl:mod		O
# 203	.	.	PUNCT		182	punct		O
# 204	Le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	205	det		O
# 205	choix	choix	NOUN	Gender=Masc|Number=Sing	211	nsubj		O
# 206	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	207	case		O
# 207	sélectionneur	sélectionneur	NOUN	Gender=Masc|Number=Sing	205	nmod		O
# 208	de	de	ADP		211	mark		O
# 209	ne	ne	ADV	Polarity=Neg	211	advmod		O
# 210	pas	pas	ADV	Polarity=Neg	211	advmod		O
# 211	retenir	retenir	VERB	VerbForm=Inf	211	ROOT		O
# 212	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	213	det		O
# 213	latéral	latéral	NOUN	Gender=Masc|Number=Sing	211	obj		O
# 214	de	de	ADP		215	mark		O
# 215	plus	plus	ADV		211	obl:arg		O
# 216	et	et	CCONJ		215	fixed		O
# 217	d'	de	ADP		219	mark		O
# 218	avoir	avoir	AUX	VerbForm=Inf	219	aux:tense		O
# 219	convoqué	convoquer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	211	xcomp		O
# 220	trois	trois	NUM	NumType=Card	221	nummod		O
# 221	défenseurs	défenseur	NOUN	Gender=Masc|Number=Plur	219	obj		O
# 222	centraux	central	ADJ	Gender=Masc|Number=Plur	221	amod		O
# 223	(	(	PUNCT		221	punct		O
# 224	Pavard	Pavard	PROPN		221	appos	PER	B
# 225	,	,	PUNCT		226	punct		O
# 226	Lucas	Lucas	PROPN	Gender=Masc|Number=Sing	221	conj	PER	B
# 227	Hernandez	Hernandez	PROPN		226	flat:name	PER	I
# 228	et	et	CCONJ		229	cc		O
# 229	Jules	Jules	PROPN	Gender=Fem|Number=Sing	227	conj	PER	B
# 230	Koundé	Koundé	PROPN		229	flat:name	PER	I
# 231	)	)	PUNCT		221	punct		O
# 232	pour	pour	ADP		233	mark		O
# 233	jouer	jouer	VERB	VerbForm=Inf	211	advcl		O
# 234	sur	sur	ADP		236	case		O
# 235	les	le	DET	Definite=Def|Number=Plur|PronType=Art	236	det		O
# 236	côtés	côté	NOUN	Gender=Masc|Number=Plur	233	obl:arg		O
# 237	exacerbe	exacerb	ADJ	Number=Sing	236	amod		O
# 238	les	le	DET	Definite=Def|Number=Plur|PronType=Art	239	det		O
# 239	interrogations	interrogation	NOUN	Gender=Fem|Number=Plur	233	obj		O
# 240	dans	dans	ADP		242	case		O
# 241	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	242	det		O
# 242	stade	stade	NOUN	Gender=Masc|Number=Sing	233	obl:mod	LOC	B
# 243	Al	Al	PROPN		242	nmod	LOC	I
# 244	-	-	PROPN		242	nmod	LOC	I
# 245	Janoub	Janoub	PROPN		242	nmod	LOC	I
# 246	.	.	PUNCT		211	punct		O
# 247	Tout	tout	ADJ	Gender=Masc|Number=Sing	249	expl:subj		O
# 248	se	se	PRON	Person=3|Reflex=Yes	249	expl:comp		O
# 249	bouscule	bousculer	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	249	ROOT		O
# 250	.	.	PUNCT		249	punct		O
# 251
#
# 	SPACE		250	dep		O
# 252	"	"	PUNCT		269	punct		O
# 253	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	254	det		O
# 254	blessure	blessure	NOUN	Gender=Fem|Number=Sing	258	nsubj		O
# 255	de	de	ADP		256	case		O
# 256	Lucas	Lucas	PROPN	Gender=Masc|Number=Sing	254	nmod	PER	B
# 257	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	258	aux:tense		O
# 258	forcément	forcément	ADV		269	advmod		O
# 259	pesé	peser	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	258	amod		O
# 260	"	"	PUNCT		259	punct		O
# 261
#
#
#
# 	SPACE		260	dep		O
# 262	"	"	PUNCT		258	punct		O
# 263	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	264	det		O
# 264	blessure	blessure	NOUN	Gender=Fem|Number=Sing	268	nsubj		O
# 265	de	de	ADP		266	case		O
# 266	Lucas	Lucas	PROPN	Gender=Masc|Number=Sing	264	nmod	PER	B
# 267	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	268	aux:tense		O
# 268	forcément	forcément	ADV		258	parataxis		O
# 269	pesé	peser	ADJ	Gender=Masc|Number=Plur	249	xcomp		O
# 270	psychologiquement	psychologiquement	ADV		269	advmod		O
# 271	.	.	PUNCT		269	punct		O
# 272	Et	et	CCONJ		275	cc		O
# 273	d'	de	ADP		275	mark		O
# 274	être	être	AUX	VerbForm=Inf	275	aux:pass		O
# 275	menés	mener	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	305	advcl		O
# 276	,	,	PUNCT		275	punct		O
# 277	ce	ce	PRON	Number=Sing|Person=3	282	nsubj		O
# 278	n'	ne	ADV	Polarity=Neg	282	advmod		O
# 279	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	282	cop		O
# 280	jamais	jamais	ADV	Polarity=Neg	282	advmod		O
# 281	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	282	det		O
# 282	idéal	idéal	NOUN	Gender=Masc|Number=Sing	275	advcl		O
# 283	,	,	PUNCT		275	punct		O
# 284	mais	mais	CCONJ		287	cc		O
# 285	il	il	PRON	Number=Sing|Person=3	287	expl:subj		O
# 286	y	y	PRON	Person=3	287	expl:comp		O
# 287	a	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	275	conj		O
# 288	de	de	ADP		290	case		O
# 289	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	290	det		O
# 290	force	force	NOUN	Gender=Fem|Number=Sing	287	obj		O
# 291	et	et	CCONJ		293	cc		O
# 292	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	293	case		O
# 293	caractère	caractère	NOUN	Gender=Masc|Number=Sing	290	conj		O
# 294	dans	dans	ADP		296	case		O
# 295	ce	ce	DET	Gender=Masc|Number=Sing|PronType=Dem	296	det		O
# 296	groupe	groupe	NOUN	Gender=Masc|Number=Sing	290	nmod		O
# 297	,	,	PUNCT		290	punct		O
# 298	avec	avec	ADP		300	case		O
# 299	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	300	det		O
# 300	joueurs	joueur	NOUN	Gender=Masc|Number=Plur	290	nmod		O
# 301	expérimentés	expérimenté	NOUN	Gender=Masc|Number=Plur	300	nmod		O
# 302	"	"	PUNCT		275	punct		O
# 303	,	,	PUNCT		305	punct		O
# 304	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	305	aux:tense		O
# 305	expliqué	expliquer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	305	ROOT		O
# 306	Didier	Didier	PROPN	Gender=Masc|Number=Sing	305	obj	PER	B
# 307	Deschamps	deschamps	ADV		306	flat:name	PER	I
# 308	.	.	PUNCT		305	punct		O
# 309	Les	le	DET	Definite=Def|Number=Plur|PronType=Art	310	det		O
# 310	minutes	minute	NOUN	Gender=Fem|Number=Plur	317	nsubj		O
# 311	qui	qui	PRON	PronType=Rel	312	nsubj		O
# 312	suivent	suivre	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	310	acl:relcl		O
# 313	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	314	det		O
# 314	but	but	NOUN	Gender=Masc|Number=Sing	312	obj		O
# 315	australien	australien	ADJ	Gender=Masc|Number=Sing	314	amod		O
# 316	sont	être	AUX	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	317	cop		O
# 317	difficiles	difficile	ADJ	Number=Plur	317	ROOT		O
# 318	:	:	PUNCT		317	punct		O
# 319	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	321	det		O
# 320	mauvaise	mauvais	ADJ	Gender=Fem|Number=Sing	321	amod		O
# 321	passe	passer	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	317	advcl		O
# 322	de	de	ADP		323	case		O
# 323	Rabiot	Rabiot	PROPN		321	nmod	PER	B
# 324	,	,	PUNCT		321	punct		O
# 325	puis	pouvoir	CCONJ		327	cc		O
# 326	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	327	det		O
# 327	autre	autre	ADJ	Number=Sing	321	conj		O
# 328	de	de	ADP		329	case		O
# 329	Theo	Theo	PROPN		327	nmod	PER	B
# 330	Hernandez	Hernandez	PROPN		329	flat:name	PER	I
# 331	qui	qui	PRON	PronType=Rel	332	nsubj		O
# 332	amène	amener	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	327	acl:relcl		O
# 333	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	334	det		O
# 334	missile	missile	NOUN	Gender=Masc|Number=Sing	332	obj		O
# 335	de	de	ADP		336	case		O
# 336	Mitchell	Mitchell	PROPN		334	nmod	PER	B
# 337	Duke	Duke	PROPN		336	flat:name	PER	I
# 338	pour	pour	ADP		339	mark		O
# 339	faire	faire	VERB	VerbForm=Inf	332	advcl		O
# 340	nouvelle	nouveau	ADJ	Gender=Fem|Number=Sing	341	amod		O
# 341	fois	fois	NOUN	Gender=Fem|Number=Sing	339	obl:mod		O
# 342	trembler	trembler	VERB	VerbForm=Inf	339	xcomp		O
# 343	Lloris	Lloris	PROPN		342	flat:name	PER	B
# 344	.	.	PUNCT		317	punct		O
# 345	L'	le	DET	Definite=Def|Number=Sing|PronType=Art	346	det		O
# 346	édifice	édifice	NOUN	Gender=Masc|Number=Sing	346	ROOT		O
# 347	tremble	trembl	ADJ	Number=Sing	346	amod		O
# 348	.	.	PUNCT		346	punct		O
# 349	Malade	malade	NOUN	Gender=Fem|Number=Sing	365	advcl		O
# 350	depuis	depuis	ADP		352	case		O
# 351	plusieurs	plusieurs	DET	Number=Plur	352	det		O
# 352	mois	mois	NOUN	Gender=Masc|Number=Plur	349	nmod		O
# 353	et	et	CCONJ		355	cc		O
# 354	en	en	ADP		355	case		O
# 355	partie	partie	NOUN	Gender=Fem|Number=Sing	352	conj		O
# 356	composée	composer	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	355	acl		O
# 357	de	de	ADP		359	case		O
# 358	joueurs	joueur	ADJ	Gender=Masc|Number=Plur	359	amod		O
# 359	inexpérimentés	inexpérimenté	NOUN	Gender=Fem|Number=Plur	352	nmod		O
# 360	,	,	PUNCT		365	punct		O
# 361	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	362	det		O
# 362	équipe	équipe	NOUN	Gender=Fem|Number=Sing	365	nsubj		O
# 363	de	de	ADP		364	case	LOC	B
# 364	France	France	PROPN	Gender=Fem|Number=Sing	362	nmod	LOC	I
# 365	semble	sembler	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	365	ROOT		O
# 366	engagée	engager	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part|Voice=Pass	365	xcomp		O
# 367	sur	sur	ADP		370	case		O
# 368	de	de	DET	Definite=Ind|Number=Plur|PronType=Art	370	det		O
# 369	mauvais	mauvais	ADJ	Gender=Masc|Number=Plur	370	amod		O
# 370	rails	rail	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	365	advcl		O
# 371	.	.	PUNCT		365	punct		O
# 372
#
#
#
# 	SPACE		371	dep		O
# 373	Mais	mais	CCONJ		383	cc		O
# 374	,	,	PUNCT		383	punct		O
# 375	dans	dans	ADP		377	case		O
# 376	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	377	det		O
# 377	dur	dur	NOUN	Gender=Masc|Number=Sing	383	obl:mod		O
# 378	,	,	PUNCT		383	punct		O
# 379	Didier	Didier	PROPN	Gender=Masc|Number=Sing	383	nsubj	PER	B
# 380	Deschamps	deschamp	NOUN	Gender=Masc|Number=Plur	379	flat:name	PER	I
# 381	s'	se	PRON	Person=3|Reflex=Yes	383	expl:comp		O
# 382	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	383	aux:tense		O
# 383	trouvé	trouver	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	365	conj		O
# 384	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	385	det		O
# 385	leaders	leader	NOUN	Gender=Masc|Number=Plur	383	obj		O
# 386	capables	capable	ADJ	Number=Plur	385	amod		O
# 387	de	de	ADP		388	mark		O
# 388	répondre	répondre	VERB	VerbForm=Inf	385	acl		O
# 389	sur	sur	ADP		391	case		O
# 390	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	391	det		O
# 391	terrain	terrain	NOUN	Gender=Masc|Number=Sing	388	obl:arg		O
# 392	.	.	PUNCT		365	punct		O
# 393	Dayot	dayot	NOUN	Gender=Masc|Number=Sing	393	ROOT	PER	B
# 394	Upamecano	Upamecano	PROPN		393	flat:name	PER	I
# 395	d'	de	ADP		394	fixed		O
# 396	abord	abord	NOUN	Gender=Masc|Number=Sing	395	fixed		O
# 397	,	,	PUNCT		398	punct		O
# 398	lui	luire	PRON	Gender=Masc|Number=Sing|Person=3|PronType=Prs	393	conj		O
# 399	qui	qui	PRON	PronType=Rel	401	nsubj		O
# 400	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	401	aux:tense		O
# 401	livré	livrer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	398	acl:relcl		O
# 402	sa	son	DET	Gender=Fem|Number=Sing|Poss=Yes	404	det		O
# 403	meilleure	meilleur	ADJ	Gender=Fem|Number=Sing	404	amod		O
# 404	prestation	prestation	NOUN	Gender=Fem|Number=Sing	401	obj		O
# 405	en	en	ADP		406	case		O
# 406	bleu	bleu	NOUN	Gender=Masc|Number=Sing	401	obl:mod		O
# 407	:	:	PUNCT		393	punct		O
# 408	"	"	PUNCT		411	punct		O
# 409	Il	il	PRON	Gender=Masc|Number=Sing|Person=3	411	expl:subj		O
# 410	nous	nous	PRON	Number=Plur|Person=1	411	iobj		O
# 411	fallait	falloir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	411	ROOT		O
# 412	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	415	det		O
# 413	peu	peu	ADV		412	fixed		O
# 414	de	de	ADP		415	case		O
# 415	temps	temps	NOUN	Gender=Masc|Number=Plur	411	obj		O
# 416	pour	pour	ADP		418	mark		O
# 417	se	se	PRON	Person=3|Reflex=Yes	418	obj		O
# 418	mettre	mettre	VERB	VerbForm=Inf	411	advcl		O
# 419	dedans	dedans	ADP		418	advmod		O
# 420	,	,	PUNCT		411	punct		O
# 421	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	422	aux:tense		O
# 422	consenti	consentir	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	424	amod		O
# 423	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	424	det		O
# 424	défenseur	défenseur	NOUN	Gender=Masc|Number=Sing	411	obl:mod		O
# 425	.	.	PUNCT		411	punct		O
# 426	Mais	mais	CCONJ		429	cc		O
# 427	après	après	ADP		429	mark		O
# 428	on	on	PRON	Number=Sing|Person=3	429	nsubj		O
# 429	a	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	429	ROOT		O
# 430	bien	bien	ADV		429	advmod		O
# 431	réagi	réagi	ADJ	Gender=Fem|Number=Plur	429	obj		O
# 432	"	"	PUNCT		429	punct		O
# 433	.	.	PUNCT		429	punct		O
# 434	Adrien	Adrien	PROPN	Gender=Fem|Number=Sing	434	ROOT	PER	B
# 435	Rabiot	Rabiot	PROPN		434	flat:name	PER	I
# 436	,	,	PUNCT		434	punct		O
# 437	surtout	surtout	ADV		434	advmod		O
# 438	,	,	PUNCT		439	punct		O
# 439	buteur	buteur	NOUN	Gender=Masc|Number=Sing	437	conj		O
# 440	puis	pouvoir	CCONJ		441	cc		O
# 441	passeur	passeur	NOUN	Gender=Masc|Number=Sing	437	conj		O
# 442	décisif	décisif	ADJ	Gender=Masc|Number=Sing	441	amod		O
# 443	.	.	PUNCT		434	punct		O
# 444	Un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	446	det		O
# 445	nouveau	nouveau	ADJ	Gender=Masc|Number=Sing	446	amod		O
# 446	phare	phare	NOUN	Gender=Masc|Number=Sing	446	ROOT		O
# 447	capable	capable	ADJ	Number=Sing	446	amod		O
# 448	de	de	ADP		449	mark		O
# 449	guider	guider	VERB	VerbForm=Inf	446	xcomp		O
# 450	les	le	DET	Definite=Def|Number=Plur|PronType=Art	451	det		O
# 451	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	449	obj	ORG	B
# 452	quand	quand	SCONJ		455	obj		O
# 453	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	454	det		O
# 454	tempête	tempête	NOUN	Gender=Fem|Number=Sing	455	nsubj		O
# 455	emportait	emporter	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	446	advcl		O
# 456	tout	tout	ADV		459	advmod		O
# 457	sur	sur	ADP		459	case		O
# 458	son	son	DET	Number=Sing|Poss=Yes	459	det		O
# 459	passage	passage	NOUN	Gender=Masc|Number=Sing	455	obl:mod		O
# 460	.	.	PUNCT		446	punct		O
# 461
#
#
#
# 	SPACE		460	dep		O
# 462	Vendredi	vendredi	NOUN	Gender=Masc|Number=Sing	471	obl:mod	MISC	B
# 463	dernier	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Sing	462	amod	MISC	I
# 464	,	,	PUNCT		471	punct		O
# 465	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	466	det		O
# 466	milieu	milieu	NOUN	Gender=Masc|Number=Sing	471	nsubj		O
# 467	de	de	ADP		469	case		O
# 468	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	469	det		O
# 469	Juventus	juventu	NOUN	Gender=Fem|Number=Sing	466	nmod	MISC	B
# 470	se	se	PRON	Person=3|Reflex=Yes	471	expl:comp		O
# 471	décrivait	décrire	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	471	ROOT		O
# 472	ainsi	ainsi	ADV		471	advmod		O
# 473	:	:	PUNCT		471	punct		O
# 474	"	"	PUNCT		471	punct		O
# 475	Quand	quand	SCONJ		480	mark		O
# 476	je	je	PRON	Number=Sing|Person=1	480	nsubj		O
# 477	suis	être	AUX	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	480	cop		O
# 478	sur	sur	ADP		480	case		O
# 479	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	480	det		O
# 480	terrain	terrain	NOUN	Gender=Masc|Number=Sing	471	advcl		O
# 481	,	,	PUNCT		483	punct		O
# 482	j'	je	PRON	Number=Sing|Person=1	483	nsubj		O
# 483	ai	avoir	VERB	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	471	conj		O
# 484	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	485	det		O
# 485	personnalité	personnalité	NOUN	Gender=Fem|Number=Sing	483	obj		O
# 486	assez	assez	ADV		487	advmod		O
# 487	différente	différente	NOUN	Gender=Masc|Number=Sing	485	amod		O
# 488	de	de	ADP		489	case		O
# 489	celle	celui	PRON	Gender=Fem|Number=Sing|PronType=Dem	487	nmod		O
# 490	à	à	ADP		492	case		O
# 491	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	492	det		O
# 492	extérieur	extérieur	NOUN	Gender=Masc|Number=Sing	485	nmod		O
# 493	.	.	PUNCT		471	punct		O
# 494	Je	je	PRON	Number=Sing|Person=1	499	nsubj		O
# 495	suis	être	AUX	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	499	aux:pass		O
# 496	vraiment	vraiment	ADV		499	advmod		O
# 497	là	là	ADV		499	advmod		O
# 498	pour	pour	ADP		499	mark		O
# 499	aider	aider	VERB	VerbForm=Inf	499	ROOT		O
# 500	mes	mon	DET	Number=Plur|Poss=Yes	501	det		O
# 501	coéquipiers	coéquipier	ADJ	Gender=Masc|Number=Plur	499	obj		O
# 502	et	et	CCONJ		504	cc		O
# 503	les	le	PRON	Number=Plur|Person=3	504	det		O
# 504	tirer	tirer	VERB	VerbForm=Inf	499	conj		O
# 505	au	au	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	506	case		O
# 506	maximum	maximum	NOUN	Gender=Masc|Number=Sing	504	obl:arg		O
# 507	,	,	PUNCT		504	punct		O
# 508	sans	sans	ADP		510	mark		O
# 509	même	même	ADV		510	advmod		O
# 510	regarder	regarder	VERB	VerbForm=Inf	504	advcl		O
# 511	qui	qui	PRON	PronType=Rel	515	nsubj		O
# 512	est	être	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	515	cop		O
# 513	sur	sur	ADP		515	case		O
# 514	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	515	det		O
# 515	terrain	terrain	NOUN	Gender=Masc|Number=Sing	510	obj		O
# 516	ou	ou	CCONJ		517	cc		O
# 517	pas	pas	ADV	Polarity=Neg	515	conj		O
# 518	,	,	PUNCT		510	punct		O
# 519	qui	qui	PRON	PronType=Rel	520	nsubj		O
# 520	a	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	510	acl:relcl		O
# 521	plus	plus	ADV		520	advmod		O
# 522	de	de	DET	Definite=Ind|Number=Plur|PronType=Art	523	case		O
# 523	sélections	sélection	NOUN	Gender=Fem|Number=Plur	521	obl:arg		O
# 524	.	.	PUNCT		499	punct		O
# 525	C'	ce	PRON	Number=Sing|Person=3	527	expl:subj		O
# 526	est	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	527	cop		O
# 527	naturel	naturel	ADJ	Gender=Masc|Number=Sing	527	ROOT		O
# 528	chez	chez	ADP		529	case		O
# 529	moi	moi	PRON	Number=Sing|Person=1|PronType=Prs	527	obl:mod		O
# 530	,	,	PUNCT		527	punct		O
# 531	parce	parce	SCONJ		534	mark		O
# 532	que	que	SCONJ		531	fixed		O
# 533	j'	je	PRON	Number=Sing|Person=1	534	nsubj		O
# 534	ai	avoir	VERB	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	527	advcl		O
# 535	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	536	det		O
# 536	envie	envie	NOUN	Gender=Fem|Number=Sing	534	obj		O
# 537	de	de	ADP		538	case		O
# 538	gagner	gagner	VERB	VerbForm=Inf	536	nmod		O
# 539	.	.	PUNCT		527	punct		O
# 540	"	"	PUNCT		541	punct		O
# 541	Promu	promu	NOUN	Gender=Masc|Number=Sing	557	nsubj		O
# 542	titulaire	titulaire	ADJ	Number=Sing	541	amod		O
# 543	indiscutable	indiscutable	ADJ	Number=Sing	541	amod		O
# 544	en	en	ADP		546	case		O
# 545	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	546	det		O
# 546	absence	absence	NOUN	Gender=Fem|Number=Sing	541	nmod		O
# 547	de	de	ADP		549	case		O
# 548	N'	ne	ADV	Polarity=Neg	549	det	MISC	B
# 549	Golo	Golo	PROPN		546	nmod	MISC	I
# 550	Kanté	Kanté	PROPN		549	flat:name	MISC	I
# 551	et	et	CCONJ		552	cc		O
# 552	Paul	Paul	PROPN	Gender=Masc|Number=Sing	550	conj	PER	B
# 553	Pogba	Pogba	PROPN		552	flat:name	PER	I
# 554	,	,	PUNCT		541	punct		O
# 555	Rabiot	Rabiot	PROPN		541	nmod	PER	B
# 556	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	557	aux:tense		O
# 557	assumé	assumer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	557	ROOT		O
# 558	son	son	DET	Number=Sing|Poss=Yes	559	det		O
# 559	rôle	rôle	NOUN	Gender=Masc|Number=Sing	557	obj		O
# 560	de	de	ADP		561	case		O
# 561	patron	patron	NOUN	Gender=Masc|Number=Sing	559	nmod		O
# 562	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	563	case		O
# 563	milieu	milieu	NOUN	Gender=Masc|Number=Sing	561	nmod		O
# 564	.	.	PUNCT		557	punct		O
# 565
#
# 	SPACE		564	dep		O
# 566	Quelques	quelque	DET	Definite=Ind|Number=Plur|PronType=Art	567	det		O
# 567	instants	instant	NOUN	Gender=Masc|Number=Plur	567	ROOT		O
# 568	pour	pour	ADP		570	mark		O
# 569	s'	se	PRON	Person=3|Reflex=Yes	570	expl:comp		O
# 570	encourager	encourager	VERB	VerbForm=Inf	570	ROOT		O
# 571
#
#
#
# 	SPACE		570	dep		O
# 572	Sur	sur	ADP		574	case		O
# 573	son	son	DET	Number=Sing|Poss=Yes	574	det		O
# 574	but	but	NOUN	Gender=Masc|Number=Sing	570	obl:arg		O
# 575	égalisateur	égalisateur	ADJ	Gender=Masc|Number=Sing	574	amod		O
# 576	,	,	PUNCT		574	punct		O
# 577	tous	tout	ADJ	Gender=Masc|Number=Plur	579	amod		O
# 578	les	le	DET	Definite=Def|Number=Plur|PronType=Art	579	det		O
# 579	joueurs	joueur	NOUN	Gender=Masc|Number=Plur	587	nsubj		O
# 580	de	de	ADP		582	case		O
# 581	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	582	det		O
# 582	équipe	équipe	NOUN	Gender=Fem|Number=Sing	579	nmod		O
# 583	de	de	ADP		584	case	LOC	B
# 584	France	France	PROPN	Gender=Fem|Number=Sing	582	nmod	LOC	I
# 585	se	se	PRON	Person=3|Reflex=Yes	587	expl:comp		O
# 586	sont	être	AUX	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	587	aux:tense		O
# 587	retrouvés	retrouver	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	574	acl		O
# 588	dans	dans	ADP		590	case		O
# 589	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	590	det		O
# 590	camp	camp	NOUN	Gender=Masc|Number=Sing	587	obl:mod		O
# 591	australien	australien	ADJ	Gender=Masc|Number=Sing	590	amod		O
# 592	pour	pour	ADP		593	mark		O
# 593	prendre	prendre	VERB	VerbForm=Inf	587	advcl		O
# 594	quelques	quelque	DET	Definite=Ind|Number=Plur|PronType=Art	595	det		O
# 595	secondes	seconde	NOUN	Gender=Fem|Number=Plur	593	obj		O
# 596	dans	dans	ADP		598	case		O
# 597	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	598	det		O
# 598	nuit	nuit	NOUN	Gender=Fem|Number=Sing	595	nmod		O
# 599	de	de	ADP		600	case		O
# 600	Doha	doha	ADV		598	nmod	LOC	B
# 601	.	.	PUNCT		570	punct		O
# 602	S'	se	PRON	Person=3|Reflex=Yes	603	obj		O
# 603	encourager	encourager	VERB	VerbForm=Inf	606	advcl		O
# 604	,	,	PUNCT		606	punct		O
# 605	se	se	PRON	Person=3|Reflex=Yes	606	expl:comp		O
# 606	rassurer	rassurer	VERB	VerbForm=Inf	609	advcl		O
# 607	,	,	PUNCT		609	punct		O
# 608	se	se	PRON	Person=3|Reflex=Yes	609	expl:comp		O
# 609	motiver	motiver	VERB	VerbForm=Inf	609	ROOT		O
# 610	.	.	PUNCT		609	punct		O
# 611	Mettre	mettre	VERB	VerbForm=Inf	611	ROOT		O
# 612	davantage	davantage	ADV		611	advmod		O
# 613	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	614	det		O
# 614	pied	pied	NOUN	Gender=Masc|Number=Sing	611	obj		O
# 615	.	.	PUNCT		611	punct		O
# 616	Mettre	mettre	VERB	VerbForm=Inf	616	ROOT		O
# 617	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	618	det		O
# 618	intensité	intensité	NOUN	Gender=Fem|Number=Sing	616	obj		O
# 619	digne	digne	ADJ	Number=Sing	618	amod		O
# 620	d'	de	ADP		622	case		O
# 621	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	622	det		O
# 622	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	619	obl:arg	MISC	B
# 623	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	624	case	MISC	I
# 624	monde	monde	NOUN	Gender=Masc|Number=Sing	622	nmod	MISC	I
# 625	,	,	PUNCT		616	punct		O
# 626	finalement	finalement	ADV		616	advmod		O
# 627	.	.	PUNCT		616	punct		O
# 628	Ce	ce	PRON	Number=Sing|Person=3	631	nsubj		O
# 629	fut	être	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	631	cop		O
# 630	beaucoup	beaucoup	ADV		631	advmod		O
# 631	mieux	mieux	ADV		631	ROOT		O
# 632	par	par	ADP		634	case		O
# 633	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	634	det		O
# 634	suite	suite	NOUN	Gender=Fem|Number=Sing	631	obl:mod		O
# 635	,	,	PUNCT		631	punct		O
# 636	et	et	CCONJ		639	cc		O
# 637	on	on	PRON	Number=Sing|Person=3	639	nsubj		O
# 638	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	639	aux:tense		O
# 639	vu	voir	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	631	conj		O
# 640	Olivier	Olivier	PROPN	Gender=Masc|Number=Sing	639	obj	PER	B
# 641	Giroud	Giroud	PROPN		640	flat:name	PER	I
# 642	,	,	PUNCT		639	punct		O
# 643	autre	autre	ADJ	Number=Sing	639	conj		O
# 644	leader	leader	VERB	VerbForm=Inf	643	xcomp		O
# 645	,	,	PUNCT		644	punct		O
# 646	apaiser	apaiser	VERB	VerbForm=Inf	644	xcomp		O
# 647	certains	certain	DET	Gender=Masc|Number=Plur	648	det		O
# 648	coéquipiers	coéquipier	ADJ	Gender=Masc|Number=Plur	646	obj		O
# 649	et	et	CCONJ		650	cc		O
# 650	donner	donner	VERB	VerbForm=Inf	646	conj		O
# 651	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	652	det		O
# 652	consignes	consigne	NOUN	Gender=Fem|Number=Plur	650	obj		O
# 653	à	à	ADP		654	case		O
# 654	Benjamin	Benjamin	PROPN	Gender=Masc|Number=Sing	650	obl:arg	PER	B
# 655	Pavard	Pavard	PROPN	Gender=Masc|Number=Sing	654	nmod	PER	I
# 656	,	,	PUNCT		644	punct		O
# 657	en	en	ADP		658	case		O
# 658	difficulté	difficulter	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	644	advcl		O
# 659	ce	ce	DET	Gender=Masc|Number=Sing|PronType=Dem	660	det		O
# 660	soir	soir	NOUN	Gender=Masc|Number=Sing	658	obj		O
# 661	.	.	PUNCT		631	punct		O
# 662
#
#
#
# 	SPACE		661	dep		O
# 663	Les	le	DET	Definite=Def|Number=Plur|PronType=Art	664	det		O
# 664	nuages	nuage	NOUN	Gender=Masc|Number=Plur	670	nsubj		O
# 665	passés	passer	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	664	acl		O
# 666	,	,	PUNCT		670	punct		O
# 667	les	le	DET	Definite=Def|Number=Plur|PronType=Art	668	det		O
# 668	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	670	nsubj	ORG	B
# 669	ont	avoir	AUX	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	670	aux:tense		O
# 670	déroulé	dérouler	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	670	ROOT		O
# 671	comme	comme	ADP		672	case		O
# 672	rarement	rarement	ADV		670	obl:mod		O
# 673	ces	ce	DET	Number=Plur|PronType=Dem	675	det		O
# 674	derniers	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Plur	675	amod		O
# 675	mois	mois	NOUN	Gender=Masc|Number=Plur	670	obj		O
# 676	.	.	PUNCT		670	punct		O
# 677	Au	au	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	678	case		O
# 678	point	point	NOUN	Gender=Masc|Number=Sing	678	ROOT		O
# 679	que	que	SCONJ		682	mark		O
# 680	les	le	DET	Definite=Def|Number=Plur|PronType=Art	681	det		O
# 681	échecs	échec	NOUN	Gender=Masc|Number=Plur	682	nsubj		O
# 682	semblent	sembler	VERB	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	678	acl:relcl		O
# 683	nourrir	nourrir	VERB	VerbForm=Inf	682	xcomp		O
# 684	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	685	det		O
# 685	équipe	équipe	NOUN	Gender=Fem|Number=Sing	683	obj		O
# 686	.	.	PUNCT		678	punct		O
# 687	Une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	688	det		O
# 688	thèse	thèse	NOUN	Gender=Fem|Number=Sing	688	ROOT		O
# 689	développée	développé	ADJ	Gender=Fem|Number=Sing	688	amod		O
# 690	,	,	PUNCT		688	punct		O
# 691	déjà	déjà	ADV		693	advmod		O
# 692	en	en	ADP		693	case		O
# 693	septembre	septembre	NOUN	Gender=Masc|Number=Sing	688	nmod		O
# 694	,	,	PUNCT		688	punct		O
# 695	par	par	ADP		696	case		O
# 696	Antoine	Antoine	PROPN		688	nmod	PER	B
# 697	Griezmann	Griezmann	PROPN		696	flat:name	PER	I
# 698	.	.	PUNCT		688	punct		O
# 699	Interrogé	interroger	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	729	advcl		O
# 700	sur	sur	ADP		703	case		O
# 701	les	le	DET	Definite=Def|Number=Plur|PronType=Art	703	det		O
# 702	mauvais	mauvais	NOUN	Gender=Masc|Number=Plur	703	amod		O
# 703	résultats	résultat	ADJ	Gender=Masc|Number=Plur	699	obl:arg		O
# 704	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	705	case		O
# 705	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	703	nmod	ORG	B
# 706	ces	ce	DET	Number=Plur|PronType=Dem	708	det		O
# 707	derniers	dernier	ADJ	Gender=Masc|NumType=Ord|Number=Plur	708	amod		O
# 708	mois	mois	NOUN	Gender=Masc|Number=Plur	699	obl:mod		O
# 709	,	,	PUNCT		708	punct		O
# 710	avec	avec	ADP		713	case		O
# 711	une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	713	det		O
# 712	seule	seul	ADJ	Gender=Fem|Number=Sing	713	amod		O
# 713	victoire	victoire	NOUN	Gender=Fem|Number=Sing	699	obl:mod		O
# 714	en	en	ADP		715	case		O
# 715	six	six	NUM	NumType=Card	716	nummod		O
# 716	matchs	match	NOUN	Number=Plur	713	nmod		O
# 717	,	,	PUNCT		713	punct		O
# 718	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	719	det		O
# 719	numéro	numéro	NOUN	Gender=Masc|Number=Sing	713	appos		O
# 720	7	7	NUM	NumType=Card	719	nummod		O
# 721	y	y	PRON	Person=3	722	iobj		O
# 722	voyait	voir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	719	acl:relcl		O
# 723	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	724	case		O
# 724	bon	bon	ADJ	Gender=Masc|Number=Sing	722	nmod		O
# 725	:	:	PUNCT		699	punct		O
# 726	"	"	PUNCT		729	punct		O
# 727	Ça	cela	PRON	Gender=Masc|Number=Sing|Person=3	729	nsubj	MISC	B
# 728	nous	nous	PRON	Number=Plur|Person=1	729	iobj		O
# 729	fait	faire	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	729	ROOT		O
# 730	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	734	advmod		O
# 731	bien	bien	ADV		730	fixed		O
# 732	avant	avant	ADP		734	case		O
# 733	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	734	det		O
# 734	Coupe	coupe	NOUN	Gender=Fem|Number=Sing	729	obj	MISC	B
# 735	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	736	case	MISC	I
# 736	monde	monde	NOUN	Gender=Masc|Number=Sing	734	nmod	MISC	I
# 737	"	"	PUNCT		729	punct		O
# 738	.	.	PUNCT		729	punct		O
# 739	Cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	741	det		O
# 740	première	premier	ADJ	Gender=Fem|NumType=Ord|Number=Sing	741	amod		O
# 741	demi-heure	demi-heure	NOUN	Gender=Masc|Number=Sing	755	nsubj		O
# 742	cauchemardesque	cauchemardesque	ADJ	Number=Sing	741	amod		O
# 743	,	,	PUNCT		741	punct		O
# 744	sanctionnée	sanctionner	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	741	acl		O
# 745	par	par	ADP		747	case		O
# 746	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	747	det		O
# 747	but	but	NOUN	Gender=Masc|Number=Sing	744	obl:agent		O
# 748	et	et	CCONJ		750	cc		O
# 749	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	750	det		O
# 750	blessure	blessure	NOUN	Gender=Fem|Number=Sing	741	conj		O
# 751	de	de	ADP		752	case		O
# 752	Lucas	Lucas	PROPN	Gender=Masc|Number=Sing	750	nmod	PER	B
# 753	Hernandez	Hernandez	PROPN		752	flat:name	PER	I
# 754	,	,	PUNCT		741	punct		O
# 755	montre	montr	ADJ	Number=Sing	755	ROOT		O
# 756	que	que	SCONJ		763	mark		O
# 757	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	758	det		O
# 758	Mâconnais	Mâconnais	PROPN	Gender=Masc|Number=Sing	763	nsubj	LOC	B
# 759	n'	ne	ADV	Polarity=Neg	763	advmod		O
# 760	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	763	aux:tense		O
# 761	pas	pas	ADV	Polarity=Neg	762	advmod		O
# 762	juste	juste	ADV		763	advmod		O
# 763	appliqué	appliquer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	755	ccomp		O
# 764	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	765	det		O
# 765	méthode	méthode	NOUN	Gender=Fem|Number=Sing	763	obj		O
# 766	Coué	coué	ADJ	Gender=Masc|Number=Sing	765	acl	ORG	B
# 767	.	.	PUNCT		755	punct		O
# 768	La	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	769	det		O
# 769	difficulté	difficulté	NOUN	Gender=Fem|Number=Sing	772	nsubj		O
# 770	a	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	772	aux:tense		O
# 771	paradoxalement	paradoxalement	ADV		772	advmod		O
# 772	semblé	sembler	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	772	ROOT		O
# 773	débloquer	débloquer	VERB	VerbForm=Inf	772	xcomp		O
# 774	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	775	case		O
# 775	Bleus	bleu	NOUN	Gender=Masc|Number=Plur	773	obl:arg	ORG	B
# 776	submergés	submerger	VERB	Gender=Masc|Number=Plur|Tense=Past|VerbForm=Part	775	acl		O
# 777	par	par	ADP		779	case		O
# 778	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	779	det		O
# 779	pression	pression	NOUN	Gender=Fem|Number=Sing	776	obl:agent		O
# 780	en	en	ADP		781	case		O
# 781	début	début	NOUN	Gender=Masc|Number=Sing	776	obl:mod		O
# 782	de	de	ADP		783	case		O
# 783	rencontre	rencontre	NOUN	Gender=Fem|Number=Sing	781	nmod		O
# 784	.	.	PUNCT		772	punct		O
# 785
#
#
#
# 	SPACE		784	dep		O
# 786	Impossible	Impossible	PROPN		772	obj	PER	B
# 787	,	,	PUNCT		786	punct		O
# 788	dès	dès	ADP		795	advmod		O
# 789	lors	lors	ADV		788	fixed		O
# 790	,	,	PUNCT		795	punct		O
# 791	de	de	ADP		795	mark		O
# 792	ne	ne	ADV	Polarity=Neg	795	advmod		O
# 793	pas	pas	ADV	Polarity=Neg	795	advmod		O
# 794	y	y	PRON	Person=3	795	iobj		O
# 795	voir	voir	VERB	VerbForm=Inf	772	advcl		O
# 796	un	un	DET	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	797	det		O
# 797	lien	lien	NOUN	Gender=Masc|Number=Sing	795	obj		O
# 798	avec	avec	ADP		800	case		O
# 799	la	le	DET	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	800	det		O
# 800	victoire	victoire	NOUN	Gender=Fem|Number=Sing	797	nmod		O
# 801	étriquée	étriqué	ADJ	Gender=Fem|Number=Sing	800	amod		O
# 802	acquise	acquérir	VERB	Gender=Fem|Number=Sing|Tense=Past|VerbForm=Part	797	acl		O
# 803	dans	dans	ADP		807	case		O
# 804	les	le	DET	Definite=Def|Number=Plur|PronType=Art	807	det		O
# 805	plus	plus	ADV		806	advmod		O
# 806	grandes	grand	ADJ	Gender=Fem|Number=Plur	807	amod		O
# 807	difficultés	difficulté	NOUN	Gender=Fem|Number=Plur	797	acl		O
# 808	contre	contre	ADP		810	case		O
# 809	l'	le	DET	Definite=Def|Number=Sing|PronType=Art	810	det		O
# 810	Australie	Australie	PROPN	Gender=Fem|Number=Sing	807	nmod	LOC	B
# 811	,	,	PUNCT		807	punct		O
# 812	déjà	déjà	ADV		807	advmod		O
# 813	,	,	PUNCT		795	punct		O
# 814	en	en	ADP		815	case		O
# 815	2018	2018	NUM	NumType=Card	795	obl:mod		O
# 816	(	(	PUNCT		815	punct		O
# 817	2	2	NUM	NumType=Card	815	nmod		O
# 818	-	-	NUM	NumType=Card	817	nmod		O
# 819	1	1	NOUN	NumType=Card	817	nmod		O
# 820	)	)	PUNCT		815	punct		O
# 821	.	.	PUNCT		772	punct		O
# 822	Une	un	DET	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	823	det		O
# 823	prestation	prestation	NOUN	Gender=Fem|Number=Sing	823	ROOT		O
# 824	fondatrice	fondateur	ADJ	Gender=Fem|Number=Sing	823	amod		O
# 825	dans	dans	ADP		827	case		O
# 826	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	827	det		O
# 827	parcours	parcours	NOUN	Gender=Masc|Number=Sing	823	nmod		O
# 828	des	de	ADP	Definite=Def|Number=Plur|PronType=Art	829	case		O
# 829	Bleus	Bleus	PROPN		827	nmod	ORG	B
# 830	,	,	PUNCT		827	punct		O
# 831	futurs	futur	NOUN	Gender=Masc|Number=Plur	827	appos		O
# 832	champions	champion	NOUN	Gender=Masc|Number=Plur	831	amod		O
# 833	du	de	ADP	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	834	case		O
# 834	monde	monde	NOUN	Gender=Masc|Number=Sing	831	nmod		O
# 835	.	.	PUNCT		823	punct		O
# 836	Didier	Didier	PROPN	Gender=Masc|Number=Sing	840	nsubj	PER	B
# 837	Deschamps	Deschamps	PROPN	Gender=Masc|Number=Sing	836	flat:name	PER	I
# 838	en	en	PRON	Person=3	840	iobj		O
# 839	avait	avoir	AUX	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	840	aux:tense		O
# 840	tiré	tirer	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	840	ROOT		O
# 841	des	un	DET	Definite=Ind|Number=Plur|PronType=Art	842	det		O
# 842	leçons	leçon	NOUN	Gender=Fem|Number=Plur	840	obj		O
# 843	,	,	PUNCT		840	punct		O
# 844	en	en	ADP		845	mark		O
# 845	bouleversant	bouleverser	VERB	Tense=Pres|VerbForm=Part	840	advcl		O
# 846	sa	son	DET	Gender=Fem|Number=Sing|Poss=Yes	847	det		O
# 847	composition	composition	NOUN	Gender=Fem|Number=Sing	845	obj		O
# 848	d'	de	ADP		849	case		O
# 849	équipe	équipe	NOUN	Gender=Fem|Number=Sing	847	nmod		O
# 850	dès	dès	ADP		853	case		O
# 851	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	853	det		O
# 852	second	second	ADJ	Gender=Masc|NumType=Ord|Number=Sing	853	amod		O
# 853	match	match	NOUN	Gender=Masc|Number=Sing	845	obl:mod		O
# 854	.	.	PUNCT		840	punct		O
# 855	Ce	ce	DET	Gender=Masc|Number=Sing|PronType=Dem	857	det		O
# 856	nouveau	nouveau	ADJ	Gender=Masc|Number=Sing	857	amod		O
# 857	succès	succès	NOUN	Gender=Masc|Number=Sing	874	nsubj		O
# 858	contre	contre	ADP		860	case		O
# 859	les	le	DET	Definite=Def|Number=Plur|PronType=Art	860	det		O
# 860	Socceroos	Socceroos	PROPN		857	nmod	MISC	B
# 861	,	,	PUNCT		857	punct		O
# 862	beaucoup	beaucoup	ADV		863	advmod		O
# 863	plus	plus	ADV		864	advmod		O
# 864	large	large	ADJ	Number=Sing	857	amod		O
# 865	cette	ce	DET	Gender=Fem|Number=Sing|PronType=Dem	866	det		O
# 866	fois	fois	NOUN	Gender=Fem|Number=Sing	864	dep		O
# 867	mais	mais	CCONJ		870	cc		O
# 868	après	après	ADP		870	mark		O
# 869	avoir	avoir	AUX	VerbForm=Inf	870	aux:tense		O
# 870	renversé	renverser	VERB	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	866	conj		O
# 871	le	le	DET	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	872	det		O
# 872	score	score	NOUN	Gender=Masc|Number=Sing	870	obj		O
# 873	,	,	PUNCT		874	punct		O
# 874	aura	avoir	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	874	ROOT		O
# 875	peut-être	peut-être	ADV		874	advmod		O
# 876	les	le	DET	Definite=Def|Number=Plur|PronType=Art	878	det		O
# 877	mêmes	même	ADJ	Number=Plur	878	amod		O
# 878	vertus	vertu	NOUN	Gender=Fem|Number=Plur	874	obj		O
# 879	.	.	PUNCT		874	punct		O

# %% [markdown]
# Visualisation des entités nommées dans un texte.

# %%
from spacy import displacy
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">France-Australie : une première demi-heure fondatrice pour les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dans cette
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coupe du monde 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  ?<br><br>L'entame de match des
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , ratée mardi contre l'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  malgré la victoire finale (4-1), pourrait servir de déclic pour le reste du
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mondial
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .<br><br>L'incompréhension d'
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hugo Lloris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Le regard noir de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Benjamin Pavard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . L'inquiétude autour de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucas Hernandez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . L'équipe
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     de France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  n'est entrée que depuis neuf minutes dans sa
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coupe du monde 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , mardi 22 novembre, qu'elle se trouve déjà en pleine tourmente. Menés par l'
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  voient les spectres des derniers mois resurgir soudainement : les blessures, les mauvais résultats, les doutes.
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  se prend de plein fouet le mur sur lequel se brisent les ambitions des champions du monde en titre lors des dernières éditions.<br><br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Devancés
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  au tableau d'affichage après le but de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Craig Goodwin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , les
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bleus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  doivent en plus digérer la blessure de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucas Hernandez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . &quot;Je pense que ça va être malheureusement assez grave&quot;, a confirmé
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Didier Deschamps
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  en conférence de presse après le match. Le choix du sélectionneur de ne pas retenir un latéral de plus et d'avoir convoqué trois défenseurs centraux (
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pavard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lucas Hernandez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  et
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jules Koundé
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ) pour jouer sur les côtés exacerbe les interrogations dans le
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     stade Al-Janoub
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . Tout se bouscule.<br>&quot;La blessure de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %% [markdown]
# Visualisation de l'abre de dépendance d'une phrase donnée.

# %%
displacy.render(list(doc.sents)[4], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="93b30437682148099dcd2c8fa59382b4-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">L'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">incompréhension</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">d'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Hugo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Lloris.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93b30437682148099dcd2c8fa59382b4-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93b30437682148099dcd2c8fa59382b4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93b30437682148099dcd2c8fa59382b4-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93b30437682148099dcd2c8fa59382b4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93b30437682148099dcd2c8fa59382b4-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93b30437682148099dcd2c8fa59382b4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-93b30437682148099dcd2c8fa59382b4-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-93b30437682148099dcd2c8fa59382b4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# [Q7] Visualiser l'abre de dépendance de la dixième phrase dans un format compact.

# %%
# insérer votre code ici
displacy.render(list(doc.sents)[9], style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="59551c16d43943a797321506d44d3d2a-0" class="displacy" width="8450" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">La</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">France</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">prend</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">plein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">fouet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">le</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">mur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">sur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">lequel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">se</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">brisent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">les</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">ambitions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">champions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">du</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">monde</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">en</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">titre</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">lors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">dernières</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">éditions.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Devancés</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">au</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">tableau</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">d'</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">affichage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300

# %% [markdown]
# 4 - Utilisation d'une image pour la réalisation d'un nuage de mots
# -----

# %%
from PIL import Image
import numpy as np

# %% [markdown]
# Convertir l'image en une matrice de valeurs 0 ou 255, i.e. un masque.

# %%
mask = (np.array(Image.open("football.png").convert('L')) > 0) * 255
plt.imshow(mask)

# %%
mask2 = (np.array(Image.open("heart.png").convert('L')) > 0) * 255
plt.imshow(mask2)

# %% [markdown]
# Génerer le nuage de mots avec des masques.

# %%
wc = WordCloud(background_color="white", max_words=100, mask=mask, contour_width=1, contour_color='steelblue')
wc.generate_from_frequencies(freq_list)
plt.imshow(wc, interpolation='bilinear')

# %%
wc = WordCloud(background_color="white", max_words=100, mask=mask2, contour_width=1, contour_color='steelblue')
wc.generate_from_frequencies(freq_list)
plt.imshow(wc, interpolation='bilinear')

# %% [markdown]
# 5 - Extraire des unités polylexicales
# -----

# %%
import nltk
from nltk.collocations import *

# %% [markdown]
# Trouver les bigrams avec l'information mutuelle la plus forte.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words([token.text for token in doc])
finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('22', 'novembre'),
#  ('Antoine', 'Griezmann'),
#  ('Au', 'point'),
#  ('Craig', 'Goodwin'),
#  ('Dayot', 'Upamecano'),
#  ('Golo', 'Kanté'),
#  ('Jules', 'Koundé'),
#  ('Mitchell', 'Duke'),
#  ("N'", 'Golo'),
#  ('Olivier', 'Giroud')]

# %% [markdown]
# [Q8] Trouver les 10 bigrams avec le coefficient de DICE le plus élevé.

# %%
# insérer votre code ici
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words([token.text for token in doc])
finder.nbest(bigram_measures.dice, 10)
# Out:
# [('22', 'novembre'),
#  ('Antoine', 'Griezmann'),
#  ('Au', 'point'),
#  ('Craig', 'Goodwin'),
#  ('Dayot', 'Upamecano'),
#  ('Didier', 'Deschamps'),
#  ('Golo', 'Kanté'),
#  ('Jules', 'Koundé'),
#  ('Mitchell', 'Duke'),
#  ("N'", 'Golo')]

# %% [markdown]
# Trouver les 10 trigrams avec l'information mutuelle la plus élevée.

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words([token.text for token in doc])
finder.nbest(trigram_measures.pmi, 10)
# Out:
# [("N'", 'Golo', 'Kanté'),
#  ('Promu', 'titulaire', 'indiscutable'),
#  ('convoqué', 'trois', 'défenseurs'),
#  ('déroulé', 'comme', 'rarement'),
#  ('naturel', 'chez', 'moi'),
#  ('ont', 'déroulé', 'comme'),
#  ('paradoxalement', 'semblé', 'débloquer'),
#  ('prendre', 'quelques', 'secondes'),
#  ('sans', 'même', 'regarder'),
#  ('tempête', 'emportait', 'tout')]

# %% [markdown]
# [Q9] Trouver les 10 trigrams avec le coefficient de DICE le plus élevé. Que se passe-t-il? Quelles sont les alternatives?

# %%
# insérer votre code ici
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words([token.text for token in doc])
finder.nbest(trigram_measures.raw_freq, 10)

# Il n'existe de coefficient DICE pour trigram
# Les alternatives sont : chi_sq, jaccard,likelihood_ratio, mi_like, poisson_stirling, raw_freq, student_t
# Out:
# [('Coupe', 'du', 'monde'),
#  ('blessure', 'de', 'Lucas'),
#  (',', 'les', 'Bleus'),
#  ('de', 'Lucas', 'Hernandez'),
#  ('sur', 'le', 'terrain'),
#  ('équipe', 'de', 'France'),
#  ('"', ',', 'a'),
#  ('"', 'La', 'blessure'),
#  ('-', '1', ')'),
#  ('Didier', 'Deschamps', 'en')]

# %% [markdown]
# Intégrer les 30 meilleurs bigrams suivant le coefficient de DICE dans un texte en les connectant par un underscore. Et générer le nuage de mot correspondant.

# %%
from nltk.tokenize import MWETokenizer

# %%
finder = BigramCollocationFinder.from_words([token.text for token in doc])
tokenizer = MWETokenizer(finder.nbest(bigram_measures.dice, 30))
new_doc = nlp(' '.join(tokenizer.tokenize([token.text for token in doc])))
generate_wordcloud(Counter([token.text for token in new_doc if not token.is_stop and "\n" not in token.text]))

# %% [markdown]
# [Q10] Intégrer les 30 meilleurs trigrams suivant l'information mutuelle dans un texte en les connectant par un underscore. Et générer un nuage de mot qui ne contient que des trigrams.

# %%
# insérer votre code ici
finder = TrigramCollocationFinder.from_words([token.text for token in doc])
tokenizer = MWETokenizer(finder.nbest(trigram_measures.raw_freq, 30))
new_doc = nlp(' '.join(tokenizer.tokenize([token.text for token in doc])))
generate_wordcloud(Counter([token.text for token in new_doc if not token.is_stop and "\n" not in token.text]))

# %% [markdown]
# 6 - Enrichissement des textes par liaison ontologique
# -----

# %%
from nltk.corpus import wordnet as wn
#import nltk
#nltk.download('omw-1.4')

# %% [markdown]
# L'algorithme de Lesk (https://en.wikipedia.org/wiki/Lesk_algorithm) permet de désambiguiser le sens d'un mot dans un contexte défini. Par exemple, dans la phrase, "le chanteur danse la java avec des choristes", l'algorithme de Lesk permet de désambiguiser le sens de java, i.e. java dans les sens de danse et non java dans le sens de café ou de langage de programmation. L'algorithme de Lesk retourne le sens correspondant à un mot dans un contexte donné.

# %%
def lesk(context_sentence, ambiguous_word, pos=None, synsets=None):
    
    """Return a synset for an ambiguous word in a context.
    :param iter context_sentence: The context sentence where the ambiguous word
         occurs, passed as an iterable of words.
    :param str ambiguous_word: The ambiguous word that requires WSD.
    :param str pos: A specified Part-of-Speech (POS).
    :param iter synsets: Possible synsets of the ambiguous word.
    :return: ``lesk_sense`` The Synset() object with the highest signature overlaps.
    This function is an implementation of the original Lesk algorithm (1986) [1].
    Usage example::
        >>> lesk(['I', 'went', 'to', 'the', 'bank', 'to', 'deposit', 'money', '.'], 'bank', 'n')
        Synset('savings_bank.n.02')
    [1] Lesk, Michael. "Automatic sense disambiguation using machine
    readable dictionaries: how to tell a pine cone from an ice cream
    cone." Proceedings of the 5th Annual International Conference on
    Systems Documentation. ACM, 1986.
    https://dl.acm.org/citation.cfm?id=318728
    """

    context = set(context_sentence)
    
    if synsets is None:
        # synsets = wn.synsets(ambiguous_word, lang='fra')
        synsets = wn.synsets(ambiguous_word)
    
    if pos:
        synsets = [ss for ss in synsets if str(ss.pos()) == pos]

    if not synsets:
        return None
    
    _, sense = max(
        (len(context.intersection(ss.definition().split())), ss) for ss in synsets
    )

    return sense

# %% [markdown]
# Nous travaillerons avec un texte en anglais pour avoir toutes les fonctions nécessaires d'accès à wordnet. Si vous voulez tester d'autres langues, l'italien et l'espagnol fonctionnent.

# %%
nlp = spacy.load("en_core_web_lg")

text_path3 = "sport-en.txt"

text3 = ""
with open(text_path3, encoding='utf-8') as f:
    text3 = f.read()
    
doc = nlp(text3)

# %% [markdown]
# Pour tous les mots d'un texte, trouver le sens de chacun d'eux dans wordnet. Attention, seuls les noms, les verbes, les adjectifs et les adverbes se trouvent dans wordnet. Dans cet exemple, le contexte donné est celui de la phrase dans lequel se trouve le mot.

# %%
pos_to_wn = {'NOUN': wn.NOUN, 'VERB': wn.VERB, 'ADJ': wn.ADJ, 'ADV': wn.ADV, 'PROPN': wn.NOUN}

sent_level = []

for sent in doc.sents:
    context = [token.text for token in sent]
    for token in sent:
        if token.pos_ in pos_to_wn:
            # print((token.text, lesk(context, token.lemma_, pos=pos_to_wn[token.pos_])))
            sent_level.append((token.text, lesk(context, token.lemma_, pos=pos_to_wn[token.pos_])))
        else:
            sent_level.append((token.text, None))

sent_level
# Out:
# [('The', None),
#  ('US', Synset('uranium.n.01')),
#  ('Men', Synset('serviceman.n.01')),
#  ('’s', None),
#  ('National', Synset('national.n.01')),
#  ('Team', Synset('team.n.02')),
#  ('(', None),
#  ('USMNT', None),
#  (')', None),
#  ('was', None),
#  ('made', Synset('make.v.42')),
#  ('to', None),
#  ('work', Synset('work.v.01')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('seat.n.01')),
#  ('in', None),
#  ('the', None),
#  ('World', Synset('world.n.06')),
#  ('Cup', Synset('cup.n.08')),
#  ('knockout', Synset('knockout.n.02')),
#  ('stage', Synset('stage.n.08')),
#  (',', None),
#  ('earning', Synset('gain.v.08')),
#  ('a', None),
#  ('tough', Synset('tough.a.07')),
#  ('1', None),
#  ('-', None),
#  ('0', None),
#  ('win', Synset('win.n.01')),
#  ('over', None),
#  ('Iran', Synset('iran.n.01')),
#  ('in', None),
#  ('a', None),
#  ('nerve', Synset('nerve.n.01')),
#  ('-', None),
#  ('racking', Synset('rack.v.10')),
#  ('Group', Synset('group.n.03')),
#  ('B', Synset('boron.n.01')),
#  ('decider', None),
#  ('at', None),
#  ('Qatar', Synset('qatar.n.02')),
#  ('2022', None),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('first', Synset('first.a.01')),
#  ('-', None),
#  ('half', Synset('half.n.02')),
#  ('goal', Synset('goal.n.01')),
#  ('was', None),
#  ('all', None),
#  ('that', None),
#  ('separated', Synset('discriminate.v.02')),
#  ('the', None),
#  ('two', None),
#  ('sides', Synset('side.n.09')),
#  ('as', None),
#  ('the', None),
#  ('USMNT', None),
#  ('reached', Synset('pass.v.05')),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('for', None),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('time', Synset('time.n.02')),
#  ('since', None),
#  ('2014', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('pressure', Synset('pressure.n.01')),
#  ('was', None),
#  ('certainly', Synset('surely.r.01')),
#  ('on', None),
#  ('for', None),
#  ('Gregg', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('after', None),
#  ('the', None),
#  ('national', Synset('national.a.02')),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('failure', Synset('failure.n.07')),
#  ('to', None),
#  ('qualify', Synset('stipulate.v.01')),
#  ('for', None),
#  ('the', None),
#  ('2018', None),
#  ('World', Synset('world.n.02')),
#  ('Cup', Synset('cup.n.08')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('US', Synset('uranium.n.01')),
#  ('got', Synset('scram.v.01')),
#  ('the', None),
#  ('job', Synset('occupation.n.01')),
#  ('done', Synset('suffice.v.01')),
#  ('with', None),
#  ('three', None),
#  ('gritty', None),
#  ('group', Synset('group.n.03')),
#  ('performances', Synset('performance.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('It', None),
#  ('certainly', Synset('surely.r.01')),
#  ('was', None),
#  ('n’t', None),
#  ('pretty', None),
#  ('at', None),
#  ('times', Synset('time.n.05')),
#  (',', None),
#  ('in', None),
#  ('particular', None),
#  ('in', None),
#  ('the', None),
#  ('closing', Synset('close_up.v.03')),
#  ('stages', Synset('stage.n.08')),
#  ('against', None),
#  ('Iran', Synset('iran.n.01')),
#  (',', None),
#  ('but', None),
#  ('progressing', Synset('advance.v.01')),
#  ('through', None),
#  ('the', None),
#  ('group', Synset('group.n.03')),
#  ('stage', Synset('stage.n.08')),
#  ('was', None),
#  ('the', None),
#  ('minimum', Synset('minimal.a.01')),
#  ('expectation', Synset('expectation.n.03')),
#  ('for', None),
#  ('this', None),
#  ('exciting', Synset('exciting.a.01')),
#  ('young', Synset('young.a.01')),
#  ('team', Synset('team.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('will', None),
#  ('be', None),
#  ('some', None),
#  ('concerns', Synset('concern.n.02')),
#  ('going', Synset('fit.v.02')),
#  ('into', None),
#  ('the', None),
#  ('knockout', Synset('knockout.n.02')),
#  ('stages', Synset('stage.n.03')),
#  (',', None),
#  ('though', Synset('though.r.01')),
#  (',', None),
#  ('after', None),
#  ('Pulisic', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('an', None),
#  ('abdominal', Synset('abdominal.a.01')),
#  ('injury', Synset('injury.n.04')),
#  ('while', None),
#  ('scoring', Synset('score.v.02')),
#  ('the', None),
#  ('winner', Synset('winner.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('will', None),
#  ('be', None),
#  ('hoping', Synset('hope.v.03')),
#  ('its', None),
#  ('star', Synset('star_topology.n.01')),
#  ('man', Synset('homo.n.02')),
#  (',', None),
#  ('dubbed', Synset('dub.v.02')),
#  ('‘', None),
#  ('Captain', Synset('captain.n.07')),
#  ('America', Synset('united_states.n.01')),
#  ('’', None),
#  ('by', None),
#  ('some', None),
#  (',', None),
#  ('is', None),
#  ('fit', Synset('fit.a.01')),
#  ('for', None),
#  ('the', None),
#  ('round', Synset('turn.n.09')),
#  ('of', None),
#  ('16', None),
#  ('tie', Synset('tie.n.07')),
#  ('against', None),
#  ('the', None),
#  ('Netherlands', Synset('netherlands.n.01')),
#  ('on', None),
#  ('Saturday', Synset('saturday.n.01')),
#  ('following', Synset('follow.v.18')),
#  ('the', None),
#  ('news', Synset('newsworthiness.n.01')),
#  ('that', None),
#  ('Pulisic', None),
#  ('had', None),
#  ('been', None),
#  ('sent', Synset('commit.v.03')),
#  ('to', None),
#  ('hospital', Synset('hospital.n.02')),
#  ('for', None),
#  ('a', None),
#  ('scan', Synset('scan.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('and', None),
#  ('Tyler', Synset('tyler.n.01')),
#  ('Adams', Synset('adam.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('the', None),
#  ('opening', Synset('opening.n.02')),
#  ('goal', Synset('goal.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Winner', Synset('winner.n.02')),
#  ('takes', Synset('take.v.39')),
#  ('all', None),
#  ('\n\n', None),
#  ('This', None),
#  ('was', None),
#  ('the', None),
#  ('only', None),
#  ('the', None),
#  ('third', None),
#  ('meeting', Synset('merging.n.01')),
#  ('ever', Synset('always.r.01')),
#  ('between', None),
#  ('the', None),
#  ('two', None),
#  ('nations', Synset('state.n.04')),
#  ('and', None),
#  ('their', None),
#  ('first', Synset('first.a.01')),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('encounter', Synset('encounter.n.03')),
#  ('since', None),
#  ('France', Synset('france.n.01')),
#  ('1998', None),
#  ('–', None),
#  ('a', None),
#  ('politically', Synset('politically.r.02')),
#  ('charged', Synset('charge.v.24')),
#  ('match', Synset('match.n.05')),
#  ('that', None),
#  ('saw', Synset('visit.v.01')),
#  ('Iran', Synset('iran.n.01')),
#  ('emerge', Synset('come_forth.v.02')),
#  ('as', None),
#  ('a', None),
#  ('shock', Synset('daze.n.01')),
#  ('2', None),
#  ('-', None),
#  ('1', None),
#  ('winner', Synset('winner.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('That', None),
#  ('was', None),
#  ('the', None),
#  ('first', Synset('first.a.06')),
#  ('time', Synset('time.n.02')),
#  ('that', None),
#  ('Iran', Synset('iran.n.01')),
#  ('and', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  (',', None),
#  ('sometimes', Synset('sometimes.r.01')),
#  ('described', Synset('identify.v.05')),
#  ('officially', Synset('officially.r.01')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('as', None),
#  ('the', None),
#  ('‘', None),
#  ('Great', Synset('great.n.01')),
#  ('Satan', Synset('satan.n.01')),
#  (',', None),
#  ('’', None),
#  ('had', None),
#  ('met', Synset('touch.v.05')),
#  ('on', None),
#  ('the', None),
#  ('football', Synset('football.n.02')),
#  ('pitch', Synset('pitch.n.08')),
#  ('and', None),
#  ('the', None),
#  ('biggest', Synset('large.a.01')),
#  ('sporting', None),
#  ('occasion', Synset('occasion.n.04')),
#  ('between', None),
#  ('the', None),
#  ('countries', Synset('nation.n.02')),
#  ('since', None),
#  ('the', None),
#  ('1979', None),
#  ('revolution', Synset('revolution.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('build', Synset('human_body.n.01')),
#  ('-', None),
#  ('up', None),
#  ('to', None),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('has', None),
#  ('been', None),
#  ('similarly', Synset('similarly.r.01')),
#  ('tense', Synset('tense.a.02')),
#  (',', None),
#  ('with', None),
#  ('Iran', Synset('iran.n.01')),
#  ('even', Synset('even.r.04')),
#  ('calling', Synset('call.v.20')),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('to', None),
#  ('be', None),
#  ('expelled', Synset('rout.v.01')),
#  ('from', None),
#  ('the', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('after', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  ('Soccer', Synset('soccer.n.01')),
#  ('Federation', Synset('federation.n.03')),
#  ('posted', Synset('post.v.08')),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('flag', Synset('pin.n.08')),
#  ('without', None),
#  ('the', None),
#  ('emblem', Synset('emblem.n.02')),
#  ('of', None),
#  ('the', None),
#  ('Islamic', None),
#  ('Republic', Synset('democracy.n.02')),
#  ('on', None),
#  ('its', None),
#  ('social', Synset('social.a.03')),
#  ('media', Synset('metier.n.02')),
#  ('platforms', Synset('platform.n.03')),
#  ('to', None),
#  ('show', Synset('show.v.01')),
#  ('support', Synset('support.n.04')),
#  ('for', None),
#  ('protesters', Synset('demonstrator.n.03')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('USMNT', None),
#  ('manager', Synset('coach.n.01')),
#  ('Berhalter', None),
#  ('and', None),
#  ('captain', Synset('captain.n.07')),
#  ('Tyler', Synset('tyler.n.02')),
#  ('Adams', Synset('adam.n.01')),
#  ('also', Synset('besides.r.02')),
#  ('faced', Synset('front.v.01')),
#  ('some', None),
#  ('tough', Synset('tough.a.07')),
#  ('questions', Synset('question.n.03')),
#  ('from', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('journalists', Synset('journalist.n.01')),
#  ('in', None),
#  ('a', None),
#  ('fiery', None),
#  ('press', Synset('wardrobe.n.01')),
#  ('conference', Synset('conference.n.01')),
#  (',', None),
#  ('fending', Synset('resist.v.04')),
#  ('off', None),
#  ('accusations', Synset('accusation.n.02')),
#  ('of', None),
#  ('hypocrisy', Synset('hypocrisy.n.02')),
#  ('and', None),
#  ('disrespect', Synset('contempt.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('furore', Synset('furor.n.02')),
#  ('surrounding', Synset('wall.v.01')),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('only', Synset('only.r.04')),
#  ('added', Synset('add.v.01')),
#  ('to', None),
#  ('the', None),
#  ('drama', Synset('drama.n.04')),
#  ('of', None),
#  ('a', None),
#  ('matchup', Synset('match-up.n.01')),
#  ('that', None),
#  ('–', None),
#  ('even', Synset('even.r.03')),
#  ('in', None),
#  ('a', None),
#  ('vacuum', Synset('vacuum.n.03')),
#  ('away', Synset('aside.r.02')),
#  ('from', None),
#  ('off', Synset('off.a.01')),
#  ('-', None),
#  ('field', Synset('field.n.12')),
#  ('issues', Synset('return.n.06')),
#  ('–', None),
#  ('was', None),
#  ('guaranteed', Synset('guarantee.v.04')),
#  ('to', None),
#  ('be', None),
#  ('fraught', None),
#  ('with', None),
#  ('tension', Synset('tension.n.04')),
#  ('.', None),
#  ('\n\n', None),
#  ('Both', None),
#  ('teams', Synset('team.n.01')),
#  ('knew', Synset('know.v.03')),
#  ('a', None),
#  ('win', Synset('win.n.01')),
#  ('would', None),
#  ('secure', Synset('fasten.v.01')),
#  ('a', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  (',', None),
#  ('but', None),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('even', Synset('even.r.04')),
#  ('a', None),
#  ('draw', Synset('hook.n.06')),
#  ('would', None),
#  ('not', None),
#  ('be', None),
#  ('enough', None),
#  ('to', None),
#  ('see', Synset('visit.v.01')),
#  ('it', None),
#  ('progress', Synset('progress.v.01')),
#  ('from', None),
#  ('the', None),
#  ('group', Synset('group.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('had', Synset('induce.v.02')),
#  ('to', None),
#  ('battled', Synset('battle.v.01')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('embody.v.02')),
#  ('n’t', None),
#  ('too', Synset('besides.r.02')),
#  ('many', Synset('many.a.01')),
#  ('signs', Synset('sign_of_the_zodiac.n.01')),
#  ('of', None),
#  ('early', Synset('early.a.05')),
#  ('nerves', Synset('nerve.n.01')),
#  ('from', None),
#  ('the', None),
#  ('USMNT', None),
#  ('as', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('dictated', Synset('dictate.v.02')),
#  ('the', None),
#  ('play', Synset('gambling.n.01')),
#  ('in', None),
#  ('the', None),
#  ('opening', Synset('opening.n.05')),
#  ('stages', Synset('stage.n.08')),
#  ('–', None),
#  ('enjoying', Synset('love.v.02')),
#  ('65', None),
#  ('%', None),
#  ('of', None),
#  ('the', None),
#  ('possession', Synset('self-control.n.02')),
#  ('–', None),
#  ('though', None),
#  ('it', None),
#  ('took', Synset('take.v.20')),
#  ('until', None),
#  ('the', None),
#  ('28th', None),
#  ('minute', Synset('hour.n.04')),
#  ('for', None),
#  ('it', None),
#  ('conjure', Synset('raise.v.07')),
#  ('the', None),
#  ('first', Synset('first.a.06')),
#  ('chance', Synset('probability.n.01')),
#  ('of', None),
#  ('note', Synset('note.n.04')),
#  ('.', None),
#  ('\n\n', None),
#  ('Josh', None),
#  ('Sargeant', None),
#  ('’s', None),
#  ('long', Synset('long.a.05')),
#  ('-', None),
#  ('range', Synset('image.n.07')),
#  ('effort', Synset('campaign.n.02')),
#  ('took', Synset('take.v.34')),
#  ('a', None),
#  ('deflection', Synset('deflection.n.03')),
#  ('off', None),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('defender', Synset('defender.n.02')),
#  ('and', None),
#  ('fell', Synset('fall.v.03')),
#  ('perfectly', Synset('perfectly.r.02')),
#  ('into', None),
#  ('the', None),
#  ('path', Synset('way.n.05')),
#  ('of', None),
#  ('Timothy', Synset('timothy.n.02')),
#  ('Weah', None),
#  (',', None),
#  ('who', None),
#  ('perhaps', Synset('possibly.r.01')),
#  ('did', None),
#  ('n’t', None),
#  ('realize', Synset('realize.v.06')),
#  ('he', None),
#  ('was', None),
#  ('all', Synset('wholly.r.01')),
#  ('alone', None),
#  ('in', None),
#  ('front', Synset('movement.n.04')),
#  ('of', None),
#  ('goal', Synset('goal.n.01')),
#  ('and', None),
#  ('rushed', Synset('rush.v.05')),
#  ('a', None),
#  ('headed', Synset('headed.a.03')),
#  ('effort', Synset('campaign.n.02')),
#  ('that', None),
#  ('Alireza', None),
#  ('Beiranvand', None),
#  ('in', None),
#  ('the', None),
#  ('Iran', Synset('iran.n.01')),
#  ('goal', Synset('goal.n.01')),
#  ('caught', Synset('catch.v.18')),
#  ('with', None),
#  ('ease', Synset('relief.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('On', None),
#  ('the', None),
#  ('half', Synset('half.a.03')),
#  ('hour', Synset('hour.n.04')),
#  ('mark', Synset('mark.n.05')),
#  (',', None),
#  ('Weah', None),
#  ('once', Synset('once.r.03')),
#  ('again', Synset('again.r.01')),
#  ('took', Synset('take.v.34')),
#  ('up', None),
#  ('a', None),
#  ('brilliant', None),
#  ('position', Synset('status.n.01')),
#  ('inside', None),
#  ('the', None),
#  ('box', Synset('box.n.03')),
#  ('but', None),
#  ('skied', Synset('ski.v.01')),
#  ('his', None),
#  ('effort', Synset('feat.n.01')),
#  ('well', Synset('well.r.02')),
#  ('over', None),
#  ('the', None),
#  ('crossbar', Synset('crossbar.n.02')),
#  ('after', None),
#  ('being', None),
#  ('set', Synset('set.v.08')),
#  ('up', None),
#  ('by', None),
#  ('Sargeant', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('pressure', Synset('pressure.n.05')),
#  ('eventually', Synset('finally.r.01')),
#  ('told', Synset('tell.v.07')),
#  ('seven', None),
#  ('minutes', Synset('moment.n.02')),
#  ('before', None),
#  ('half', Synset('half.a.03')),
#  ('time', Synset('prison_term.n.01')),
#  (',', None),
#  ('taking', Synset('remove.v.01')),
#  ('the', None),
#  ('lead', Synset('spark_advance.n.01')),
#  ('following', Synset('watch.v.02')),
#  ('an', None),
#  ('incisive', None),
#  ('team', Synset('team.n.02')),
#  ('move', Synset('move.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('’s', None),
#  ('pinpoint', Synset('pinpoint.n.03')),
#  ('cross', Synset('cross.n.03')),
#  ('field', Synset('field.n.10')),
#  ('ball', Synset('ball.n.07')),
#  ('was', None),
#  ('headed', Synset('head.v.04')),
#  ('back', Synset('back.r.02')),
#  ('across', None),
#  ('goal', Synset('goal.n.03')),
#  ('by', None),
#  ('the', None),
#  ('marauding', Synset('maraud.v.01')),
#  ('Sergiño', None),
#  ('Dest', None),
#  ('and', None),
#  ('bundled', Synset('bundle.v.04')),
#  ('home', Synset('home_plate.n.01')),
#  ('bravely', Synset('bravely.r.01')),
#  ('by', None),
#  ('Pulisic', None),
#  (',', None),
#  ('who', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('a', None),
#  ('hefty', None),
#  ('collision', Synset('collision.n.03')),
#  ('with', None),
#  ('Beiranvand', None),
#  ('as', None),
#  ('he', None),
#  ('turned', Synset('plow.v.01')),
#  ('the', None),
#  ('ball', Synset('ball.n.07')),
#  ('over', None),
#  ('the', None),
#  ('line', Synset('wrinkle.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('delight', Synset('joy.n.02')),
#  ('swiftly', Synset('swiftly.r.01')),
#  ('turned', Synset('twist.v.10')),
#  ('to', None),
#  ('worry', Synset('worry.v.05')),
#  ('as', None),
#  ('it', None),
#  ('was', None),
#  ('evident', None),
#  ('that', None),
#  ('Pulisic', None),
#  ('was', None),
#  ('in', None),
#  ('significant', Synset('significant.a.03')),
#  ('pain', Synset('pain.n.02')),
#  ('following', Synset('take_after.v.02')),
#  ('the', None),
#  ('clash', Synset('clash.n.03')),
#  (',', None),
#  ('limping', Synset('limp.v.01')),
#  ('heavily', Synset('heavy.r.01')),
#  ('as', None),
#  ('he', None),
#  ('was', None),
#  ('helped', Synset('help.v.06')),
#  ('off', None),
#  ('the', None),
#  ('pitch', Synset('pitch.n.02')),
#  ('by', None),
#  ('two', None),
#  ('medics', Synset('medical_officer.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Pulisic', None),
#  ('soon', Synset('soon.r.01')),
#  ('re', None),
#  ('-', None),
#  ('entered', Synset('record.v.01')),
#  ('the', None),
#  ('pitch', Synset('pitch.n.01')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('Chelsea', None),
#  ('man', Synset('world.n.08')),
#  ('was', None),
#  ('clearly', Synset('distinctly.r.01')),
#  ('still', Synset('still.r.01')),
#  ('struggling', Synset('struggle.v.02')),
#  ('with', None),
#  ('the', None),
#  ('knock', Synset('knock.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('is', None),
#  ('surrounded', Synset('wall.v.01')),
#  ('by', None),
#  ('teammates', Synset('teammate.n.01')),
#  ('after', None),
#  ('going', Synset('move.v.13')),
#  ('down', Synset('down.r.06')),
#  ('injured', Synset('injure.v.01')),
#  ('following', Synset('follow.v.06')),
#  ('his', None),
#  ('goal', Synset('goal.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('As', None),
#  ('the', None),
#  ('USMNT', None),
#  ('grew', Synset('grow.v.10')),
#  ('in', None),
#  ('confidence', Synset('confidence.n.03')),
#  (',', None),
#  ('spaces', Synset('space.n.08')),
#  ('began', Synset('begin.v.08')),
#  ('to', None),
#  ('open', Synset('open.v.11')),
#  ('up', None),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('’s', None),
#  ('defense', Synset('department_of_defense.n.01')),
#  ('and', None),
#  ('Weah', None),
#  ('thought', Synset('think.v.03')),
#  ('he', None),
#  ('’d', None),
#  ('doubled', Synset('double_over.v.01')),
#  ('his', None),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('lead', Synset('spark_advance.n.01')),
#  ('just', Synset('merely.r.01')),
#  ('before', None),
#  ('the', None),
#  ('interval', Synset('time_interval.n.01')),
#  (',', None),
#  ('finishing', Synset('finish.v.06')),
#  ('wonderfully', Synset('wonderfully.r.01')),
#  ('with', None),
#  ('the', None),
#  ('outside', Synset('outside.n.01')),
#  ('of', None),
#  ('his', None),
#  ('boot', Synset('boot.n.06')),
#  ('only', Synset('only.r.04')),
#  ('to', None),
#  ('be', None),
#  ('met', Synset('meet.v.09')),
#  ('by', None),
#  ('the', None),
#  ('linesman', Synset('linesman.n.01')),
#  ('’s', None),
#  ('flag', Synset('masthead.n.01')),
#  ('for', None),
#  ('the', None),
#  ('narrowest', Synset('narrow.a.04')),
#  ('of', None),
#  ('offside', Synset('offside.a.01')),
#  ('decisions', Synset('decisiveness.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Though', None),
#  ('Iran', Synset('iran.n.01')),
#  ('would', None),
#  ('have', None),
#  ('been', None),
#  ('happy', Synset('happy.a.01')),
#  ('to', None),
#  ('weather', Synset('weather.v.04')),
#  ('that', None),
#  ('first', Synset('first.a.06')),
#  ('-', None),
#  ('half', Synset('one-half.n.01')),
#  ('storm', Synset('storm.n.01')),
#  (',', None),
#  ('it', None),
#  ('was', None),
#  ('a', None),
#  ('surprisingly', Synset('surprisingly.r.01')),
#  ('subdued', None),
#  ('performance', Synset('performance.n.03')),
#  ('–', None),
#  ('in', None),
#  ('particular', None),
#  ('following', Synset('take_after.v.02')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('goal', Synset('goal.n.01')),
#  ('–', None),
#  ('from', None),
#  ('a', None),
#  ('team', Synset('team.n.02')),
#  ('that', None),
#  ('had', None),
#  ('caused', Synset('induce.v.02')),
#  ('both', None),
#  ('England', Synset('england.n.01')),
#  ('and', None),
#  ('Wales', Synset('wales.n.01')),
#  ('defensive', Synset('defensive.a.01')),
#  ('problems', Synset('problem.n.01')),
#  ('in', None),
#  ('its', None),
#  ('opening', Synset('opening.n.04')),
#  ('two', None),
#  ('matches', Synset('match.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('Iran', Synset('iran.n.01')),
#  ('did', None),
#  ('begin', Synset('begin.v.10')),
#  ('the', None),
#  ('second', Synset('second.a.02')),
#  ('half', Synset('half.n.02')),
#  ('with', None),
#  ('more', Synset('more.a.02')),
#  ('authority', Synset('authority.n.01')),
#  (',', None),
#  ('creating', Synset('make.v.03')),
#  ('two', None),
#  ('brilliant', None),
#  ('chances', Synset('probability.n.01')),
#  ('for', None),
#  ('Saman', Synset('rain_tree.n.01')),
#  ('Ghoddos', None),
#  ('but', None),
#  ('the', None),
#  ('Brentford', None),
#  ('forward', Synset('forward.r.01')),
#  ('was', None),
#  ('unable', Synset('unable.a.01')),
#  ('to', None),
#  ('trouble', Synset('trouble_oneself.v.01')),
#  ('USMNT', None),
#  ('goalkeeper', Synset('goalkeeper.n.02')),
#  ('Matt', Synset('flatness.n.04')),
#  ('Turner', Synset('turner.n.07')),
#  ('.', None),
#  ('\n\n', None),
#  ('With', None),
#  ('the', None),
#  ('clock', Synset('clock.n.01')),
#  ('ticking', Synset('tick.v.02')),
#  ('down', None),
#  (',', None),
#  ('Iran', Synset('iran.n.01')),
#  ('had', Synset('induce.v.02')),
#  ('a', None),
#  ('glorious', Synset('glorious.a.01')),
#  ('chance', Synset('probability.n.01')),
#  ('to', None),
#  ('level', Synset('level.v.02')),
#  ('the', None),
#  ('score', Synset('score.n.10')),
#  ('but', None),
#  ('Morteza', None),
#  ('Pouraliganji', None),
#  ('’s', None),
#  ('stooping', Synset('crouch.v.01')),
#  ('header', Synset('header.n.04')),
#  ('flashed', Synset('flash.v.08')),
#  ('narrowly', Synset('narrowly.r.01')),
#  ('wide', Synset('wide.a.01')),
#  ('of', None),
#  ('the', None),
#  ('far', Synset('far.a.01')),
#  ('post', Synset('post.n.09')),
#  ('much', Synset('much.a.01')),
#  ('to', None),
#  ('the', None),
#  ('relief', Synset('relief.n.10')),
#  ('of', None),
#  ('the', None),
#  ('American', Synset('american.a.02')),
#  ('fans', Synset('fan.n.01')),
#  ('in', None),
#  ('the', None),
#  ('stands', Synset('stand.n.10')),
#  (',', None),
#  ('many', Synset('many.a.01')),
#  ('who', None),
#  ('had', Synset('induce.v.02')),
#  ('their', None),
#  ('heads', Synset('head.n.25')),
#  ('in', None),
#  ('their', None),
#  ('hands', Synset('hand.n.09')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('embody.v.02')),
#  ('loud', Synset('forte.a.01')),
#  ('calls', Synset('margin_call.n.01')),
#  ('for', None),
#  ('a', None),
#  ('penalty', Synset('penalty.n.04')),
#  ('from', None),
#  ('the', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('players', Synset('player.n.05')),
#  ('late', Synset('recently.r.01')),
#  ('on', Synset('on.r.03')),
#  ('in', None),
#  ('the', None),
#  ('nine', None),
#  ('minutes', Synset('minute.n.01')),
#  ('of', None),
#  ('added', Synset('add.v.01')),
#  ('time', Synset('time.n.05')),
#  (',', None),
#  ('with', None),
#  ('Mehdi', None),
#  ('Taremi', None),
#  ('insisting', Synset('insist.v.03')),
#  ('that', None),
#  ('Cameron', None),
#  ('Carter', Synset('carter.n.01')),
#  ('-', None),
#  ('Vickers', None),
#  ('had', None),
#  ('pulled', Synset('pull.v.11')),
#  ('down', None),
#  ('the', None),
#  ('Porto', Synset('porto.n.01')),
#  ('forward', Synset('ahead.r.02')),
#  ('down', Synset('down.r.03')),
#  ('as', None),
#  ('he', None),
#  ('attempted', Synset('undertake.v.01')),
#  ('to', None),
#  ('get', Synset('induce.v.02')),
#  ('on', None),
#  ('the', None),
#  ('end', Synset('goal.n.01')),
#  ('of', None),
#  ('a', None),
#  ('cross', Synset('cross.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('USA', Synset('united_states_army.n.01')),
#  ('players', Synset('player.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('at', None),
#  ('the', None),
#  ...]

# %% [markdown]
# [Q11] Pour tous les mots d'un texte, trouver le sens de chacun d'eux dans wordnet en utilisant l'ensemble du document pour désambiguiser le sens? Quels sont vos commentaires par rapport à une désambiguisation basée sur la phrase uniquement.

# %%
# insérer votre code ici
context = [token.text for token in doc if not token.is_punct]
sens = []
for token in doc:
    res = lesk(context, token.lemma_, pos=pos_to_wn.get(token.pos_, 'NOUN'))
    sens.append((token.text, res))
sens

#La désambiguïsation basée sur la phrase uniquement peut être insuffisante pour résoudre les ambiguïtés de sens,
#car elle ne prend pas en compte les informations contextuelles plus larges telles que la connaissance du monde et les relations sémantiques entre les mots
# Out:
# [('The', None),
#  ('US', Synset('uracil.n.01')),
#  ('Men', Synset('man.n.08')),
#  ('’s', None),
#  ('National', Synset('national.n.01')),
#  ('Team', Synset('team.n.02')),
#  ('(', None),
#  ('USMNT', None),
#  (')', None),
#  ('was', None),
#  ('made', Synset('make.v.42')),
#  ('to', None),
#  ('work', Synset('work.v.09')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('knockout', Synset('smasher.n.02')),
#  ('stage', Synset('stage.n.03')),
#  (',', None),
#  ('earning', Synset('gain.v.08')),
#  ('a', None),
#  ('tough', Synset('tough.a.01')),
#  ('1', None),
#  ('-', None),
#  ('0', None),
#  ('win', Synset('win.n.01')),
#  ('over', None),
#  ('Iran', Synset('iran.n.01')),
#  ('in', None),
#  ('a', None),
#  ('nerve', Synset('nerve.n.01')),
#  ('-', None),
#  ('racking', Synset('rack.v.10')),
#  ('Group', Synset('group.n.03')),
#  ('B', Synset('barn.n.02')),
#  ('decider', None),
#  ('at', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('2022', None),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('first', Synset('first.a.01')),
#  ('-', None),
#  ('half', Synset('half.n.02')),
#  ('goal', Synset('goal.n.03')),
#  ('was', None),
#  ('all', None),
#  ('that', None),
#  ('separated', Synset('branch.v.02')),
#  ('the', None),
#  ('two', None),
#  ('sides', Synset('english.n.04')),
#  ('as', None),
#  ('the', None),
#  ('USMNT', None),
#  ('reached', Synset('reach.v.03')),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('for', None),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('time', Synset('time.n.05')),
#  ('since', None),
#  ('2014', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('pressure', Synset('pressure.n.05')),
#  ('was', None),
#  ('certainly', Synset('surely.r.01')),
#  ('on', None),
#  ('for', None),
#  ('Gregg', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('after', None),
#  ('the', None),
#  ('national', Synset('national.a.02')),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('failure', Synset('failure.n.04')),
#  ('to', None),
#  ('qualify', Synset('stipulate.v.01')),
#  ('for', None),
#  ('the', None),
#  ('2018', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  ('got', Synset('get.v.14')),
#  ('the', None),
#  ('job', Synset('job.n.02')),
#  ('done', Synset('serve.v.09')),
#  ('with', None),
#  ('three', None),
#  ('gritty', None),
#  ('group', Synset('group.n.03')),
#  ('performances', Synset('performance.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('It', None),
#  ('certainly', Synset('surely.r.01')),
#  ('was', None),
#  ('n’t', None),
#  ('pretty', None),
#  ('at', None),
#  ('times', Synset('time.n.05')),
#  (',', None),
#  ('in', None),
#  ('particular', None),
#  ('in', None),
#  ('the', None),
#  ('closing', Synset('close.v.10')),
#  ('stages', Synset('stage.n.03')),
#  ('against', None),
#  ('Iran', Synset('iran.n.01')),
#  (',', None),
#  ('but', None),
#  ('progressing', Synset('advance.v.01')),
#  ('through', None),
#  ('the', None),
#  ('group', Synset('group.n.03')),
#  ('stage', Synset('stage.n.03')),
#  ('was', None),
#  ('the', None),
#  ('minimum', Synset('minimal.a.01')),
#  ('expectation', Synset('expectation.n.03')),
#  ('for', None),
#  ('this', None),
#  ('exciting', Synset('exciting.a.01')),
#  ('young', Synset('young.a.01')),
#  ('team', Synset('team.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('will', None),
#  ('be', None),
#  ('some', None),
#  ('concerns', Synset('business.n.01')),
#  ('going', Synset('go.v.03')),
#  ('into', None),
#  ('the', None),
#  ('knockout', Synset('smasher.n.02')),
#  ('stages', Synset('stage.n.03')),
#  (',', None),
#  ('though', Synset('though.r.01')),
#  (',', None),
#  ('after', None),
#  ('Pulisic', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('an', None),
#  ('abdominal', Synset('abdominal.a.01')),
#  ('injury', Synset('injury.n.01')),
#  ('while', None),
#  ('scoring', Synset('score.v.06')),
#  ('the', None),
#  ('winner', Synset('achiever.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('will', None),
#  ('be', None),
#  ('hoping', Synset('hope.v.03')),
#  ('its', None),
#  ('star', Synset('star.n.05')),
#  ('man', Synset('man.n.08')),
#  (',', None),
#  ('dubbed', Synset('dub.v.02')),
#  ('‘', None),
#  ('Captain', Synset('captain.n.07')),
#  ('America', Synset('united_states.n.01')),
#  ('’', None),
#  ('by', None),
#  ('some', None),
#  (',', None),
#  ('is', None),
#  ('fit', Synset('fit.a.01')),
#  ('for', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('tie', Synset('tie.n.07')),
#  ('against', None),
#  ('the', None),
#  ('Netherlands', Synset('netherlands.n.01')),
#  ('on', None),
#  ('Saturday', Synset('saturday.n.01')),
#  ('following', Synset('follow.v.10')),
#  ('the', None),
#  ('news', Synset('newsworthiness.n.01')),
#  ('that', None),
#  ('Pulisic', None),
#  ('had', None),
#  ('been', None),
#  ('sent', Synset('commit.v.03')),
#  ('to', None),
#  ('hospital', Synset('hospital.n.02')),
#  ('for', None),
#  ('a', None),
#  ('scan', Synset('scan.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('and', None),
#  ('Tyler', Synset('tyler.n.01')),
#  ('Adams', Synset('adam.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('the', None),
#  ('opening', Synset('opening.n.12')),
#  ('goal', Synset('goal.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('Winner', Synset('achiever.n.01')),
#  ('takes', Synset('take.v.34')),
#  ('all', None),
#  ('\n\n', None),
#  ('This', None),
#  ('was', None),
#  ('the', None),
#  ('only', None),
#  ('the', None),
#  ('third', None),
#  ('meeting', Synset('meeting.n.04')),
#  ('ever', Synset('always.r.01')),
#  ('between', None),
#  ('the', None),
#  ('two', None),
#  ('nations', Synset('nation.n.03')),
#  ('and', None),
#  ('their', None),
#  ('first', Synset('first.a.01')),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('encounter', Synset('encounter.n.03')),
#  ('since', None),
#  ('France', Synset('france.n.01')),
#  ('1998', None),
#  ('–', None),
#  ('a', None),
#  ('politically', Synset('politically.r.01')),
#  ('charged', Synset('charge.v.24')),
#  ('match', Synset('peer.n.01')),
#  ('that', None),
#  ('saw', Synset('visit.v.01')),
#  ('Iran', Synset('iran.n.01')),
#  ('emerge', Synset('emerge.v.04')),
#  ('as', None),
#  ('a', None),
#  ('shock', Synset('shock.n.07')),
#  ('2', None),
#  ('-', None),
#  ('1', None),
#  ('winner', Synset('achiever.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('That', None),
#  ('was', None),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('time', Synset('time.n.05')),
#  ('that', None),
#  ('Iran', Synset('iran.n.01')),
#  ('and', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  (',', None),
#  ('sometimes', Synset('sometimes.r.01')),
#  ('described', Synset('report.v.01')),
#  ('officially', Synset('officially.r.01')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('as', None),
#  ('the', None),
#  ('‘', None),
#  ('Great', Synset('great.n.01')),
#  ('Satan', Synset('satan.n.01')),
#  (',', None),
#  ('’', None),
#  ('had', None),
#  ('met', Synset('meet.v.09')),
#  ('on', None),
#  ('the', None),
#  ('football', Synset('football.n.01')),
#  ('pitch', Synset('pitch.n.08')),
#  ('and', None),
#  ('the', None),
#  ('biggest', Synset('large.a.01')),
#  ('sporting', None),
#  ('occasion', Synset('occasion.n.04')),
#  ('between', None),
#  ('the', None),
#  ('countries', Synset('area.n.01')),
#  ('since', None),
#  ('the', None),
#  ('1979', None),
#  ('revolution', Synset('revolution.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('build', Synset('human_body.n.01')),
#  ('-', None),
#  ('up', None),
#  ('to', None),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('in', None),
#  ('Qatar', Synset('qatar.n.01')),
#  ('has', None),
#  ('been', None),
#  ('similarly', Synset('similarly.r.01')),
#  ('tense', Synset('tense.a.02')),
#  (',', None),
#  ('with', None),
#  ('Iran', Synset('iran.n.01')),
#  ('even', Synset('even.r.03')),
#  ('calling', Synset('call.v.20')),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('to', None),
#  ('be', None),
#  ('expelled', Synset('oust.v.01')),
#  ('from', None),
#  ('the', None),
#  ('World', Synset('worldly_concern.n.01')),
#  ('Cup', Synset('cup.n.08')),
#  ('after', None),
#  ('the', None),
#  ('US', Synset('uracil.n.01')),
#  ('Soccer', Synset('soccer.n.01')),
#  ('Federation', Synset('federation.n.03')),
#  ('posted', Synset('post.v.08')),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('flag', Synset('masthead.n.01')),
#  ('without', None),
#  ('the', None),
#  ('emblem', Synset('emblem.n.02')),
#  ('of', None),
#  ('the', None),
#  ('Islamic', None),
#  ('Republic', Synset('democracy.n.02')),
#  ('on', None),
#  ('its', None),
#  ('social', Synset('social.a.01')),
#  ('media', Synset('medium.n.09')),
#  ('platforms', Synset('platform.n.03')),
#  ('to', None),
#  ('show', Synset('prove.v.02')),
#  ('support', Synset('support.n.04')),
#  ('for', None),
#  ('protesters', Synset('demonstrator.n.03')),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('USMNT', None),
#  ('manager', Synset('coach.n.01')),
#  ('Berhalter', None),
#  ('and', None),
#  ('captain', Synset('captain.n.07')),
#  ('Tyler', Synset('tyler.n.01')),
#  ('Adams', Synset('adam.n.01')),
#  ('also', Synset('besides.r.02')),
#  ('faced', Synset('front.v.01')),
#  ('some', None),
#  ('tough', Synset('tough.a.01')),
#  ('questions', Synset('motion.n.05')),
#  ('from', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('journalists', Synset('journalist.n.01')),
#  ('in', None),
#  ('a', None),
#  ('fiery', None),
#  ('press', Synset('press.n.02')),
#  ('conference', Synset('league.n.01')),
#  (',', None),
#  ('fending', Synset('resist.v.04')),
#  ('off', None),
#  ('accusations', Synset('accusation.n.02')),
#  ('of', None),
#  ('hypocrisy', Synset('hypocrisy.n.02')),
#  ('and', None),
#  ('disrespect', Synset('contempt.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('furore', Synset('furor.n.02')),
#  ('surrounding', Synset('wall.v.01')),
#  ('this', None),
#  ('game', Synset('game.n.09')),
#  ('only', Synset('only.r.04')),
#  ('added', Synset('add.v.01')),
#  ('to', None),
#  ('the', None),
#  ('drama', Synset('play.n.01')),
#  ('of', None),
#  ('a', None),
#  ('matchup', Synset('match-up.n.01')),
#  ('that', None),
#  ('–', None),
#  ('even', Synset('even.r.03')),
#  ('in', None),
#  ('a', None),
#  ('vacuum', Synset('vacuum.n.04')),
#  ('away', Synset('away.r.01')),
#  ('from', None),
#  ('off', Synset('off.a.01')),
#  ('-', None),
#  ('field', Synset('field.n.10')),
#  ('issues', Synset('consequence.n.01')),
#  ('–', None),
#  ('was', None),
#  ('guaranteed', Synset('guarantee.v.04')),
#  ('to', None),
#  ('be', None),
#  ('fraught', None),
#  ('with', None),
#  ('tension', Synset('tension.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('Both', None),
#  ('teams', Synset('team.n.02')),
#  ('knew', Synset('know.v.03')),
#  ('a', None),
#  ('win', Synset('win.n.01')),
#  ('would', None),
#  ('secure', Synset('plug.v.01')),
#  ('a', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  (',', None),
#  ('but', None),
#  ('for', None),
#  ('the', None),
#  ('USMNT', None),
#  ('even', Synset('even.r.03')),
#  ('a', None),
#  ('draw', Synset('draw.n.07')),
#  ('would', None),
#  ('not', None),
#  ('be', None),
#  ('enough', None),
#  ('to', None),
#  ('see', Synset('visit.v.01')),
#  ('it', None),
#  ('progress', Synset('advance.v.01')),
#  ('from', None),
#  ('the', None),
#  ('group', Synset('group.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('had', Synset('get.v.03')),
#  ('to', None),
#  ('battled', Synset('battle.v.01')),
#  ('hard', Synset('hard.r.10')),
#  ('for', None),
#  ('its', None),
#  ('place', Synset('topographic_point.n.01')),
#  ('in', None),
#  ('the', None),
#  ('round', Synset('round.n.11')),
#  ('of', None),
#  ('16', None),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('be.v.01')),
#  ('n’t', None),
#  ('too', Synset('excessively.r.01')),
#  ('many', Synset('many.a.01')),
#  ('signs', Synset('signboard.n.01')),
#  ('of', None),
#  ('early', Synset('early.a.05')),
#  ('nerves', Synset('nerve.n.01')),
#  ('from', None),
#  ('the', None),
#  ('USMNT', None),
#  ('as', None),
#  ('Berhalter', None),
#  ('’s', None),
#  ('side', Synset('english.n.04')),
#  ('dictated', Synset('dictate.v.02')),
#  ('the', None),
#  ('play', Synset('gambling.n.01')),
#  ('in', None),
#  ('the', None),
#  ('opening', Synset('opening.n.12')),
#  ('stages', Synset('stage.n.03')),
#  ('–', None),
#  ('enjoying', Synset('love.v.02')),
#  ('65', None),
#  ('%', None),
#  ('of', None),
#  ('the', None),
#  ('possession', Synset('possession.n.05')),
#  ('–', None),
#  ('though', None),
#  ('it', None),
#  ('took', Synset('take.v.34')),
#  ('until', None),
#  ('the', None),
#  ('28th', None),
#  ('minute', Synset('minute.n.01')),
#  ('for', None),
#  ('it', None),
#  ('conjure', Synset('raise.v.07')),
#  ('the', None),
#  ('first', Synset('first.a.01')),
#  ('chance', Synset('probability.n.01')),
#  ('of', None),
#  ('note', Synset('note.n.09')),
#  ('.', None),
#  ('\n\n', None),
#  ('Josh', None),
#  ('Sargeant', None),
#  ('’s', None),
#  ('long', Synset('long.a.01')),
#  ('-', None),
#  ('range', Synset('image.n.07')),
#  ('effort', Synset('campaign.n.02')),
#  ('took', Synset('take.v.34')),
#  ('a', None),
#  ('deflection', Synset('deflection.n.03')),
#  ('off', None),
#  ('an', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('defender', Synset('defender.n.02')),
#  ('and', None),
#  ('fell', Synset('descend.v.01')),
#  ('perfectly', Synset('absolutely.r.01')),
#  ('into', None),
#  ('the', None),
#  ('path', Synset('path.n.03')),
#  ('of', None),
#  ('Timothy', Synset('timothy.n.02')),
#  ('Weah', None),
#  (',', None),
#  ('who', None),
#  ('perhaps', Synset('possibly.r.01')),
#  ('did', None),
#  ('n’t', None),
#  ('realize', Synset('realize.v.06')),
#  ('he', None),
#  ('was', None),
#  ('all', Synset('wholly.r.01')),
#  ('alone', None),
#  ('in', None),
#  ('front', Synset('movement.n.04')),
#  ('of', None),
#  ('goal', Synset('goal.n.03')),
#  ('and', None),
#  ('rushed', Synset('rush.v.05')),
#  ('a', None),
#  ('headed', Synset('headed.a.03')),
#  ('effort', Synset('campaign.n.02')),
#  ('that', None),
#  ('Alireza', None),
#  ('Beiranvand', None),
#  ('in', None),
#  ('the', None),
#  ('Iran', Synset('iran.n.01')),
#  ('goal', Synset('goal.n.03')),
#  ('caught', Synset('get.v.19')),
#  ('with', None),
#  ('ease', Synset('relief.n.02')),
#  ('.', None),
#  ('\n\n', None),
#  ('On', None),
#  ('the', None),
#  ('half', Synset('half.a.03')),
#  ('hour', Synset('hour.n.04')),
#  ('mark', Synset('mark.n.08')),
#  (',', None),
#  ('Weah', None),
#  ('once', Synset('once.r.03')),
#  ('again', Synset('again.r.01')),
#  ('took', Synset('take.v.34')),
#  ('up', None),
#  ('a', None),
#  ('brilliant', None),
#  ('position', Synset('position.n.07')),
#  ('inside', None),
#  ('the', None),
#  ('box', Synset('box.n.07')),
#  ('but', None),
#  ('skied', Synset('ski.v.01')),
#  ('his', None),
#  ('effort', Synset('campaign.n.02')),
#  ('well', Synset('well.r.01')),
#  ('over', None),
#  ('the', None),
#  ('crossbar', Synset('crossbar.n.02')),
#  ('after', None),
#  ('being', None),
#  ('set', Synset('set.v.16')),
#  ('up', None),
#  ('by', None),
#  ('Sargeant', None),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('pressure', Synset('pressure.n.05')),
#  ('eventually', Synset('finally.r.01')),
#  ('told', Synset('order.v.01')),
#  ('seven', None),
#  ('minutes', Synset('minute.n.01')),
#  ('before', None),
#  ('half', Synset('half.a.03')),
#  ('time', Synset('time.n.05')),
#  (',', None),
#  ('taking', Synset('take.v.34')),
#  ('the', None),
#  ('lead', Synset('lead.n.05')),
#  ('following', Synset('follow.v.10')),
#  ('an', None),
#  ('incisive', None),
#  ('team', Synset('team.n.02')),
#  ('move', Synset('move.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('Weston', Synset('weston.n.01')),
#  ('McKennie', None),
#  ('’s', None),
#  ('pinpoint', Synset('pinpoint.n.03')),
#  ('cross', Synset('cross.n.03')),
#  ('field', Synset('field.n.10')),
#  ('ball', Synset('ball.n.12')),
#  ('was', None),
#  ('headed', Synset('head.v.07')),
#  ('back', Synset('back.r.04')),
#  ('across', None),
#  ('goal', Synset('goal.n.03')),
#  ('by', None),
#  ('the', None),
#  ('marauding', Synset('maraud.v.01')),
#  ('Sergiño', None),
#  ('Dest', None),
#  ('and', None),
#  ('bundled', Synset('bundle.v.04')),
#  ('home', Synset('home_plate.n.01')),
#  ('bravely', Synset('bravely.r.01')),
#  ('by', None),
#  ('Pulisic', None),
#  (',', None),
#  ('who', None),
#  ('suffered', Synset('suffer.v.11')),
#  ('a', None),
#  ('hefty', None),
#  ('collision', Synset('collision.n.01')),
#  ('with', None),
#  ('Beiranvand', None),
#  ('as', None),
#  ('he', None),
#  ('turned', Synset('turn.v.10')),
#  ('the', None),
#  ('ball', Synset('ball.n.12')),
#  ('over', None),
#  ('the', None),
#  ('line', Synset('production_line.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('The', None),
#  ('USMNT', None),
#  ('’s', None),
#  ('delight', Synset('joy.n.02')),
#  ('swiftly', Synset('swiftly.r.01')),
#  ('turned', Synset('turn.v.10')),
#  ('to', None),
#  ('worry', Synset('concern.v.02')),
#  ('as', None),
#  ('it', None),
#  ('was', None),
#  ('evident', None),
#  ('that', None),
#  ('Pulisic', None),
#  ('was', None),
#  ('in', None),
#  ('significant', Synset('significant.a.03')),
#  ('pain', Synset('pain.n.02')),
#  ('following', Synset('follow.v.10')),
#  ('the', None),
#  ('clash', Synset('clash.n.03')),
#  (',', None),
#  ('limping', Synset('limp.v.01')),
#  ('heavily', Synset('heavy.r.01')),
#  ('as', None),
#  ('he', None),
#  ('was', None),
#  ('helped', Synset('serve.v.05')),
#  ('off', None),
#  ('the', None),
#  ('pitch', Synset('pitch.n.08')),
#  ('by', None),
#  ('two', None),
#  ('medics', Synset('medic.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Pulisic', None),
#  ('soon', Synset('soon.r.01')),
#  ('re', None),
#  ('-', None),
#  ('entered', Synset('figure.v.02')),
#  ('the', None),
#  ('pitch', Synset('pitch.n.08')),
#  (',', None),
#  ('but', None),
#  ('the', None),
#  ('Chelsea', None),
#  ('man', Synset('man.n.08')),
#  ('was', None),
#  ('clearly', Synset('distinctly.r.01')),
#  ('still', Synset('however.r.01')),
#  ('struggling', Synset('contend.v.06')),
#  ('with', None),
#  ('the', None),
#  ('knock', Synset('knock.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Christian', Synset('christian.n.01')),
#  ('Pulisic', None),
#  ('is', None),
#  ('surrounded', Synset('wall.v.01')),
#  ('by', None),
#  ('teammates', Synset('teammate.n.01')),
#  ('after', None),
#  ('going', Synset('go.v.03')),
#  ('down', Synset('down.r.02')),
#  ('injured', Synset('hurt.v.05')),
#  ('following', Synset('follow.v.10')),
#  ('his', None),
#  ('goal', Synset('goal.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('As', None),
#  ('the', None),
#  ('USMNT', None),
#  ('grew', Synset('grow.v.10')),
#  ('in', None),
#  ('confidence', Synset('confidence.n.03')),
#  (',', None),
#  ('spaces', Synset('quad.n.03')),
#  ('began', Synset('begin.v.08')),
#  ('to', None),
#  ('open', Synset('open.v.11')),
#  ('up', None),
#  ('in', None),
#  ('Iran', Synset('iran.n.01')),
#  ('’s', None),
#  ('defense', Synset('defense.n.03')),
#  ('and', None),
#  ('Weah', None),
#  ('thought', Synset('think.v.03')),
#  ('he', None),
#  ('’d', None),
#  ('doubled', Synset('double_over.v.01')),
#  ('his', None),
#  ('team', Synset('team.n.02')),
#  ('’s', None),
#  ('lead', Synset('lead.n.05')),
#  ('just', Synset('just.r.06')),
#  ('before', None),
#  ('the', None),
#  ('interval', Synset('time_interval.n.01')),
#  (',', None),
#  ('finishing', Synset('end.v.01')),
#  ('wonderfully', Synset('wonderfully.r.01')),
#  ('with', None),
#  ('the', None),
#  ('outside', Synset('outside.n.01')),
#  ('of', None),
#  ('his', None),
#  ('boot', Synset('boot.n.05')),
#  ('only', Synset('only.r.04')),
#  ('to', None),
#  ('be', None),
#  ('met', Synset('meet.v.09')),
#  ('by', None),
#  ('the', None),
#  ('linesman', Synset('linesman.n.01')),
#  ('’s', None),
#  ('flag', Synset('masthead.n.01')),
#  ('for', None),
#  ('the', None),
#  ('narrowest', Synset('narrow.a.04')),
#  ('of', None),
#  ('offside', Synset('offside.a.01')),
#  ('decisions', Synset('decisiveness.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Though', None),
#  ('Iran', Synset('iran.n.01')),
#  ('would', None),
#  ('have', None),
#  ('been', None),
#  ('happy', Synset('happy.a.01')),
#  ('to', None),
#  ('weather', Synset('weather.v.04')),
#  ('that', None),
#  ('first', Synset('first.a.01')),
#  ('-', None),
#  ('half', Synset('half.n.02')),
#  ('storm', Synset('storm.n.01')),
#  (',', None),
#  ('it', None),
#  ('was', None),
#  ('a', None),
#  ('surprisingly', Synset('amazingly.r.01')),
#  ('subdued', None),
#  ('performance', Synset('performance.n.03')),
#  ('–', None),
#  ('in', None),
#  ('particular', None),
#  ('following', Synset('follow.v.10')),
#  ('Pulisic', None),
#  ('’s', None),
#  ('goal', Synset('goal.n.03')),
#  ('–', None),
#  ('from', None),
#  ('a', None),
#  ('team', Synset('team.n.02')),
#  ('that', None),
#  ('had', None),
#  ('caused', Synset('induce.v.02')),
#  ('both', None),
#  ('England', Synset('england.n.01')),
#  ('and', None),
#  ('Wales', Synset('wales.n.01')),
#  ('defensive', Synset('defensive.a.01')),
#  ('problems', Synset('problem.n.01')),
#  ('in', None),
#  ('its', None),
#  ('opening', Synset('opening.n.12')),
#  ('two', None),
#  ('matches', Synset('peer.n.01')),
#  ('.', None),
#  ('\n\n', None),
#  ('Iran', Synset('iran.n.01')),
#  ('did', None),
#  ('begin', Synset('begin.v.08')),
#  ('the', None),
#  ('second', Synset('second.a.02')),
#  ('half', Synset('half.n.02')),
#  ('with', None),
#  ('more', Synset('more.a.01')),
#  ('authority', Synset('authority.n.01')),
#  (',', None),
#  ('creating', Synset('create.v.03')),
#  ('two', None),
#  ('brilliant', None),
#  ('chances', Synset('probability.n.01')),
#  ('for', None),
#  ('Saman', Synset('rain_tree.n.01')),
#  ('Ghoddos', None),
#  ('but', None),
#  ('the', None),
#  ('Brentford', None),
#  ('forward', Synset('forward.r.01')),
#  ('was', None),
#  ('unable', Synset('unable.a.01')),
#  ('to', None),
#  ('trouble', Synset('trouble_oneself.v.01')),
#  ('USMNT', None),
#  ('goalkeeper', Synset('goalkeeper.n.02')),
#  ('Matt', Synset('flatness.n.04')),
#  ('Turner', Synset('turner.n.07')),
#  ('.', None),
#  ('\n\n', None),
#  ('With', None),
#  ('the', None),
#  ('clock', Synset('clock.n.01')),
#  ('ticking', Synset('check.v.06')),
#  ('down', None),
#  (',', None),
#  ('Iran', Synset('iran.n.01')),
#  ('had', Synset('get.v.03')),
#  ('a', None),
#  ('glorious', Synset('glorious.a.01')),
#  ('chance', Synset('probability.n.01')),
#  ('to', None),
#  ('level', Synset('level.v.02')),
#  ('the', None),
#  ('score', Synset('score.n.03')),
#  ('but', None),
#  ('Morteza', None),
#  ('Pouraliganji', None),
#  ('’s', None),
#  ('stooping', Synset('crouch.v.01')),
#  ('header', Synset('heading.n.01')),
#  ('flashed', Synset('flash.v.07')),
#  ('narrowly', Synset('narrowly.r.01')),
#  ('wide', Synset('wide.a.01')),
#  ('of', None),
#  ('the', None),
#  ('far', Synset('far.a.01')),
#  ('post', Synset('post.n.09')),
#  ('much', Synset('much.a.01')),
#  ('to', None),
#  ('the', None),
#  ('relief', Synset('relief.n.10')),
#  ('of', None),
#  ('the', None),
#  ('American', Synset('american.a.01')),
#  ('fans', Synset('fan.n.01')),
#  ('in', None),
#  ('the', None),
#  ('stands', Synset('stand.n.10')),
#  (',', None),
#  ('many', Synset('many.a.01')),
#  ('who', None),
#  ('had', Synset('get.v.03')),
#  ('their', None),
#  ('heads', Synset('heading.n.01')),
#  ('in', None),
#  ('their', None),
#  ('hands', Synset('hand.n.05')),
#  ('.', None),
#  ('\n\n', None),
#  ('There', None),
#  ('were', Synset('be.v.01')),
#  ('loud', Synset('forte.a.01')),
#  ('calls', Synset('margin_call.n.01')),
#  ('for', None),
#  ('a', None),
#  ('penalty', Synset('penalty.n.04')),
#  ('from', None),
#  ('the', None),
#  ('Iranian', Synset('iranian.a.01')),
#  ('players', Synset('player.n.01')),
#  ('late', Synset('late.r.03')),
#  ('on', Synset('on.r.03')),
#  ('in', None),
#  ('the', None),
#  ('nine', None),
#  ('minutes', Synset('minute.n.01')),
#  ('of', None),
#  ('added', Synset('add.v.01')),
#  ('time', Synset('time.n.05')),
#  (',', None),
#  ('with', None),
#  ('Mehdi', None),
#  ('Taremi', None),
#  ('insisting', Synset('insist.v.01')),
#  ('that', None),
#  ('Cameron', None),
#  ('Carter', Synset('carter.n.01')),
#  ('-', None),
#  ('Vickers', None),
#  ('had', None),
#  ('pulled', Synset('pull.v.09')),
#  ('down', None),
#  ('the', None),
#  ('Porto', Synset('porto.n.01')),
#  ('forward', Synset('forward.r.01')),
#  ('down', Synset('down.r.02')),
#  ('as', None),
#  ('he', None),
#  ('attempted', Synset('try.v.01')),
#  ('to', None),
#  ('get', Synset('get.v.14')),
#  ('on', None),
#  ('the', None),
#  ('end', Synset('end.n.13')),
#  ('of', None),
#  ('a', None),
#  ('cross', Synset('cross.n.03')),
#  ('.', None),
#  ('\n\n', None),
#  ('USA', Synset('united_states_army.n.01')),
#  ('players', Synset('player.n.01')),
#  ('celebrate', Synset('observe.v.06')),
#  ('at', None),
#  ('the', None),
#  ...]

# %% [markdown]
# 7 - PROJET : Réécrire un texte avec des informations retirées de wordnet
# -----

# %% [markdown]
# [PROJET Q1] Réécrire un texte en interchangeant un mot par son antonyme. Par exemple, "petit" devient "grand" et "laideur" devient "beauté". Vous pourrez utiliser la fonction highligth_word() pour mettre en avant les mots qui ont été changés.

# %%
def highlight_word(word):
    # Il faut aussi vérifier si word est ""
    return "\x1b[43m" + (word if word else "") + "\x1b[m"

# %%
for word in doc:
    # Recherche de synsets pour le mot donné
    synsets = wn.synsets(word.text)
    
    if synsets and len(synsets) > 1:
        second_synset = synsets[1]
        antonyme = None
        if second_synset.lemmas():
            antonyme = second_synset.lemmas()[0].antonyms()[0].name() if second_synset.lemmas()[0].antonyms() else None
        if antonyme:
            print(f"highlight_word({antonyme}) {word.text}")
        else:
            print(f"{word.text}")
    else:
        print(f"{word.text}")
# Out:
# The
# US
# highlight_word(woman) Men
# ’s
# National
# Team
# (
# USMNT
# )
# was
# made
# to
# work
# highlight_word(soft) hard
# for
# its
# place
# in
# the
# World
# Cup
# knockout
# stage
# ,
# earning
# a
# tough
# 1
# -
# 0
# highlight_word(losings) win
# over
# Iran
# in
# a
# nerve
# -
# racking
# Group
# B
# decider
# at
# Qatar
# 2022
# .
#
#
#
# Christian
# Pulisic
# ’s
# first
# -
# half
# goal
# was
# all
# that
# separated
# the
# two
# sides
# as
# the
# USMNT
# reached
# the
# round
# of
# 16
# for
# the
# first
# time
# since
# 2014
# .
#
#
#
# The
# pressure
# was
# certainly
# highlight_word(off) on
# for
# Gregg
# Berhalter
# ’s
# side
# in
# Qatar
# after
# the
# national
# team
# ’s
# highlight_word(success) failure
# to
# highlight_word(disqualify) qualify
# for
# the
# 2018
# World
# Cup
# ,
# but
# the
# US
# got
# the
# job
# done
# with
# three
# gritty
# group
# performances
# .
#
#
#
# It
# certainly
# was
# n’t
# pretty
# at
# times
# ,
# in
# particular
# in
# the
# closing
# stages
# against
# Iran
# ,
# but
# highlight_word(recede) progressing
# through
# the
# group
# stage
# was
# the
# highlight_word(maximum) minimum
# expectation
# for
# this
# highlight_word(stifle) exciting
# young
# team
# .
#
#
#
# highlight_word(here) There
# will
# be
# some
# concerns
# going
# into
# the
# knockout
# stages
# ,
# though
# ,
# after
# Pulisic
# suffered
# an
# abdominal
# injury
# while
# scoring
# the
# highlight_word(loser) winner
# .
#
#
#
# The
# USMNT
# will
# be
# highlight_word(despair) hoping
# its
# star
# highlight_word(civilian) man
# ,
# dubbed
# ‘
# Captain
# America
# ’
# by
# some
# ,
# is
# fit
# for
# the
# round
# of
# 16
# tie
# against
# the
# Netherlands
# highlight_word(off) on
# Saturday
# following
# the
# news
# that
# Pulisic
# highlight_word(lack) had
# been
# sent
# to
# hospital
# for
# a
# scan
# .
#
#
#
# Weston
# McKennie
# and
# Tyler
# Adams
# celebrate
# the
# opening
# goal
# .
#
#
#
# highlight_word(loser) Winner
# takes
# all
#
#
#
# This
# was
# the
# only
# the
# third
# meeting
# ever
# between
# the
# two
# nations
# and
# their
# first
# World
# Cup
# encounter
# since
# France
# 1998
# –
# a
# politically
# charged
# match
# that
# saw
# Iran
# emerge
# as
# a
# shock
# 2
# -
# 1
# highlight_word(loser) winner
# .
#
#
#
# That
# was
# the
# first
# time
# that
# Iran
# and
# the
# US
# ,
# sometimes
# described
# officially
# in
# Iran
# as
# the
# ‘
# Great
# Satan
# ,
# ’
# highlight_word(lack) had
# met
# highlight_word(off) on
# the
# football
# pitch
# and
# the
# biggest
# sporting
# occasion
# between
# the
# countries
# since
# the
# 1979
# revolution
# .
#
#
#
# The
# build
# -
# highlight_word(down) up
# to
# this
# game
# in
# Qatar
# has
# been
# similarly
# tense
# ,
# with
# Iran
# even
# calling
# for
# the
# USMNT
# to
# be
# expelled
# from
# the
# World
# Cup
# after
# the
# US
# Soccer
# Federation
# posted
# an
# Iranian
# flag
# without
# the
# emblem
# of
# the
# Islamic
# Republic
# highlight_word(off) on
# its
# social
# media
# platforms
# to
# show
# support
# for
# protesters
# in
# Iran
# .
#
#
#
# USMNT
# manager
# Berhalter
# and
# captain
# Tyler
# Adams
# also
# faced
# some
# tough
# questions
# from
# Iranian
# journalists
# in
# a
# fiery
# press
# conference
# ,
# fending
# highlight_word(on) off
# accusations
# of
# hypocrisy
# and
# highlight_word(respect) disrespect
# .
#
#
#
# The
# furore
# surrounding
# this
# game
# only
# added
# to
# the
# drama
# of
# a
# matchup
# that
# –
# even
# in
# a
# vacuum
# highlight_word(home) away
# from
# highlight_word(on) off
# -
# field
# issues
# –
# was
# guaranteed
# to
# be
# fraught
# with
# tension
# .
#
#
#
# Both
# teams
# knew
# a
# highlight_word(losings) win
# would
# highlight_word(unfasten) secure
# a
# place
# in
# the
# round
# of
# 16
# ,
# but
# for
# the
# USMNT
# even
# a
# draw
# would
# not
# be
# enough
# to
# see
# it
# progress
# from
# the
# group
# .
#
#
#
# The
# USMNT
# highlight_word(lack) had
# to
# battled
# highlight_word(soft) hard
# for
# its
# place
# in
# the
# round
# of
# 16
# .
#
#
#
# highlight_word(here) There
# were
# n’t
# too
# many
# signs
# of
# highlight_word(late) early
# nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# side
# dictated
# the
# play
# in
# the
# opening
# stages
# –
# enjoying
# 65
# %
# of
# the
# possession
# –
# though
# it
# took
# until
# the
# 28th
# minute
# for
# it
# conjure
# the
# first
# chance
# of
# note
# .
#
#
#
# Josh
# Sargeant
# ’s
# highlight_word(short) long
# -
# range
# effort
# took
# a
# deflection
# highlight_word(on) off
# an
# Iranian
# defender
# and
# fell
# highlight_word(imperfectly) perfectly
# into
# the
# path
# of
# Timothy
# Weah
# ,
# who
# perhaps
# did
# n’t
# realize
# he
# was
# all
# alone
# in
# front
# of
# goal
# and
# rushed
# a
# headed
# effort
# that
# Alireza
# Beiranvand
# in
# the
# Iran
# goal
# caught
# with
# ease
# .
#
#
#
# highlight_word(off) On
# the
# half
# hour
# mark
# ,
# Weah
# once
# again
# took
# highlight_word(down) up
# a
# brilliant
# position
# highlight_word(outside) inside
# the
# box
# but
# skied
# his
# effort
# well
# over
# the
# crossbar
# after
# being
# set
# highlight_word(down) up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# pressure
# eventually
# told
# seven
# minutes
# before
# half
# time
# ,
# taking
# the
# lead
# following
# an
# incisive
# team
# move
# .
#
#
#
# Weston
# McKennie
# ’s
# pinpoint
# cross
# field
# ball
# was
# headed
# highlight_word(front) back
# across
# goal
# by
# the
# marauding
# Sergiño
# Dest
# and
# bundled
# home
# bravely
# by
# Pulisic
# ,
# who
# suffered
# a
# hefty
# collision
# with
# Beiranvand
# as
# he
# turned
# the
# ball
# over
# the
# line
# .
#
#
#
# The
# USMNT
# ’s
# delight
# swiftly
# turned
# to
# worry
# as
# it
# was
# evident
# that
# Pulisic
# was
# in
# significant
# highlight_word(pleasure) pain
# following
# the
# clash
# ,
# limping
# heavily
# as
# he
# was
# helped
# highlight_word(on) off
# the
# pitch
# by
# two
# medics
# .
#
#
#
# Pulisic
# soon
# re
# -
# highlight_word(drop_out) entered
# the
# pitch
# ,
# but
# the
# Chelsea
# highlight_word(civilian) man
# was
# highlight_word(unintelligibly) clearly
# still
# struggling
# with
# the
# knock
# .
#
#
#
# Christian
# Pulisic
# is
# surrounded
# by
# teammates
# after
# going
# down
# injured
# following
# his
# goal
# .
#
#
#
# As
# the
# USMNT
# grew
# in
# highlight_word(diffidence) confidence
# ,
# spaces
# highlight_word(end) began
# to
# open
# highlight_word(down) up
# in
# Iran
# ’s
# defense
# and
# Weah
# thought
# he
# ’d
# doubled
# his
# team
# ’s
# lead
# highlight_word(inequitable) just
# before
# the
# interval
# ,
# highlight_word(start) finishing
# wonderfully
# with
# the
# highlight_word(inside) outside
# of
# his
# boot
# only
# to
# be
# met
# by
# the
# linesman
# ’s
# flag
# for
# the
# narrowest
# of
# highlight_word(onside) offside
# decisions
# .
#
#
#
# Though
# Iran
# would
# have
# been
# happy
# to
# weather
# that
# first
# -
# half
# storm
# ,
# it
# was
# a
# surprisingly
# subdued
# performance
# –
# in
# particular
# following
# Pulisic
# ’s
# goal
# –
# from
# a
# team
# that
# highlight_word(lack) had
# caused
# both
# England
# and
# Wales
# highlight_word(offensive) defensive
# problems
# in
# its
# opening
# two
# matches
# .
#
#
#
# Iran
# did
# begin
# the
# second
# half
# with
# highlight_word(less) more
# authority
# ,
# creating
# two
# brilliant
# chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# forward
# was
# unable
# to
# trouble
# USMNT
# goalkeeper
# Matt
# Turner
# .
#
#
#
# With
# the
# clock
# ticking
# down
# ,
# Iran
# highlight_word(lack) had
# a
# glorious
# chance
# to
# level
# the
# score
# but
# Morteza
# Pouraliganji
# ’s
# stooping
# header
# flashed
# narrowly
# wide
# of
# the
# highlight_word(near) far
# post
# highlight_word(little) much
# to
# the
# relief
# of
# the
# American
# fans
# in
# the
# stands
# ,
# many
# who
# highlight_word(lack) had
# their
# heads
# in
# their
# hands
# .
#
#
#
# highlight_word(here) There
# were
# loud
# calls
# for
# a
# penalty
# from
# the
# Iranian
# players
# late
# highlight_word(off) on
# in
# the
# nine
# minutes
# of
# added
# time
# ,
# with
# Mehdi
# Taremi
# insisting
# that
# Cameron
# Carter
# -
# Vickers
# highlight_word(lack) had
# highlight_word(repel) pulled
# down
# the
# Porto
# forward
# down
# as
# he
# attempted
# to
# get
# highlight_word(off) on
# the
# highlight_word(beginning) end
# of
# a
# cross
# .
#
#
#
# USA
# players
# celebrate
# at
# the
# final
# whistle
# .
#
#
#
# After
# a
# brief
# ,
# tense
# check
# ,
# VAR
# decided
# it
# was
# n’t
# a
# penalty
# and
# soon
# after
# referee
# Mateu
# Lahoz
# blew
# his
# whistle
# to
# highlight_word(beginning) end
# the
# game
# .
#
#
#
# Both
# teams
# sank
# to
# the
# floor
# –
# for
# very
# difference
# reasons
# –
# but
# the
# USMNT
# will
# highlight_word(ignore) know
# an
# highlight_word(worsen) improved
# performance
# is
# highlight_word(unnecessary) necessary
# if
# it
# wants
# to
# have
# a
# chance
# of
# advancing
# further
# in
# Qatar
# .
#
#
#
# ‘
# I
# highlight_word(despair) hope
# our
# fans
# …
# forgive
# us
# ’
#
#
# Following
# the
# defeat
# ,
# an
# highlight_word(unemotional) emotional
# Saeid
# Ezatolahi
# asked
# for
# forgiveness
# from
# Iran
# fans
# .
#
#
#
# Iran
# was
# in
# a
# strong
# position
# going
# into
# the
# final
# game
# following
# that
# crucial
# 2
# -
# 0
# highlight_word(losings) win
# over
# Wales
# ,
# needing
# highlight_word(inequitable) just
# a
# draw
# to
# progress
# ,
# but
# put
# in
# a
# disappointing
# performance
# with
# a
# place
# in
# the
# knockout
# stages
# highlight_word(off) on
# the
# line
# .
#
#
#
# “
# I
# ’m
# really
# sorry
# highlight_word(off) on
# behalf
# of
# our
# players
# ,
# our
# group
# ,
# that
# we
# could
# n’t
# get
# our
# opportunity
# to
# highlight_word(disqualify) qualify
# for
# the
# next
# round
# ,
# ”
# the
# midfielder
# said
# .
#
#
#
# “
# Life
# and
# football
# is
# going
# highlight_word(off) on
# and
# that
# can
# be
# a
# highlight_word(evil) good
# lesson
# for
# us
# ,
# at
# highlight_word(most) least
# for
# the
# young
# players
# like
# me
# for
# the
# future
# .
# So
# I
# highlight_word(despair) hope
# our
# fans
# and
# our
# people
# in
# Iran
# ,
# they
# forgive
# us
# and
# I
# feel
# highlight_word(inequitable) just
# sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# coach
# Carlos
# Quieroz
# said
# “
# the
# dream
# is
# over
# ”
# but
# is
# already
# looking
# to
# the
# future
# .
#
#
#
# “
# The
# first
# half
# was
# US
# and
# the
# second
# half
# Iran
# ,
# ”
# said
# Quieroz
# ,
# who
# is
# Iran
# ’s
# highlight_word(short) longest
# -
# serving
# coach
# ,
# highlight_word(lack) having
# managed
# the
# team
# from
# 2011
# to
# 2019
# ,
# before
# returning
# for
# a
# second
# spell
# in
# charge
# in
# September
# .
#
#
#
# “
# The
# difference
# [
# was
# ]
# we
# did
# n’t
# score
# in
# the
# second
# half
# as
# we
# should
# .
# But
# ,
# the
# dream
# is
# over
# .
# Now
# ,
# its
# thinking
# about
# the
# next
# step
# for
# Iran
# ,
# ”
# added
# Quieroz
# ,
# who
# is
# the
# only
# coach
# to
# have
# led
# the
# team
# to
# consecutive
# World
# Cups
# .

# %% [markdown]
# [PROJET Q2] Réécrire un texte en interchangeant tous les mots par leur hyponyme le plus profond dans wordnet pour un contexte donné. Ainsi, pour chaque mot vous devrez (1) trouver son synset, (2) descendre dans l'arbre en choisissant le prochain synset selon la relation d'hyperonimie, (3) parmi les hyponymes possibles choisir celui qui est le plus probable selon l'algorithme de Lesk. Par exemple, "groupe" devient "sous-groupe", "chat" devient "siamois".

# %%
for word in doc:
    word_synsets = wn.synsets(word.text)
    if not word_synsets:
        print(word.text)
        continue
    first_synset_hyponyms = word_synsets[0].hyponyms()
    if not first_synset_hyponyms:
        print(word.text)
        continue
    first_hyponyme_name = first_synset_hyponyms[0].name().split('.')[0]
    print(f'{highlight_word(first_hyponyme_name)} {word.text}')
# Out:
# The
# US
# complement Men
# ’s
# citizen National
# a-team Team
# (
# USMNT
# )
# was
# overdo made
# to
# action work
# hard
# for
# its
# birthplace place
# in
# the
# closed_universe World
# beaker Cup
# knockout
# anal_stage stage
# ,
# eke_out earning
# a
# tough
# monad 1
# -
# 0
# first-place_finish win
# maiden_over over
# Iran
# in
# a
# cranial_nerve nerve
# -
# racking
# actinoid Group
# bacillus_anthracis B
# decider
# at
# Qatar
# 2022
# .
#
#
#
# adventist Christian
# Pulisic
# ’s
# former first
# -
# fifty_percent half
# aim goal
# was
# all
# that
# separated
# the
# couple two
# bedside sides
# as
# the
# USMNT
# access reached
# the
# round
# of
# 16
# for
# the
# former first
# time
# since
# 2014
# .
#
#
#
# The
# blood_pressure pressure
# was
# certainly
# on
# for
# Gregg
# Berhalter
# ’s
# bedside side
# in
# Qatar
# after
# the
# citizen national
# a-team team
# ’s
# backsliding failure
# to
# qualify
# for
# the
# 2018
# closed_universe World
# beaker Cup
# ,
# but
# the
# US
# accept got
# the
# accountancy job
# overdo done
# with
# three
# gritty
# actinoid group
# act performances
# .
#
#
#
# It
# certainly
# was
# n’t
# pretty
# at
# modern_times times
# ,
# in
# particular
# in
# the
# closing
# anal_stage stages
# against
# Iran
# ,
# but
# climb progressing
# through
# the
# actinoid group
# anal_stage stage
# was
# the
# skeleton minimum
# anticipation expectation
# for
# this
# enthuse exciting
# hatchling young
# a-team team
# .
#
#
#
# There
# velleity will
# be
# some
# matter concerns
# boarding going
# into
# the
# knockout
# anal_stage stages
# ,
# though
# ,
# after
# Pulisic
# die suffered
# an
# external_oblique_muscle abdominal
# birth_trauma injury
# cold_spell while
# scoring
# the
# contestee winner
# .
#
#
#
# The
# USMNT
# velleity will
# be
# hoping
# its
# binary_star star
# adonis man
# ,
# dubbed
# ‘
# Captain
# America
# ’
# by
# some
# ,
# abound is
# fit
# for
# the
# round
# of
# 16
# bolo_tie tie
# against
# the
# Netherlands
# on
# Saturday
# claque following
# the
# good_word news
# that
# Pulisic
# bear had
# abound been
# sent
# to
# creche hospital
# for
# a
# scan
# .
#
#
#
# Weston
# McKennie
# and
# Tyler
# Adams
# commemorate celebrate
# the
# breach opening
# aim goal
# .
#
#
#
# contestee Winner
# economic_rent takes
# all
#
#
#
# This
# was
# the
# only
# the
# third
# board_meeting meeting
# ever
# between
# the
# couple two
# ally nations
# and
# their
# former first
# closed_universe World
# beaker Cup
# contretemps encounter
# since
# France
# 1998
# –
# a
# politically
# charged
# fusee match
# that
# saw
# Iran
# burst emerge
# as
# a
# shock
# couple 2
# -
# monad 1
# contestee winner
# .
#
#
#
# That
# was
# the
# former first
# time
# that
# Iran
# and
# the
# US
# ,
# sometimes
# delineate described
# officially
# in
# Iran
# as
# the
# ‘
# Great
# Satan
# ,
# ’
# bear had
# intersect met
# on
# the
# american_football football
# alto pitch
# and
# the
# biggest
# sporting
# climax occasion
# between
# the
# ally countries
# since
# the
# 1979
# cultural_revolution revolution
# .
#
#
#
# The
# body_type build
# -
# up
# to
# this
# athletic_game game
# in
# Qatar
# has
# abound been
# similarly
# aorist tense
# ,
# with
# Iran
# guest_night even
# business_life calling
# for
# the
# USMNT
# to
# be
# banish expelled
# from
# the
# closed_universe World
# beaker Cup
# after
# the
# US
# Soccer
# american_federation_of_labor Federation
# placard posted
# an
# farsi Iranian
# american_flag flag
# without
# the
# colophon emblem
# of
# the
# Islamic
# parliamentary_democracy Republic
# on
# its
# social
# album media
# auction_block platforms
# to
# cabaret show
# logistic_support support
# for
# conscientious_objector protesters
# in
# Iran
# .
#
#
#
# USMNT
# bank_manager manager
# Berhalter
# and
# captain
# Tyler
# Adams
# also
# undertake faced
# some
# tough
# questions
# from
# farsi Iranian
# broadcast_journalist journalists
# in
# a
# fiery
# press
# colloquium conference
# ,
# fending
# burke off
# allegation accusations
# of
# crocodile_tears hypocrisy
# and
# abuse disrespect
# .
#
#
#
# The
# furore
# cloister surrounding
# this
# athletic_game game
# only
# add_on added
# to
# the
# grand_guignol drama
# of
# a
# matchup
# that
# –
# guest_night even
# in
# a
# vacuum
# away
# from
# burke off
# -
# campus field
# gut_issue issues
# –
# was
# bail guaranteed
# to
# be
# fraught
# with
# breaking_point tension
# .
#
#
#
# Both
# a-team teams
# keep_track knew
# a
# first-place_finish win
# would
# copyright secure
# a
# birthplace place
# in
# the
# round
# of
# 16
# ,
# but
# for
# the
# USMNT
# guest_night even
# a
# draw
# would
# not
# be
# fill enough
# to
# see
# it
# forwarding progress
# from
# the
# actinoid group
# .
#
#
#
# The
# USMNT
# bear had
# to
# dogfight battled
# hard
# for
# its
# birthplace place
# in
# the
# round
# of
# 16
# .
#
#
#
# There
# abound were
# n’t
# too
# many
# token signs
# of
# early
# jitters nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# bedside side
# mandate dictated
# the
# grand_guignol play
# in
# the
# breach opening
# anal_stage stages
# –
# devour enjoying
# 65
# %
# of
# the
# actual_possession possession
# –
# though
# it
# took
# until
# the
# 28th
# minute
# for
# it
# bless conjure
# the
# former first
# brass_ring chance
# of
# jotting note
# .
#
#
#
# Josh
# Sargeant
# ’s
# ache long
# -
# approximate_range range
# batting effort
# took
# a
# deflection
# burke off
# an
# farsi Iranian
# admonisher defender
# and
# cowhide fell
# perfectly
# into
# the
# ambages path
# of
# Timothy
# Weah
# ,
# who
# perhaps
# overdo did
# n’t
# know realize
# he
# was
# all
# alone
# in
# forefront front
# of
# aim goal
# and
# barge rushed
# a
# take headed
# batting effort
# that
# Alireza
# Beiranvand
# in
# the
# Iran
# aim goal
# caught
# with
# effortlessness ease
# .
#
#
#
# On
# the
# fifty_percent half
# man_hour hour
# decile mark
# ,
# Weah
# once
# again
# took
# up
# a
# brilliant
# anomaly position
# midland inside
# the
# ballot_box box
# but
# hot-dog skied
# his
# batting effort
# artesian_well well
# maiden_over over
# the
# doubletree crossbar
# after
# actuality being
# bracket set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# blood_pressure pressure
# eventually
# add told
# seven
# congressional_record minutes
# before
# fifty_percent half
# time
# ,
# taking
# the
# lead
# claque following
# an
# incisive
# a-team team
# demarche move
# .
#
#
#
# Weston
# McKennie
# ’s
# pinpoint
# cross
# campus field
# baseball ball
# was
# take headed
# back
# across
# aim goal
# by
# the
# marauding
# Sergiño
# Dest
# and
# bundled
# home_away_from_home home
# bravely
# by
# Pulisic
# ,
# who
# die suffered
# a
# hefty
# collision
# with
# Beiranvand
# as
# he
# about-face turned
# the
# baseball ball
# maiden_over over
# the
# chorus line
# .
#
#
#
# The
# USMNT
# ’s
# amusement delight
# swiftly
# about-face turned
# to
# bugaboo worry
# as
# it
# was
# evident
# that
# Pulisic
# was
# in
# significant
# ache pain
# claque following
# the
# clash
# ,
# intermittent_claudication limping
# heavily
# as
# he
# was
# avail helped
# burke off
# the
# alto pitch
# by
# couple two
# alfalfa medics
# .
#
#
#
# Pulisic
# soon
# re
# -
# board entered
# the
# alto pitch
# ,
# but
# the
# Chelsea
# adonis man
# was
# clearly
# still
# flounder struggling
# with
# the
# knock
# .
#
#
#
# adventist Christian
# Pulisic
# abound is
# cloister surrounded
# by
# teammates
# after
# boarding going
# duck_down down
# bruise injured
# claque following
# his
# aim goal
# .
#
#
#
# As
# the
# USMNT
# bald grew
# in
# confidence
# ,
# absolute_space spaces
# attack began
# to
# open
# up
# in
# Iran
# ’s
# air_defense defense
# and
# Weah
# burden thought
# he
# ’d
# geminate doubled
# his
# a-team team
# ’s
# lead
# just
# before
# the
# absence interval
# ,
# glaze finishing
# wonderfully
# with
# the
# outdoors outside
# of
# his
# buskin boot
# only
# to
# be
# intersect met
# by
# the
# linesman
# ’s
# american_flag flag
# for
# the
# narrowest
# of
# offside
# appointment decisions
# .
#
#
#
# Though
# Iran
# would
# affluent have
# abound been
# happy
# to
# atmosphere weather
# that
# former first
# -
# fifty_percent half
# blizzard storm
# ,
# it
# was
# a
# surprisingly
# subdued
# act performance
# –
# in
# particular
# claque following
# Pulisic
# ’s
# aim goal
# –
# from
# a
# a-team team
# that
# bear had
# determine caused
# both
# England
# and
# Wales
# defensive
# balance-of-payments_problem problems
# in
# its
# breach opening
# couple two
# fusee matches
# .
#
#
#
# Iran
# overdo did
# begin
# the
# leap_second second
# fifty_percent half
# with
# more
# carte_blanche authority
# ,
# arouse creating
# couple two
# brilliant
# brass_ring chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# forward
# was
# unable
# to
# can_of_worms trouble
# USMNT
# goalkeeper
# Matt
# Turner
# .
#
#
#
# With
# the
# alarm_clock clock
# ticktock ticking
# duck_down down
# ,
# Iran
# bear had
# a
# glorious
# brass_ring chance
# to
# amplitude_level level
# the
# decile score
# but
# Morteza
# Pouraliganji
# ’s
# huddle stooping
# crossheading header
# flicker flashed
# narrowly
# wide
# of
# the
# far
# bridgehead post
# much
# to
# the
# relief
# of
# the
# african-american American
# electric_fan fans
# in
# the
# brass_monkey stands
# ,
# many
# who
# bear had
# their
# human_head heads
# in
# their
# hands
# .
#
#
#
# There
# abound were
# loud
# call-back calls
# for
# a
# castigation penalty
# from
# the
# farsi Iranian
# ballplayer players
# late
# on
# in
# the
# nine
# congressional_record minutes
# of
# add_on added
# time
# ,
# with
# Mehdi
# Taremi
# purism insisting
# that
# Cameron
# Carter
# -
# Vickers
# bear had
# abduct pulled
# duck_down down
# the
# Porto
# forward
# duck_down down
# as
# he
# endeavor attempted
# to
# get
# on
# the
# bitter_end end
# of
# a
# cross
# .
#
#
#
# USA
# ballplayer players
# commemorate celebrate
# at
# the
# cup_final final
# whistle
# .
#
#
#
# After
# a
# amicus_curiae_brief brief
# ,
# aorist tense
# bad_check check
# ,
# VAR
# choose decided
# it
# was
# n’t
# a
# castigation penalty
# and
# soon
# after
# referee
# Mateu
# Lahoz
# insufflate blew
# his
# whistle
# to
# bitter_end end
# the
# athletic_game game
# .
#
#
#
# Both
# a-team teams
# drop_open sank
# to
# the
# bell_deck floor
# –
# for
# very
# differentia difference
# occasion reasons
# –
# but
# the
# USMNT
# velleity will
# know
# an
# advance improved
# act performance
# abound is
# desideratum necessary
# if
# it
# wants
# to
# affluent have
# a
# brass_ring chance
# of
# close_in advancing
# further
# in
# Qatar
# .
#
#
#
# ‘
# iodine-125 I
# hope
# our
# electric_fan fans
# …
# absolve forgive
# us
# ’
#
#
# claque Following
# the
# heartbreaker defeat
# ,
# an
# emotional
# Saeid
# Ezatolahi
# consult asked
# for
# forgiveness
# from
# Iran
# electric_fan fans
# .
#
#
#
# Iran
# was
# in
# a
# strong
# anomaly position
# boarding going
# into
# the
# cup_final final
# athletic_game game
# claque following
# that
# crucial
# couple 2
# -
# 0
# first-place_finish win
# maiden_over over
# Wales
# ,
# claim needing
# just
# a
# draw
# to
# forwarding progress
# ,
# but
# put
# in
# a
# disenchant disappointing
# act performance
# with
# a
# birthplace place
# in
# the
# knockout
# anal_stage stages
# on
# the
# chorus line
# .
#
#
#
# “
# iodine-125 I
# ’m
# really
# sorry
# on
# behalf
# of
# our
# ballplayer players
# ,
# our
# actinoid group
# ,
# that
# we
# could
# n’t
# get
# our
# brass_ring opportunity
# to
# qualify
# for
# the
# next
# round
# ,
# ”
# the
# midfielder
# add said
# .
#
#
#
# “
# ghetto Life
# and
# american_football football
# abound is
# boarding going
# on
# and
# that
# beer_can can
# be
# a
# common_good good
# dance_lesson lesson
# for
# us
# ,
# at
# least
# for
# the
# hatchling young
# ballplayer players
# like
# me
# for
# the
# by-and-by future
# .
# So
# iodine-125 I
# hope
# our
# electric_fan fans
# and
# our
# age_group people
# in
# Iran
# ,
# they
# absolve forgive
# us
# and
# iodine-125 I
# feel
# just
# sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# baseball_coach coach
# Carlos
# Quieroz
# add said
# “
# the
# nightmare dream
# abound is
# maiden_over over
# ”
# but
# abound is
# already
# dekko looking
# to
# the
# by-and-by future
# .
#
#
#
# “
# The
# former first
# fifty_percent half
# was
# US
# and
# the
# leap_second second
# fifty_percent half
# Iran
# ,
# ”
# add said
# Quieroz
# ,
# who
# abound is
# Iran
# ’s
# longest
# -
# breast serving
# baseball_coach coach
# ,
# bear having
# managed
# the
# a-team team
# from
# 2011
# to
# 2019
# ,
# before
# backtrack returning
# for
# a
# leap_second second
# fascination spell
# in
# countercharge charge
# in
# September
# .
#
#
#
# “
# The
# differentia difference
# [
# was
# ]
# we
# overdo did
# n’t
# decile score
# in
# the
# leap_second second
# fifty_percent half
# as
# we
# should
# .
# But
# ,
# the
# nightmare dream
# abound is
# maiden_over over
# .
# Now
# ,
# its
# consideration thinking
# about
# the
# next
# countermeasure step
# for
# Iran
# ,
# ”
# add_on added
# Quieroz
# ,
# who
# abound is
# the
# only
# baseball_coach coach
# to
# affluent have
# organic_light-emitting_diode led
# the
# a-team team
# to
# consecutive
# closed_universe World
# beaker Cups
# .

# %% [markdown]
# [PROJET Q3] Réécrire un texte écrit en anglais en interchangeant tous les mots par leurs correspondants en français, en italien ou en espagnol. Cela revient à avoir un traducteur mot à mot. Par exemple, "group" devient "groupe", "cat" devient "chat".

# %%
wn.langs()
# Out:
# ['eng',
#  'als',
#  'arb',
#  'bul',
#  'cmn',
#  'dan',
#  'ell',
#  'fin',
#  'fra',
#  'heb',
#  'hrv',
#  'isl',
#  'ita',
#  'ita_iwn',
#  'jpn',
#  'cat',
#  'eus',
#  'glg',
#  'spa',
#  'ind',
#  'zsm',
#  'nld',
#  'nno',
#  'nob',
#  'pol',
#  'por',
#  'ron',
#  'lit',
#  'slk',
#  'slv',
#  'swe',
#  'tha']

# %%
# Traduction des mots en français
import nltk
from nltk.corpus import wordnet as wn
for word in doc:
    word_synsets = wn.synsets(word.text)

    if len(word_synsets) > 1:
        second_synset_french_lemmas = word_synsets[1].lemma_names('fra')
        if second_synset_french_lemmas:
            print(f"{highlight_word(second_synset_french_lemmas[0])} {word.text}")
        else:
            print(word.text)
    else:
        print(word.text)
# Out:
# The
# uracile US
# homme Men
# ’s
# national National
# attelage Team
# (
# USMNT
# )
# être was
# rendre made
# to
# job work
# difficile hard
# for
# its
# endroit place
# IN in
# the
# Terre World
# tasse Cup
# Ko knockout
# degré stage
# ,
# gagner earning
# rétinol a
# bandit tough
# 10 1
# -
# 0 0
# gagner win
# fini over
# Iran
# IN in
# rétinol a
# cœur nerve
# -
# racking
# groupe Group
# B
# decider
# at at
# Katar Qatar
# 2022
# .
#
#
#
# Christian Christian
# Pulisic
# ’s
# premier first
# -
# mi-temps half
# but goal
# être was
# tout all
# that
# diviser separated
# the
# two
# côté sides
# Samoa_américaines as
# the
# USMNT
# aboutir reached
# the
# cycle round
# of
# seize 16
# for
# the
# premier first
# temps time
# since
# 2014
# .
#
#
#
# The
# oppression pressure
# être was
# certainly
# on
# for
# Gregg
# Berhalter
# ’s
# côté side
# IN in
# Katar Qatar
# après after
# the
# national national
# attelage team
# ’s
# failure
# to
# définir qualify
# for
# the
# 2018
# Terre World
# tasse Cup
# ,
# but
# the
# uracile US
# devenir got
# the
# travail job
# accomplir done
# with
# three
# jeu gritty
# groupe group
# performance performances
# .
#
#
#
# It
# certainly
# être was
# n’t
# beau pretty
# at at
# fois times
# ,
# IN in
# chose particular
# IN in
# the
# conclusion closing
# degré stages
# against
# Iran
# ,
# but
# arriver progressing
# through
# the
# groupe group
# degré stage
# être was
# the
# minimum minimum
# anticipation expectation
# for
# this
# exciter exciting
# Crosby young
# attelage team
# .
#
#
#
# là There
# testament will
# être be
# quelque some
# crainte concerns
# abandon going
# into
# the
# Ko knockout
# degré stages
# ,
# though
# ,
# après after
# Pulisic
# atteindre suffered
# an
# abdominal abdominal
# blessure injury
# while
# marquer scoring
# the
# gagnant winner
# .
#
#
#
# The
# USMNT
# testament will
# être be
# espérer hoping
# its
# as star
# homme man
# ,
# doubler dubbed
# ‘
# capitaine Captain
# Amérique America
# ’
# loin by
# quelque some
# ,
# être is
# paroxysme fit
# for
# the
# cycle round
# of
# seize 16
# affiliation tie
# against
# the
# Netherlands
# on
# Saturday
# poursuite following
# the
# actualité news
# that
# Pulisic
# avoir had
# être been
# envoyer sent
# to
# centre_hospitalier hospital
# for
# rétinol a
# scanner scan
# .
#
#
#
# Weston
# McKennie
# and
# Tyler
# John_Quincy_Adams Adams
# célébrer celebrate
# the
# ouverture opening
# but goal
# .
#
#
#
# gagnant Winner
# pêcher takes
# tout all
#
#
#
# This
# être was
# the
# seul only
# the
# tierce third
# rencontre meeting
# toujours ever
# entre between
# the
# two
# nation nations
# and
# their
# premier first
# Terre World
# tasse Cup
# abord encounter
# since
# Anatole_France France
# 1998
# –
# rétinol a
# politically
# accuser charged
# match match
# that
# scie saw
# Iran
# donner emerge
# Samoa_américaines as
# rétinol a
# shock
# 1 2
# -
# 10 1
# gagnant winner
# .
#
#
#
# That
# être was
# the
# premier first
# temps time
# that
# Iran
# and
# the
# uracile US
# ,
# sometimes
# apporter described
# formellement officially
# IN in
# Iran
# Samoa_américaines as
# the
# ‘
# grand Great
# Satan
# ,
# ’
# avoir had
# rassembler met
# on
# the
# ballon football
# lancer pitch
# and
# the
# grand biggest
# alouette sporting
# aventure occasion
# entre between
# the
# pays countries
# since
# the
# 1979
# révolution revolution
# .
#
#
#
# The
# Corps_humain build
# -
# up
# to
# this
# jeu game
# IN in
# Katar Qatar
# avoir has
# être been
# similarly
# bander tense
# ,
# with
# Iran
# niveler even
# appeler calling
# for
# the
# USMNT
# to
# être be
# expulser expelled
# from
# the
# Terre World
# tasse Cup
# après after
# the
# uracile US
# Soccer
# confédération Federation
# posted
# an
# Iranien Iranian
# drapeau flag
# without
# the
# allégorie emblem
# of
# the
# Islamic
# république Republic
# on
# its
# social social
# milieu media
# plate-forme platforms
# to
# concours show
# appui support
# for
# manifestant protesters
# IN in
# Iran
# .
#
#
#
# USMNT
# administrateur manager
# Berhalter
# and
# capitaine captain
# Tyler
# John_Quincy_Adams Adams
# also
# affronter faced
# quelque some
# bandit tough
# chose questions
# from
# Iranien Iranian
# diariste journalists
# IN in
# rétinol a
# igné fiery
# presse press
# conférence conference
# ,
# opposer fending
# off
# accusation accusations
# of
# hypocrisie hypocrisy
# and
# disrespect
# .
#
#
#
# The
# fureur furore
# surrounding
# this
# jeu game
# seul only
# adjoindre added
# to
# the
# drame drama
# of
# rétinol a
# matchup
# that
# –
# niveler even
# IN in
# rétinol a
# néant vacuum
# loin away
# from
# off
# -
# champ_de_bataille field
# numéro issues
# –
# être was
# assurer guaranteed
# to
# être be
# enceinte fraught
# with
# tension tension
# .
#
#
#
# Both
# attelage teams
# connaître knew
# rétinol a
# gagner win
# would
# attacher secure
# rétinol a
# endroit place
# IN in
# the
# cycle round
# of
# seize 16
# ,
# but
# for
# the
# USMNT
# niveler even
# rétinol a
# attraction draw
# would
# not
# être be
# adéquat enough
# to
# percevoir see
# it
# progression progress
# from
# the
# groupe group
# .
#
#
#
# The
# USMNT
# avoir had
# to
# battled
# difficile hard
# for
# its
# endroit place
# IN in
# the
# cycle round
# of
# seize 16
# .
#
#
#
# là There
# être were
# n’t
# aussi too
# many
# pancarte signs
# of
# mi-précoce early
# nerves
# from
# the
# USMNT
# Samoa_américaines as
# Berhalter
# ’s
# côté side
# dicter dictated
# the
# jeu play
# IN in
# the
# ouverture opening
# degré stages
# –
# bénéficier enjoying
# 65
# %
# of
# the
# bien possession
# –
# though
# it
# occuper took
# until
# the
# 28th
# instant minute
# for
# it
# implorer conjure
# the
# premier first
# aléa chance
# of
# billette note
# .
#
#
#
# Josh
# Sargeant
# ’s
# long long
# -
# portée range
# effort effort
# occuper took
# rétinol a
# réfraction deflection
# off
# an
# Iranien Iranian
# défenseur defender
# and
# fell
# parfaitement perfectly
# into
# the
# parcours path
# of
# Fête Timothy
# Weah
# ,
# who
# perhaps
# accomplir did
# n’t
# comprendre realize
# he he
# être was
# tout all
# isolé alone
# IN in
# front front
# of
# but goal
# and
# rushed
# rétinol a
# conduire headed
# effort effort
# that
# Alireza
# Beiranvand
# IN in
# the
# Iran
# but goal
# saisir caught
# with
# aisance ease
# .
#
#
#
# On
# the
# mi-temps half
# heure hour
# marquage mark
# ,
# Weah
# dès_que once
# again
# occuper took
# up
# rétinol a
# brilliant
# position position
# dedans inside
# the
# boite box
# but
# skied
# his
# effort effort
# puits well
# fini over
# the
# crossbar
# après after
# organisme being
# ensemble set
# up
# loin by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# oppression pressure
# eventually
# communiquer told
# seven
# min minutes
# auparavant before
# mi-temps half
# temps time
# ,
# faire taking
# the
# plomb lead
# poursuite following
# an
# incisive
# attelage team
# délocalisation move
# .
#
#
#
# Weston
# McKennie
# ’s
# pinpoint
# croix cross
# champ_de_bataille field
# bal ball
# être was
# conduire headed
# arrière back
# across
# but goal
# loin by
# the
# marauding
# Sergiño
# Dest
# and
# faisceau bundled
# demeure home
# bravely
# loin by
# Pulisic
# ,
# who
# atteindre suffered
# rétinol a
# hefty
# abordage collision
# with
# Beiranvand
# Samoa_américaines as
# he he
# turned
# the
# bal ball
# fini over
# the
# ligne line
# .
#
#
#
# The
# USMNT
# ’s
# allégresse delight
# swiftly
# turned
# to
# angoisse worry
# Samoa_américaines as
# it
# être was
# évident evident
# that
# Pulisic
# être was
# IN in
# considérable significant
# douleur pain
# poursuite following
# the
# conflit clash
# ,
# boiter limping
# gauchement heavily
# Samoa_américaines as
# he he
# être was
# aider helped
# off
# the
# lancer pitch
# loin by
# two
# medics
# .
#
#
#
# Pulisic
# soon
# re
# -
# entrer entered
# the
# lancer pitch
# ,
# but
# the
# Chelsea
# homme man
# être was
# clairement clearly
# calme still
# struggling
# with
# the
# griller knock
# .
#
#
#
# Christian Christian
# Pulisic
# être is
# surrounded
# loin by
# teammates
# après after
# abandon going
# porte down
# blesser injured
# poursuite following
# his
# but goal
# .
#
#
#
# Samoa_américaines As
# the
# USMNT
# augmenter grew
# IN in
# censure confidence
# ,
# espace spaces
# commencer began
# to
# air open
# up
# IN in
# Iran
# ’s
# défense defense
# and
# Weah
# cérébration thought
# he he
# ’d
# double doubled
# his
# attelage team
# ’s
# plomb lead
# juste just
# auparavant before
# the
# façon interval
# ,
# fin finishing
# wonderfully
# with
# the
# dehors outside
# of
# his
# boot
# seul only
# to
# être be
# rassembler met
# loin by
# the
# électricien linesman
# ’s
# drapeau flag
# for
# the
# étroit narrowest
# of
# hors-jeu offside
# conclusion decisions
# .
#
#
#
# Though
# Iran
# would
# avoir have
# être been
# heureux happy
# to
# courageux weather
# that
# premier first
# -
# mi-temps half
# orage storm
# ,
# it
# être was
# rétinol a
# brillamment surprisingly
# conquérir subdued
# performance performance
# –
# IN in
# chose particular
# poursuite following
# Pulisic
# ’s
# but goal
# –
# from
# rétinol a
# attelage team
# that
# avoir had
# causer caused
# both
# England
# and
# prospérité Wales
# défensif defensive
# problème problems
# IN in
# its
# ouverture opening
# two
# match matches
# .
#
#
#
# Iran
# accomplir did
# commencer begin
# the
# instant second
# mi-temps half
# with
# plus more
# autorité authority
# ,
# créer creating
# two
# brilliant
# aléa chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# forward
# être was
# incapable unable
# to
# agitation trouble
# USMNT
# gardien_de_but goalkeeper
# mat Matt
# Turner
# .
#
#
#
# With
# the
# chronométrer clock
# ticking
# porte down
# ,
# Iran
# avoir had
# rétinol a
# fameux glorious
# aléa chance
# to
# grade level
# the
# score
# but
# Morteza
# Pouraliganji
# ’s
# perron stooping
# linteau header
# flash flashed
# narrowly
# wide
# of
# the
# lointain far
# post
# beaucoup much
# to
# the
# allégement relief
# of
# the
# Américain American
# fan fans
# IN in
# the
# être_debout stands
# ,
# many
# who
# avoir had
# their
# morceau heads
# IN in
# their
# actif hands
# .
#
#
#
# là There
# être were
# bariolé loud
# appel calls
# for
# rétinol a
# peine penalty
# from
# the
# Iranien Iranian
# instrumentiste players
# tard late
# on
# IN in
# the
# club nine
# min minutes
# of
# adjoindre added
# temps time
# ,
# with
# Mehdi
# Taremi
# insister insisting
# that
# Cameron
# James_Earl_Carter Carter
# -
# Vickers
# avoir had
# allécher pulled
# porte down
# the
# Porto
# forward
# porte down
# Samoa_américaines as
# he he
# assumer attempted
# to
# acquérir get
# on
# the
# bout end
# of
# rétinol a
# croix cross
# .
#
#
#
# EUA USA
# instrumentiste players
# célébrer celebrate
# at at
# the
# dernier final
# siffler whistle
# .
#
#
#
# après After
# rétinol a
# bref brief
# ,
# bander tense
# contrôle check
# ,
# VAR
# décider decided
# it
# être was
# n’t
# rétinol a
# peine penalty
# and
# soon
# après after
# arbitre referee
# Mateu
# Lahoz
# souffler blew
# his
# siffler whistle
# to
# bout end
# the
# jeu game
# .
#
#
#
# Both
# attelage teams
# évier sank
# to
# the
# niveau floor
# –
# for
# identique very
# différence difference
# cause reasons
# –
# but
# the
# USMNT
# testament will
# connaître know
# an
# amender improved
# performance performance
# être is
# nécessaire necessary
# if
# it
# absence wants
# to
# avoir have
# rétinol a
# aléa chance
# of
# proposer advancing
# améliorer further
# IN in
# Katar Qatar
# .
#
#
#
# ‘
# 10 I
# espoir hope
# our
# fan fans
# …
# excuser forgive
# uracile us
# ’
#
#
# poursuite Following
# the
# défaite defeat
# ,
# an
# émotionnel emotional
# Saeid
# Ezatolahi
# demander asked
# for
# pardon forgiveness
# from
# Iran
# fan fans
# .
#
#
#
# Iran
# être was
# IN in
# rétinol a
# fort strong
# position position
# abandon going
# into
# the
# dernier final
# jeu game
# poursuite following
# that
# pertinent crucial
# 1 2
# -
# 0 0
# gagner win
# fini over
# prospérité Wales
# ,
# avoir_besoin_de needing
# juste just
# rétinol a
# attraction draw
# to
# progression progress
# ,
# but
# mettre put
# IN in
# rétinol a
# décevant disappointing
# performance performance
# with
# rétinol a
# endroit place
# IN in
# the
# Ko knockout
# degré stages
# on
# the
# ligne line
# .
#
#
#
# “
# 10 I
# ’m
# effectivement really
# lamentable sorry
# on
# nom behalf
# of
# our
# instrumentiste players
# ,
# our
# groupe group
# ,
# that
# we
# could
# n’t
# acquérir get
# our
# opportunity
# to
# définir qualify
# for
# the
# prochain next
# cycle round
# ,
# ”
# the
# midfielder
# accuser said
# .
#
#
#
# “
# existence Life
# and
# ballon football
# être is
# abandon going
# on
# and
# that
# pouvoir can
# être be
# rétinol a
# bonté good
# exemple lesson
# for
# uracile us
# ,
# at at
# moindre least
# for
# the
# Crosby young
# instrumentiste players
# grain like
# me
# for
# the
# avenir future
# .
# ainsi So
# 10 I
# espoir hope
# our
# fan fans
# and
# our
# nation people
# IN in
# Iran
# ,
# they
# excuser forgive
# uracile us
# and
# 10 I
# esprit feel
# juste just
# lamentable sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# autobus coach
# Carlos
# Quieroz
# accuser said
# “
# the
# rêve dream
# être is
# fini over
# ”
# but
# être is
# already
# looking
# to
# the
# avenir future
# .
#
#
#
# “
# The
# premier first
# mi-temps half
# être was
# uracile US
# and
# the
# instant second
# mi-temps half
# Iran
# ,
# ”
# accuser said
# Quieroz
# ,
# who
# être is
# Iran
# ’s
# long longest
# -
# portion serving
# autobus coach
# ,
# avoir having
# diriger managed
# the
# attelage team
# from
# 2011
# to
# 2019
# ,
# auparavant before
# redonner returning
# for
# rétinol a
# instant second
# aller spell
# IN in
# accusation charge
# IN in
# September
# .
#
#
#
# “
# The
# différence difference
# [
# être was
# ]
# we
# accomplir did
# n’t
# score
# IN in
# the
# instant second
# mi-temps half
# Samoa_américaines as
# we
# should
# .
# But
# ,
# the
# rêve dream
# être is
# fini over
# .
# Now
# ,
# its
# considérer thinking
# approximativement about
# the
# prochain next
# enjambée step
# for
# Iran
# ,
# ”
# adjoindre added
# Quieroz
# ,
# who
# être is
# the
# seul only
# autobus coach
# to
# avoir have
# amener led
# the
# attelage team
# to
# consécutif consecutive
# Terre World
# tasse Cups
# .

# %%
# Traduction des mots en italien
for word in doc:
    word_synsets = wn.synsets(word.text)
    if len(word_synsets) > 1:
        selected_synset = word_synsets[1]
        italian_lemmas = selected_synset.lemma_names('ita')
        if italian_lemmas:
            selected_lemma = italian_lemmas[0]
            print(f"{highlight_word(selected_lemma)} {word.text}")
            continue
    print(word.text)
# Out:
# The
# US
# maschio Men
# ’s
# nazionale National
# attacco Team
# (
# USMNT
# )
# avere was
# essere made
# to
# lavoro work
# duro hard
# for
# its
# luogo place
# indio in
# the
# mondo World
# tazza Cup
# ko knockout
# fase stage
# ,
# guadagnare earning
# a
# giovinastro tough
# 1 1
# -
# zero 0
# vincita win
# finito over
# Iran
# indio in
# a
# animo nerve
# -
# racking
# radicale Group
# B
# decider
# lat at
# Qatar Qatar
# 2022
# .
#
#
#
# cristiano Christian
# Pulisic
# ’s
# primo first
# -
# tempo half
# destinazione goal
# avere was
# all
# that
# disgiungere separated
# the
# two
# parte sides
# as
# the
# USMNT
# raggiungere reached
# the
# ciclo round
# of
# 16 16
# for
# the
# primo first
# periodo time
# since
# 2014
# .
#
#
#
# The
# pressione pressure
# avere was
# certainly
# on
# for
# Gregg
# Berhalter
# ’s
# parte side
# indio in
# Qatar Qatar
# dopo after
# the
# nazionale national
# attacco team
# ’s
# fallimento failure
# to
# qualify
# for
# the
# 2018
# mondo World
# tazza Cup
# ,
# but
# the
# US
# divenire got
# the
# job
# eseguire done
# with
# three
# gritty
# radicale group
# esecuzione performances
# .
#
#
#
# It
# certainly
# avere was
# n’t
# pretty
# lat at
# moltiplicazione times
# ,
# indio in
# dettaglio particular
# indio in
# the
# chiusa closing
# fase stages
# against
# Iran
# ,
# but
# andare_avanti progressing
# through
# the
# radicale group
# fase stage
# avere was
# the
# minimum
# aspettativa expectation
# for
# this
# sollecitare exciting
# young
# attacco team
# .
#
#
#
# There
# volontà will
# avere be
# some
# paura concerns
# going
# into
# the
# ko knockout
# fase stages
# ,
# though
# ,
# dopo after
# Pulisic
# beccarsi suffered
# an
# addominale abdominal
# lesione injury
# while
# marcare scoring
# the
# winner
# .
#
#
#
# The
# USMNT
# volontà will
# avere be
# sperare hoping
# its
# asso star
# militare man
# ,
# doppiare dubbed
# ‘
# capitano Captain
# America America
# ’
# by
# some
# ,
# essere is
# accesso fit
# for
# the
# ciclo round
# of
# 16 16
# affiliazione tie
# against
# the
# Netherlands
# on
# Saturday
# caccia following
# the
# annuncio news
# that
# Pulisic
# avere had
# essere been
# mandare sent
# to
# hospital
# for
# a
# scan
# .
#
#
#
# Weston
# McKennie
# and
# Tyler
# Adams
# festeggiare celebrate
# the
# apertura opening
# destinazione goal
# .
#
#
#
# Winner
# inquadratura takes
# all
#
#
#
# This
# avere was
# the
# only
# the
# terza third
# incontro meeting
# sempre ever
# between
# the
# two
# nazione nations
# and
# their
# primo first
# mondo World
# tazza Cup
# incontro encounter
# since
# France
# 1998
# –
# a
# politically
# charged
# combattimento match
# that
# sega saw
# Iran
# fuoriuscire emerge
# as
# a
# shock
# 2 2
# -
# 1 1
# winner
# .
#
#
#
# That
# avere was
# the
# primo first
# periodo time
# that
# Iran
# and
# the
# US
# ,
# sometimes
# descrivere described
# formalmente officially
# indio in
# Iran
# as
# the
# ‘
# grande Great
# Satan
# ,
# ’
# avere had
# incontrare met
# on
# the
# palla_ovale football
# pitch
# and
# the
# biggest
# ruzzare sporting
# avvenimento occasion
# between
# the
# nazione countries
# since
# the
# 1979
# rivoluzione revolution
# .
#
#
#
# The
# carne build
# -
# up
# to
# this
# giocata game
# indio in
# Qatar Qatar
# avere has
# essere been
# similarly
# tense
# ,
# with
# Iran
# livellare even
# battezzare calling
# for
# the
# USMNT
# to
# avere be
# expelled
# from
# the
# mondo World
# tazza Cup
# dopo after
# the
# US
# Soccer
# confederazione Federation
# posted
# an
# iranico Iranian
# flag
# without
# the
# emblema emblem
# of
# the
# Islamic
# Republic
# on
# its
# sociale social
# mezzo media
# piattaforma platforms
# to
# dimostrazione show
# adesione support
# for
# dimostrante protesters
# indio in
# Iran
# .
#
#
#
# USMNT
# CT manager
# Berhalter
# and
# capitano captain
# Tyler
# Adams
# also
# affrontare faced
# some
# giovinastro tough
# questione questions
# from
# iranico Iranian
# journalists
# indio in
# a
# fiery
# press
# campionato conference
# ,
# fending
# off
# accusa accusations
# of
# farisaismo hypocrisy
# and
# GAP! disrespect
# .
#
#
#
# The
# furore
# surrounding
# this
# giocata game
# only
# aggiungere added
# to
# the
# dramma drama
# of
# a
# matchup
# that
# –
# livellare even
# indio in
# a
# vuoto vacuum
# away
# from
# off
# -
# campo_di_battaglia field
# fascicolo issues
# –
# avere was
# assicurare guaranteed
# to
# avere be
# fraught
# with
# tensione tension
# .
#
#
#
# Both
# attacco teams
# conoscere knew
# a
# vincita win
# would
# secure
# a
# luogo place
# indio in
# the
# ciclo round
# of
# 16 16
# ,
# but
# for
# the
# USMNT
# livellare even
# a
# attrazione draw
# would
# not
# avere be
# sufficiente enough
# to
# vedere see
# it
# andamento progress
# from
# the
# radicale group
# .
#
#
#
# The
# USMNT
# avere had
# to
# battled
# duro hard
# for
# its
# luogo place
# indio in
# the
# ciclo round
# of
# 16 16
# .
#
#
#
# There
# essere were
# n’t
# anche too
# many
# signs
# of
# primo early
# nerves
# from
# the
# USMNT
# as
# Berhalter
# ’s
# parte side
# dettare dictated
# the
# rappresentazione play
# indio in
# the
# apertura opening
# fase stages
# –
# godere enjoying
# 65
# %
# of
# the
# possesso possession
# –
# though
# it
# andare took
# until
# the
# 28th
# attimo minute
# for
# it
# implorare conjure
# the
# primo first
# caso chance
# of
# biglietto note
# .
#
#
#
# Josh
# Sargeant
# ’s
# lungo long
# -
# gittata range
# fatica effort
# andare took
# a
# deflection
# off
# an
# iranico Iranian
# defender
# and
# fell
# a_puntino perfectly
# into
# the
# sentiero path
# of
# Timothy
# Weah
# ,
# who
# perhaps
# eseguire did
# n’t
# capire realize
# he
# avere was
# all
# solo alone
# indio in
# fronte front
# of
# destinazione goal
# and
# rushed
# a
# capeggiare headed
# fatica effort
# that
# Alireza
# Beiranvand
# indio in
# the
# Iran
# destinazione goal
# captare caught
# with
# agiatezza ease
# .
#
#
#
# On
# the
# tempo half
# ora hour
# contrassegno mark
# ,
# Weah
# quando once
# again
# andare took
# up
# a
# brillante brilliant
# appostamento position
# dentro inside
# the
# palco box
# but
# skied
# his
# fatica effort
# well
# finito over
# the
# asticella crossbar
# dopo after
# essere_vivente being
# insieme set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# pressione pressure
# eventually
# dire told
# seven
# minuto minutes
# anteriormente before
# tempo half
# periodo time
# ,
# avere taking
# the
# lead
# caccia following
# an
# incisive
# attacco team
# sgomberatura move
# .
#
#
#
# Weston
# McKennie
# ’s
# macchietta pinpoint
# croce cross
# campo_di_battaglia field
# ball
# avere was
# capeggiare headed
# di_dietro back
# trasversalmente across
# destinazione goal
# by
# the
# marauding
# Sergiño
# Dest
# and
# bundled
# abitazione home
# bravely
# by
# Pulisic
# ,
# who
# beccarsi suffered
# a
# hefty
# collisione collision
# with
# Beiranvand
# as
# he
# turned
# the
# ball
# finito over
# the
# linea line
# .
#
#
#
# The
# USMNT
# ’s
# delizia delight
# swiftly
# turned
# to
# affanno worry
# as
# it
# avere was
# evident
# that
# Pulisic
# avere was
# indio in
# significativo significant
# dolore pain
# caccia following
# the
# conflitto clash
# ,
# arrancare limping
# pesantemente heavily
# as
# he
# avere was
# aiutare helped
# off
# the
# pitch
# by
# two
# medico_militare medics
# .
#
#
#
# Pulisic
# soon
# re
# -
# entered
# the
# pitch
# ,
# but
# the
# Chelsea
# militare man
# avere was
# chiaramente clearly
# pace still
# struggling
# with
# the
# knock
# .
#
#
#
# cristiano Christian
# Pulisic
# essere is
# surrounded
# by
# teammates
# dopo after
# going
# down
# addolorare injured
# caccia following
# his
# destinazione goal
# .
#
#
#
# As
# the
# USMNT
# allargarsi grew
# indio in
# affidamento confidence
# ,
# spazio spaces
# aprire began
# to
# scoperto open
# up
# indio in
# Iran
# ’s
# argine defense
# and
# Weah
# pensiero thought
# he
# ’d
# doubled
# his
# attacco team
# ’s
# lead
# equo just
# anteriormente before
# the
# interval
# ,
# fine finishing
# wonderfully
# with
# the
# esterno outside
# of
# his
# boot
# only
# to
# avere be
# incontrare met
# by
# the
# elettricista linesman
# ’s
# flag
# for
# the
# narrowest
# of
# offside
# conclusione decisions
# .
#
#
#
# Though
# Iran
# would
# avere have
# essere been
# happy
# to
# sfidare weather
# that
# primo first
# -
# tempo half
# bufera storm
# ,
# it
# avere was
# a
# surprisingly
# reprimere subdued
# esecuzione performance
# –
# indio in
# dettaglio particular
# caccia following
# Pulisic
# ’s
# destinazione goal
# –
# from
# a
# attacco team
# that
# avere had
# avere caused
# both
# England
# and
# Wales
# difensivo defensive
# problema problems
# indio in
# its
# apertura opening
# two
# combattimento matches
# .
#
#
#
# Iran
# eseguire did
# attaccare begin
# the
# attimo second
# tempo half
# with
# altro more
# autorità authority
# ,
# creare creating
# two
# brillante brilliant
# caso chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# avanti forward
# avere was
# unable
# to
# briga trouble
# USMNT
# goalkeeper
# Matt
# Turner
# .
#
#
#
# With
# the
# calcolare_la_durata_di clock
# traliccio ticking
# down
# ,
# Iran
# avere had
# a
# magnifico glorious
# caso chance
# to
# livello level
# the
# partitura score
# but
# Morteza
# Pouraliganji
# ’s
# abbassarsi stooping
# architrave header
# flashed
# narrowly
# ampio wide
# of
# the
# lontano far
# post
# molto much
# to
# the
# sollievo relief
# of
# the
# americano American
# tifoso fans
# indio in
# the
# stands
# ,
# many
# who
# avere had
# their
# capo heads
# indio in
# their
# forza_lavoro hands
# .
#
#
#
# There
# essere were
# loud
# calls
# for
# a
# penale penalty
# from
# the
# iranico Iranian
# musicista players
# in_ritardo late
# on
# indio in
# the
# società nine
# minuto minutes
# of
# aggiungere added
# periodo time
# ,
# with
# Mehdi
# Taremi
# insistere insisting
# that
# Cameron
# Carter
# -
# Vickers
# avere had
# accentrare pulled
# down
# the
# Porto
# avanti forward
# down
# as
# he
# attempted
# to
# acquisire get
# on
# the
# chiusa end
# of
# a
# croce cross
# .
#
#
#
# USA
# musicista players
# festeggiare celebrate
# lat at
# the
# maturità final
# fischio whistle
# .
#
#
#
# dopo After
# a
# brief
# ,
# tense
# check
# ,
# VAR
# decidere decided
# it
# avere was
# n’t
# a
# penale penalty
# and
# soon
# dopo after
# censore referee
# Mateu
# Lahoz
# spirare blew
# his
# fischio whistle
# to
# chiusa end
# the
# giocata game
# .
#
#
#
# Both
# attacco teams
# affondare sank
# to
# the
# piano floor
# –
# for
# identico very
# deroga difference
# causa reasons
# –
# but
# the
# USMNT
# volontà will
# conoscere know
# an
# acquistare improved
# esecuzione performance
# essere is
# indispensabile necessary
# if
# it
# assenza wants
# to
# avere have
# a
# caso chance
# of
# accampare advancing
# caldeggiare further
# indio in
# Qatar Qatar
# .
#
#
#
# ‘
# 1 I
# speranza hope
# our
# tifoso fans
# …
# abbonare forgive
# us
# ’
#
#
# caccia Following
# the
# frustrazione defeat
# ,
# an
# GAP! emotional
# Saeid
# Ezatolahi
# chiedere asked
# for
# perdono forgiveness
# from
# Iran
# tifoso fans
# .
#
#
#
# Iran
# avere was
# indio in
# a
# forte strong
# appostamento position
# going
# into
# the
# maturità final
# giocata game
# caccia following
# that
# crucial
# 2 2
# -
# zero 0
# vincita win
# finito over
# Wales
# ,
# avere_bisogno needing
# equo just
# a
# attrazione draw
# to
# andamento progress
# ,
# but
# appoggiare put
# indio in
# a
# GAP! disappointing
# esecuzione performance
# with
# a
# luogo place
# indio in
# the
# ko knockout
# fase stages
# on
# the
# linea line
# .
#
#
#
# “
# 1 I
# ’m
# davvero really
# sorry
# on
# behalf
# of
# our
# musicista players
# ,
# our
# radicale group
# ,
# that
# we
# could
# n’t
# acquisire get
# our
# opportunity
# to
# qualify
# for
# the
# altro next
# ciclo round
# ,
# ”
# the
# midfielder
# said
# .
#
#
#
# “
# vita Life
# and
# palla_ovale football
# essere is
# going
# on
# and
# that
# can
# avere be
# a
# bontà good
# esempio lesson
# for
# us
# ,
# lat at
# least
# for
# the
# young
# musicista players
# like
# me
# for
# the
# futuro future
# .
# a_tal_punto So
# 1 I
# speranza hope
# our
# tifoso fans
# and
# our
# popolazione people
# indio in
# Iran
# ,
# they
# abbonare forgive
# us
# and
# 1 I
# sensazione feel
# equo just
# sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# aio coach
# Carlos
# Quieroz
# said
# “
# the
# sogno dream
# essere is
# finito over
# ”
# but
# essere is
# already
# looking
# to
# the
# futuro future
# .
#
#
#
# “
# The
# primo first
# tempo half
# avere was
# US
# and
# the
# attimo second
# tempo half
# Iran
# ,
# ”
# said
# Quieroz
# ,
# who
# essere is
# Iran
# ’s
# lungo longest
# -
# notifica serving
# aio coach
# ,
# avere having
# trattare managed
# the
# attacco team
# from
# 2011
# to
# 2019
# ,
# anteriormente before
# rendere returning
# for
# a
# attimo second
# spell
# indio in
# accusa charge
# indio in
# September
# .
#
#
#
# “
# The
# deroga difference
# [
# avere was
# ]
# we
# eseguire did
# n’t
# partitura score
# indio in
# the
# attimo second
# tempo half
# as
# we
# should
# .
# But
# ,
# the
# sogno dream
# essere is
# finito over
# .
# adesso Now
# ,
# its
# credere thinking
# all'_incirca about
# the
# altro next
# passo step
# for
# Iran
# ,
# ”
# aggiungere added
# Quieroz
# ,
# who
# essere is
# the
# only
# aio coach
# to
# avere have
# accompagnare led
# the
# attacco team
# to
# consecutive
# mondo World
# tazza Cups
# .

# %%
# Traduction des mots en espagnol
for word in doc:
    word_synsets = wn.synsets(word.text)
    if len(word_synsets) > 1:
        second_synset = word_synsets[1]
        spanish_lemmas = second_synset.lemma_names('spa')
        if spanish_lemmas:
            spanish_lemma = spanish_lemmas[0]
            print(f"{highlight_word(spanish_lemma)} {word.text}")
        else:
            print(word.text)
    else:
        print(word.text)
# Out:
# The
# uracilo US
# hombre Men
# ’s
# nacional National
# Team
# (
# USMNT
# )
# ser was
# convertir made
# to
# obra work
# duro hard
# for
# its
# lugar place
# indio in
# the
# World
# taza Cup
# nocaut knockout
# etapa stage
# ,
# ganar earning
# a
# tough
# 1
# -
# 0
# ganancia win
# completo over
# Iran
# indio in
# a
# coraje nerve
# -
# atormentar racking
# radical Group
# B
# decider
# at
# Qatar
# 2022
# .
#
#
#
# cristiano Christian
# Pulisic
# ’s
# primero first
# -
# mitad half
# destino goal
# ser was
# all
# that
# separar separated
# the
# two
# ala sides
# Samoa_Americana as
# the
# USMNT
# lograr reached
# the
# ciclo round
# of
# 16
# for
# the
# primero first
# tiempo time
# since
# 2014
# .
#
#
#
# The
# presión pressure
# ser was
# certainly
# on
# for
# Gregg
# Berhalter
# ’s
# ala side
# indio in
# Qatar
# after
# the
# nacional national
# team
# ’s
# fracaso failure
# to
# capacitar qualify
# for
# the
# 2018
# World
# taza Cup
# ,
# but
# the
# uracilo US
# got
# the
# cometido job
# ejecutar done
# with
# three
# enérgico gritty
# radical group
# actuación performances
# .
#
#
#
# It
# certainly
# ser was
# n’t
# buen pretty
# at
# multiplicación times
# ,
# indio in
# elemento particular
# indio in
# the
# cierre closing
# etapa stages
# against
# Iran
# ,
# but
# progressing
# seguido through
# the
# radical group
# etapa stage
# ser was
# the
# mínimo minimum
# anticipación expectation
# for
# this
# estimular exciting
# Loretta_Young young
# team
# .
#
#
#
# allí There
# voluntad will
# ser be
# some
# inquietud concerns
# deceso going
# into
# the
# nocaut knockout
# etapa stages
# ,
# though
# ,
# after
# Pulisic
# sufrir suffered
# an
# abdominal abdominal
# injury
# while
# anotar scoring
# the
# winner
# .
#
#
#
# The
# USMNT
# voluntad will
# ser be
# hoping
# its
# as star
# militar man
# ,
# doblar dubbed
# ‘
# capitán Captain
# América America
# ’
# by
# some
# ,
# ser is
# fit
# for
# the
# ciclo round
# of
# 16
# tie
# against
# the
# Netherlands
# on
# Saturday
# caza following
# the
# noticia news
# that
# Pulisic
# presentar had
# ser been
# echar sent
# to
# clínica hospital
# for
# a
# scan
# .
#
#
#
# Weston
# McKennie
# and
# Tyler
# Adams Adams
# festejar celebrate
# the
# apertura opening
# destino goal
# .
#
#
#
# Winner
# toma takes
# all
#
#
#
# This
# ser was
# the
# only
# the
# third
# encuentro meeting
# ever
# between
# the
# two
# nación nations
# and
# their
# primero first
# World
# taza Cup
# acercamiento encounter
# since
# Anatole_France France
# 1998
# –
# a
# politically
# acusar charged
# encuentro match
# that
# sierra saw
# Iran
# aparecer emerge
# Samoa_Americana as
# a
# shock
# 2
# -
# 1
# winner
# .
#
#
#
# That
# ser was
# the
# primero first
# tiempo time
# that
# Iran
# and
# the
# uracilo US
# ,
# sometimes
# denunciar described
# officially
# indio in
# Iran
# Samoa_Americana as
# the
# ‘
# grande Great
# Satan
# ,
# ’
# presentar had
# encontrarse met
# on
# the
# football
# pitch
# and
# the
# gran biggest
# sporting
# acontecimiento occasion
# between
# the
# estado countries
# since
# the
# 1979
# revolución revolution
# .
#
#
#
# The
# carne build
# -
# up
# to
# this
# juego game
# indio in
# Qatar
# poseer has
# ser been
# similarly
# tensar tense
# ,
# with
# Iran
# even
# llamar calling
# for
# the
# USMNT
# to
# ser be
# expulsar expelled
# from
# the
# World
# taza Cup
# after
# the
# uracilo US
# Soccer
# confederación Federation
# anunciar posted
# an
# Iranian
# flag
# without
# the
# divisa emblem
# of
# the
# Islamic
# república Republic
# on
# its
# social social
# medio media
# programa platforms
# to
# indicio show
# apoyo support
# for
# protesters
# indio in
# Iran
# .
#
#
#
# USMNT
# adiestrador manager
# Berhalter
# and
# capitán captain
# Tyler
# Adams Adams
# also
# afrontar faced
# some
# tough
# aspecto questions
# from
# Iranian
# diarista journalists
# indio in
# a
# fiery
# prensa press
# liga conference
# ,
# fending
# apagado off
# accusations
# of
# hypocrisy
# and
# descortesía disrespect
# .
#
#
#
# The
# arrebato furore
# cercar surrounding
# this
# juego game
# only
# añadir added
# to
# the
# drama drama
# of
# a
# matchup
# that
# –
# even
# indio in
# a
# vacío vacuum
# away
# from
# apagado off
# -
# field
# ejemplar issues
# –
# ser was
# asegurar guaranteed
# to
# ser be
# lleno fraught
# with
# tensión tension
# .
#
#
#
# Both
# teams
# conocer knew
# a
# ganancia win
# would
# asegurar secure
# a
# lugar place
# indio in
# the
# ciclo round
# of
# 16
# ,
# but
# for
# the
# USMNT
# even
# a
# atracción draw
# would
# not
# ser be
# suficiente enough
# to
# ver see
# it
# avance progress
# from
# the
# radical group
# .
#
#
#
# The
# USMNT
# presentar had
# to
# battled
# duro hard
# for
# its
# lugar place
# indio in
# the
# ciclo round
# of
# 16
# .
#
#
#
# allí There
# ser were
# n’t
# además too
# many
# anuncio signs
# of
# temprano early
# nerves
# from
# the
# USMNT
# Samoa_Americana as
# Berhalter
# ’s
# ala side
# dictar dictated
# the
# obra play
# indio in
# the
# apertura opening
# etapa stages
# –
# disfrutar enjoying
# 65
# %
# of
# the
# posesión possession
# –
# though
# it
# llevar took
# until
# the
# 28th
# instante minute
# for
# it
# adjurar conjure
# the
# primero first
# azar chance
# of
# línea note
# .
#
#
#
# Josh
# Sargeant
# ’s
# extenso long
# -
# alcance range
# afán effort
# llevar took
# a
# deflection
# apagado off
# an
# Iranian
# defender
# and
# fell
# perfectamente perfectly
# into
# the
# camino path
# of
# Timothy
# Weah
# ,
# who
# perhaps
# ejecutar did
# n’t
# entender realize
# he
# ser was
# all
# alone
# indio in
# frente front
# of
# destino goal
# and
# rushed
# a
# dirigir headed
# afán effort
# that
# Alireza
# Beiranvand
# indio in
# the
# Iran
# destino goal
# captar caught
# with
# bienestar ease
# .
#
#
#
# On
# the
# mitad half
# hora hour
# marca mark
# ,
# Weah
# una_vez once
# again
# llevar took
# up
# a
# brillante brilliant
# posición position
# interior inside
# the
# palco box
# but
# skied
# his
# afán effort
# well
# completo over
# the
# crossbar
# after
# organismo being
# conjunto set
# up
# by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# presión pressure
# eventually
# decir told
# seven
# minuto minutes
# ante before
# mitad half
# tiempo time
# ,
# tomar taking
# the
# lead
# caza following
# an
# incisive
# team
# mudanza move
# .
#
#
#
# Weston
# McKennie
# ’s
# pinpoint
# cruz cross
# field
# ball
# ser was
# dirigir headed
# fondo back
# a_través across
# destino goal
# by
# the
# marauding
# Sergiño
# Dest
# and
# agrupar bundled
# casa home
# bravely
# by
# Pulisic
# ,
# who
# sufrir suffered
# a
# hefty
# collision
# with
# Beiranvand
# Samoa_Americana as
# he
# turned
# the
# ball
# completo over
# the
# line
# .
#
#
#
# The
# USMNT
# ’s
# alegría delight
# swiftly
# turned
# to
# inquietud worry
# Samoa_Americana as
# it
# ser was
# evidente evident
# that
# Pulisic
# ser was
# indio in
# significant
# angustia pain
# caza following
# the
# clash
# ,
# limping
# heavily
# Samoa_Americana as
# he
# ser was
# auxilio helped
# apagado off
# the
# pitch
# by
# two
# médico medics
# .
#
#
#
# Pulisic
# soon
# re
# -
# entrar entered
# the
# pitch
# ,
# but
# the
# Chelsea
# militar man
# ser was
# clearly
# calma still
# struggling
# with
# the
# crítica_negativa knock
# .
#
#
#
# cristiano Christian
# Pulisic
# ser is
# cercar surrounded
# by
# teammates
# after
# deceso going
# down
# dañar injured
# caza following
# his
# destino goal
# .
#
#
#
# Samoa_Americana As
# the
# USMNT
# crecer grew
# indio in
# confianza confidence
# ,
# espacio spaces
# comenzar began
# to
# open
# up
# indio in
# Iran
# ’s
# defender defense
# and
# Weah
# meditación thought
# he
# ’d
# doubled
# his
# team
# ’s
# lead
# just
# ante before
# the
# interval
# ,
# finishing
# wonderfully
# with
# the
# outside
# of
# his
# boot
# only
# to
# ser be
# encontrarse met
# by
# the
# chispa linesman
# ’s
# flag
# for
# the
# estrecho narrowest
# of
# offside
# decisión decisions
# .
#
#
#
# Though
# Iran
# would
# poseer have
# ser been
# contento happy
# to
# weather
# that
# primero first
# -
# mitad half
# tormenta storm
# ,
# it
# ser was
# a
# surprisingly
# contener subdued
# actuación performance
# –
# indio in
# elemento particular
# caza following
# Pulisic
# ’s
# destino goal
# –
# from
# a
# team
# that
# presentar had
# causar caused
# both
# England
# and
# Wales
# defensivo defensive
# problema problems
# indio in
# its
# apertura opening
# two
# encuentro matches
# .
#
#
#
# Iran
# ejecutar did
# comenzar begin
# the
# instante second
# mitad half
# with
# more
# autoridad authority
# ,
# crear creating
# two
# brillante brilliant
# azar chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# forward
# ser was
# unable
# to
# alboroto trouble
# USMNT
# guardameta goalkeeper
# mate Matt
# Henry_Hubert_Turner Turner
# .
#
#
#
# With
# the
# clock
# ticking
# down
# ,
# Iran
# presentar had
# a
# brillante glorious
# azar chance
# to
# grado level
# the
# score
# but
# Morteza
# Pouraliganji
# ’s
# stooping
# header
# flashed
# narrowly
# amplio wide
# of
# the
# distante far
# post
# much
# to
# the
# alivio relief
# of
# the
# americano American
# aficionado fans
# indio in
# the
# stands
# ,
# many
# who
# presentar had
# their
# cabeza heads
# indio in
# their
# hands
# .
#
#
#
# allí There
# ser were
# llamativo loud
# calls
# for
# a
# penalty
# from
# the
# Iranian
# instrumentista players
# tardío late
# on
# indio in
# the
# nine
# minuto minutes
# of
# añadir added
# tiempo time
# ,
# with
# Mehdi
# Taremi
# insistir insisting
# that
# Cameron
# Carter Carter
# -
# Vickers
# presentar had
# atraer pulled
# down
# the
# Porto
# forward
# down
# Samoa_Americana as
# he
# emprender attempted
# to
# adquirir get
# on
# the
# conclusión end
# of
# a
# cruz cross
# .
#
#
#
# Ejército_de_los_Estados_Unidos USA
# instrumentista players
# festejar celebrate
# at
# the
# examen_final final
# whistle
# .
#
#
#
# After
# a
# compendio brief
# ,
# tensar tense
# comprobación check
# ,
# VAR
# resolver decided
# it
# ser was
# n’t
# a
# penalty
# and
# soon
# after
# crítico referee
# Mateu
# Lahoz
# soplar blew
# his
# whistle
# to
# conclusión end
# the
# juego game
# .
#
#
#
# Both
# teams
# hundir sank
# to
# the
# piso floor
# –
# for
# idéntico very
# desviación difference
# porqué reasons
# –
# but
# the
# USMNT
# voluntad will
# conocer know
# an
# adelantar improved
# actuación performance
# ser is
# necesario necessary
# if
# it
# carencia wants
# to
# poseer have
# a
# azar chance
# of
# avanzar advancing
# estimular further
# indio in
# Qatar
# .
#
#
#
# ‘
# I
# esperanza hope
# our
# aficionado fans
# …
# condonar forgive
# uracilo us
# ’
#
#
# caza Following
# the
# derrota defeat
# ,
# an
# emocional emotional
# Saeid
# Ezatolahi
# pedir asked
# for
# perdón forgiveness
# from
# Iran
# aficionado fans
# .
#
#
#
# Iran
# ser was
# indio in
# a
# fuerte strong
# posición position
# deceso going
# into
# the
# examen_final final
# juego game
# caza following
# that
# crucial crucial
# 2
# -
# 0
# ganancia win
# completo over
# Wales
# ,
# necesitar needing
# just
# a
# atracción draw
# to
# avance progress
# ,
# but
# poner put
# indio in
# a
# disappointing
# actuación performance
# with
# a
# lugar place
# indio in
# the
# nocaut knockout
# etapa stages
# on
# the
# line
# .
#
#
#
# “
# I
# ’m
# really
# lamentable sorry
# on
# nombre behalf
# of
# our
# instrumentista players
# ,
# our
# radical group
# ,
# that
# we
# could
# n’t
# adquirir get
# our
# opportunity
# to
# capacitar qualify
# for
# the
# inmediato next
# ciclo round
# ,
# ”
# the
# midfielder
# afirmar said
# .
#
#
#
# “
# existencia Life
# and
# football
# ser is
# deceso going
# on
# and
# that
# can
# ser be
# a
# bondad good
# ejemplo lesson
# for
# uracilo us
# ,
# at
# mínimo least
# for
# the
# Loretta_Young young
# instrumentista players
# clase like
# me
# for
# the
# futuro future
# .
# tan So
# I
# esperanza hope
# our
# aficionado fans
# and
# our
# pueblo people
# indio in
# Iran
# ,
# they
# condonar forgive
# uracilo us
# and
# I
# feel
# just
# lamentable sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# coach
# Carlos
# Quieroz
# afirmar said
# “
# the
# sueño dream
# ser is
# completo over
# ”
# but
# ser is
# already
# looking
# to
# the
# futuro future
# .
#
#
#
# “
# The
# primero first
# mitad half
# ser was
# uracilo US
# and
# the
# instante second
# mitad half
# Iran
# ,
# ”
# afirmar said
# Quieroz
# ,
# who
# ser is
# Iran
# ’s
# extenso longest
# -
# serving
# coach
# ,
# presentar having
# manejar managed
# the
# team
# from
# 2011
# to
# 2019
# ,
# ante before
# devolver returning
# for
# a
# instante second
# turno spell
# indio in
# cargo charge
# indio in
# September
# .
#
#
#
# “
# The
# desviación difference
# [
# ser was
# ]
# we
# ejecutar did
# n’t
# score
# indio in
# the
# instante second
# mitad half
# Samoa_Americana as
# we
# should
# .
# But
# ,
# the
# sueño dream
# ser is
# completo over
# .
# Now
# ,
# its
# considerar thinking
# about
# the
# inmediato next
# paso step
# for
# Iran
# ,
# ”
# añadir added
# Quieroz
# ,
# who
# ser is
# the
# only
# coach
# to
# poseer have
# conducir led
# the
# team
# to
# continuado consecutive
# World
# taza Cups
# .

# %% [markdown]
# [PROJET Q4] Réécrire un texte en interchangeant tous les mots par leurs définitions. Cela revient à produire la contrainte Littérature Définitionnelle (https://www.oulipo.net/fr/contraintes/litterature-definitionnelle) du groupe de recherche en écriture créative OULIPO (https://fr.wikipedia.org/wiki/Oulipo).

# %%
for word in doc:
    synsets = wn.synsets(word.text)
    if synsets and len(synsets) > 1:
        synset = synsets[0]
        definition = synset.definition()
        
        print(f"{highlight_word(definition)} {word.text}")
    else:
        print(f"{word.text}")
# Out:
# The
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 US
# the force of workers available Men
# ’s
# a person who owes allegiance to that nation National
# a cooperative unit (especially in sports) Team
# (
# USMNT
# )
# a state in northwestern United States on the Pacific was
# engage in made
# to
# activity directed toward making or doing something work
# not easy; requiring great physical or mental effort to accomplish or comprehend or endure hard
# for
# its
# a point located with respect to surface features of some region place
# a unit of length equal to one twelfth of a foot in
# the
# everything that exists anywhere World
# a small open container usually used for drinking; usually has a handle Cup
# a very attractive or seductive looking woman knockout
# any distinct time period in a sequence of events stage
# ,
# earn on some commercial or business transaction; earn as salary or wages earning
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# someone who learned to fight in the streets rather than being formally trained in the sport of boxing tough
# the smallest whole number or a numeral representing this number 1
# -
# a mathematical element that when added to another number yields the same number 0
# a victory (as in a race or other competition) win
# (cricket) the division of play during which six balls are bowled at the batsman by one player from the other team from the same end of the pitch over
# Iran
# a unit of length equal to one twelfth of a foot in
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# any bundle of nerve fibers running to various organs and tissues of the body nerve
# -
# go at a rack racking
# any number of entities (members) considered as a unit Group
# aerobic rod-shaped spore-producing bacterium; often occurring in chainlike formations; found primarily in soil B
# decider
# a highly unstable radioactive element (the heaviest of the halogen series); a decay product of uranium and thorium at
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# 2022
# .
#
#
#
# a religious person who believes Jesus is the Christ and who is a member of a Christian denomination Christian
# Pulisic
# ’s
# the first or highest in an ordering or series first
# -
# one of two equal parts of a divisible whole half
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# a state in northwestern United States on the Pacific was
# quantifier; used with either mass or count nouns to indicate the whole number or amount of or every one of a class all
# that
# act as a barrier between; stand between separated
# the
# the cardinal number that is the sum of one and one or a numeral representing this number two
# a place within a region identified relative to a center or reference location sides
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# the
# USMNT
# reach a destination, either real or abstract reached
# the
# a charge of ammunition for a single shot round
# of
# the cardinal number that is the sum of fifteen and one 16
# for
# the
# the first or highest in an ordering or series first
# an instance or single occasion for some event time
# since
# 2014
# .
#
#
#
# The
# the force applied to a unit area of surface; measured in pascals (SI unit) or in dynes (cgs unit) pressure
# a state in northwestern United States on the Pacific was
# certainly
# in operation or operational on
# for
# Gregg
# Berhalter
# ’s
# a place within a region identified relative to a center or reference location side
# a unit of length equal to one twelfth of a foot in
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# located farther aft after
# the
# a person who owes allegiance to that nation national
# a cooperative unit (especially in sports) team
# ’s
# an act that fails failure
# to
# prove capable or fit; meet requirements qualify
# for
# the
# 2018
# everything that exists anywhere World
# a small open container usually used for drinking; usually has a handle Cup
# ,
# but
# the
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 US
# come into the possession of something concrete or abstract got
# the
# the principal activity in your life that you do to earn money job
# engage in done
# with
# the cardinal number that is the sum of one and one and one three
# composed of or covered with particles resembling meal in texture or consistency gritty
# any number of entities (members) considered as a unit group
# a dramatic or musical entertainment performances
# .
#
#
#
# It
# certainly
# a state in northwestern United States on the Pacific was
# n’t
# pleasing by delicacy or grace; not imposing pretty
# a highly unstable radioactive element (the heaviest of the halogen series); a decay product of uranium and thorium at
# a more or less definite period of time now or previously present times
# ,
# a unit of length equal to one twelfth of a foot in
# a fact about some part (as opposed to general) particular
# a unit of length equal to one twelfth of a foot in
# the
# the act of closing something closing
# any distinct time period in a sequence of events stages
# against
# Iran
# ,
# but
# develop in a positive way progressing
# having finished or arrived at completion through
# the
# any number of entities (members) considered as a unit group
# any distinct time period in a sequence of events stage
# a state in northwestern United States on the Pacific was
# the
# the smallest possible quantity minimum
# belief about (or mental picture of) the future expectation
# for
# this
# arouse or elicit a feeling exciting
# any immature animal young
# a cooperative unit (especially in sports) team
# .
#
#
#
# a location other than here; that place There
# the capability of conscious choice and decision and intention; - George Meredith will
# a light strong brittle grey toxic bivalent metallic element be
# quantifier; used with either mass nouns or plural count nouns to indicate an unspecified number or quantity some
# something that interests you because it is important or affects you concerns
# the act of departing going
# into
# the
# a very attractive or seductive looking woman knockout
# any distinct time period in a sequence of events stages
# ,
# though
# ,
# located farther aft after
# Pulisic
# undergo or be subjected to suffered
# an
# the muscles of the abdomen abdominal
# any physical damage to the body caused by violence or accident or fracture etc. injury
# while
# evaluation of performance by assigning a grade or score scoring
# the
# the contestant who wins the contest winner
# .
#
#
#
# The
# USMNT
# the capability of conscious choice and decision and intention; - George Meredith will
# a light strong brittle grey toxic bivalent metallic element be
# expect and wish hoping
# its
# (astronomy) a celestial body of hot gases that radiates energy derived from thermonuclear reactions in the interior star
# an adult person who is male (as opposed to a woman) man
# ,
# give a nickname to dubbed
# ‘
# an officer holding a rank below a major but above a lieutenant Captain
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 America
# ’
# so as to pass a given point by
# quantifier; used with either mass nouns or plural count nouns to indicate an unspecified number or quantity some
# ,
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# a display of bad temper fit
# for
# the
# a charge of ammunition for a single shot round
# of
# the cardinal number that is the sum of fifteen and one 16
# neckwear consisting of a long narrow piece of material worn (mostly by men) under a collar and tied in knot at the front tie
# against
# the
# Netherlands
# in operation or operational on
# Saturday
# a group of followers or enthusiasts following
# the
# information about recent and important events news
# that
# Pulisic
# have or possess, either in a concrete or an abstract sense had
# have the quality of being; (copula, used with an adjective or a predicate noun) been
# 100 senti equal 1 kroon in Estonia sent
# to
# a health facility where patients receive treatment hospital
# for
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# the act of scanning; systematic examination of a prescribed region scan
# .
#
#
#
# Weston
# McKennie
# and
# elected vice president and became the 10th President of the United States when Harrison died (1790-1862) Tyler
# American Revolutionary leader and patriot; an organizer of the Boston Tea Party and signer of the Declaration of Independence (1722-1803) Adams
# behave as expected during of holidays or rites celebrate
# the
# an open or empty space in or between things opening
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# .
#
#
#
# the contestant who wins the contest Winner
# the income or profit arising from such transactions as the sale of land or other property takes
# quantifier; used with either mass or count nouns to indicate the whole number or amount of or every one of a class all
#
#
#
# This
# a state in northwestern United States on the Pacific was
# the
# being the only one; single and isolated from others only
# the
# one of three equal parts of a divisible whole third
# a formally arranged gathering meeting
# at any time ever
# in the interval between
# the
# the cardinal number that is the sum of one and one or a numeral representing this number two
# a politically organized body of people under a single government nations
# and
# their
# the first or highest in an ordering or series first
# everything that exists anywhere World
# a small open container usually used for drinking; usually has a handle Cup
# a minor short-term fight encounter
# since
# a republic in western Europe; the largest country wholly in Europe France
# 1998
# –
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# with regard to social relationships involving authority politically
# to make a rush at or sudden attack upon, as in battle charged
# lighter consisting of a thin piece of wood or cardboard tipped with combustible chemical; ignites with friction match
# that
# a condensed but memorable saying embodying some important fact of experience that is taken as true by many people saw
# Iran
# come out into view, as from concealment emerge
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# the feeling of distress and disbelief that you have when something bad happens accidentally shock
# the cardinal number that is the sum of one and one or a numeral representing this number 2
# -
# the smallest whole number or a numeral representing this number 1
# the contestant who wins the contest winner
# .
#
#
#
# That
# a state in northwestern United States on the Pacific was
# the
# the first or highest in an ordering or series first
# an instance or single occasion for some event time
# that
# Iran
# and
# the
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 US
# ,
# sometimes
# give a description of described
# in an official role officially
# a unit of length equal to one twelfth of a foot in
# Iran
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# the
# ‘
# a person who has achieved distinction and honor in some field Great
# Satan
# ,
# ’
# have or possess, either in a concrete or an abstract sense had
# come together met
# in operation or operational on
# the
# any of various games played with a ball (round or oval) in which two teams try to kick or carry or propel the ball into each other's goal football
# the property of sound that varies with variation in the frequency of vibration pitch
# and
# the
# above average in size or number or quantity or magnitude or extent biggest
# wear or display in an ostentatious or proud manner sporting
# an event that occurs at a critical time occasion
# in the interval between
# the
# a politically organized body of people under a single government countries
# since
# the
# 1979
# a drastic and far-reaching change in ways of thinking and behaving revolution
# .
#
#
#
# The
# constitution of the human body build
# -
# raise up
# to
# this
# a contest with rules to determine a winner game
# a unit of length equal to one twelfth of a foot in
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# (astronomy) the angular distance of a celestial point measured westward along the celestial equator from the zenith crossing; the right ascension for an observer at a particular location and time of day has
# have the quality of being; (copula, used with an adjective or a predicate noun) been
# similarly
# a grammatical category of verbs used to express distinctions of time tense
# ,
# with
# Iran
# the latter part of the day (the period of decreasing daylight from late afternoon until nightfall) even
# the particular occupation for which you are trained calling
# for
# the
# USMNT
# to
# a light strong brittle grey toxic bivalent metallic element be
# force to leave or move out expelled
# from
# the
# everything that exists anywhere World
# a small open container usually used for drinking; usually has a handle Cup
# located farther aft after
# the
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 US
# Soccer
# an organization formed by merging several groups or parties Federation
# affix in a public place or for public notice posted
# an
# a native or inhabitant of Iran Iranian
# emblem usually consisting of a rectangular piece of cloth of distinctive design flag
# without
# the
# special design or visual object representing a quality, type, group, etc. emblem
# of
# the
# Islamic
# a political system in which the supreme power lies in a body of citizens who can elect people to represent them Republic
# in operation or operational on
# its
# a party of people assembled to promote sociability and communal activity social
# a means or instrumentality for storing or communicating information media
# a raised horizontal surface platforms
# to
# the act of publicly exhibiting or entertaining show
# the activity of providing for or maintaining by supplying with money or necessities support
# for
# a person who dissents from some established policy protesters
# a unit of length equal to one twelfth of a foot in
# Iran
# .
#
#
#
# USMNT
# someone who controls resources and expenditures manager
# Berhalter
# and
# an officer holding a rank below a major but above a lieutenant captain
# elected vice president and became the 10th President of the United States when Harrison died (1790-1862) Tyler
# American Revolutionary leader and patriot; an organizer of the Boston Tea Party and signer of the Declaration of Independence (1722-1803) Adams
# also
# deal with (something unpleasant) head on faced
# quantifier; used with either mass nouns or plural count nouns to indicate an unspecified number or quantity some
# someone who learned to fight in the streets rather than being formally trained in the sport of boxing tough
# an instance of questioning questions
# from
# a native or inhabitant of Iran Iranian
# a writer for newspapers and magazines journalists
# a unit of length equal to one twelfth of a foot in
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# characterized by intense emotion fiery
# the state of demanding notice or attention press
# a prearranged meeting for consultation or exchange of information or discussion (especially one with a formal agenda) conference
# ,
# try to manage without help fending
# kill intentionally and with premeditation off
# a formal charge of wrongdoing brought against a person; the act of imputing blame or guilt accusations
# of
# an expression of agreement that is not supported by real conviction hypocrisy
# and
# an expression of lack of respect disrespect
# .
#
#
#
# The
# an interest followed with exaggerated zeal furore
# extend on all sides of simultaneously; encircle surrounding
# this
# a contest with rules to determine a winner game
# being the only one; single and isolated from others only
# make an addition (to); join or combine or unite with others; increase the quality, quantity, size or scope of added
# to
# the
# a dramatic work intended for performance by actors on a stage drama
# of
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# matchup
# that
# –
# the latter part of the day (the period of decreasing daylight from late afternoon until nightfall) even
# a unit of length equal to one twelfth of a foot in
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# the absence of matter vacuum
# not present; having left away
# from
# kill intentionally and with premeditation off
# -
# a piece of land cleared of trees and usually enclosed field
# an important question that is in dispute and must be settled issues
# –
# a state in northwestern United States on the Pacific was
# give surety or assume responsibility guaranteed
# to
# a light strong brittle grey toxic bivalent metallic element be
# marked by distress fraught
# with
# (psychology) a state of mental or emotional strain or suspense tension
# .
#
#
#
# Both
# a cooperative unit (especially in sports) teams
# be cognizant or aware of a fact or a specific piece of information; possess knowledge or information about knew
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a victory (as in a race or other competition) win
# would
# get by special effort secure
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a point located with respect to surface features of some region place
# a unit of length equal to one twelfth of a foot in
# the
# a charge of ammunition for a single shot round
# of
# the cardinal number that is the sum of fifteen and one 16
# ,
# but
# for
# the
# USMNT
# the latter part of the day (the period of decreasing daylight from late afternoon until nightfall) even
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a gully that is shallower than a ravine draw
# would
# not
# a light strong brittle grey toxic bivalent metallic element be
# an adequate quantity; a quantity that is large enough to achieve a purpose enough
# to
# the seat within a bishop's diocese where his cathedral is located see
# it
# gradual improvement or growth or development progress
# from
# the
# any number of entities (members) considered as a unit group
# .
#
#
#
# The
# USMNT
# have or possess, either in a concrete or an abstract sense had
# to
# battled
# not easy; requiring great physical or mental effort to accomplish or comprehend or endure hard
# for
# its
# a point located with respect to surface features of some region place
# a unit of length equal to one twelfth of a foot in
# the
# a charge of ammunition for a single shot round
# of
# the cardinal number that is the sum of fifteen and one 16
# .
#
#
#
# a location other than here; that place There
# have the quality of being; (copula, used with an adjective or a predicate noun) were
# n’t
# to a degree exceeding normal or proper limits too
# many
# a perceptible indication of something not immediately apparent (as a visible clue that something has happened) signs
# of
# at or near the beginning of a period of time or course of events or before the usual or expected time early
# an uneasy psychological state nerves
# from
# the
# USMNT
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# Berhalter
# ’s
# a place within a region identified relative to a center or reference location side
# issue commands or orders for dictated
# the
# a dramatic work intended for performance by actors on a stage play
# a unit of length equal to one twelfth of a foot in
# the
# an open or empty space in or between things opening
# any distinct time period in a sequence of events stages
# –
# derive or receive pleasure from; get enjoyment from; take pleasure in enjoying
# 65
# %
# of
# the
# the act of having and controlling property possession
# –
# though
# it
# carry out took
# until
# the
# 28th
# a unit of time equal to 60 seconds or 1/60th of an hour minute
# for
# it
# summon into action or bring into existence, often as if by magic conjure
# the
# the first or highest in an ordering or series first
# a possibility due to a favorable combination of circumstances chance
# of
# a brief written record note
# .
#
#
#
# Josh
# Sargeant
# ’s
# desire strongly or persistently long
# -
# an area in which something acts or operates or has power or control: range
# earnest and conscientious activity intended to do or accomplish something effort
# carry out took
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a twist or aberration; especially a perverse or abnormal way of judging or acting deflection
# kill intentionally and with premeditation off
# an
# a native or inhabitant of Iran Iranian
# a person who cares for persons or property defender
# and
# the dressed skin of an animal (especially a large animal) fell
# completely and without qualification; used informally as intensifiers perfectly
# into
# the
# a course of conduct path
# of
# grass with long cylindrical spikes grown in northern United States and Europe for hay Timothy
# Weah
# ,
# who
# perhaps
# engage in did
# n’t
# be fully aware or cognizant of realize
# a very light colorless element that is one of the six inert gasses; the most difficult gas to liquefy; occurs in economically extractable amounts in certain natural gases (as those found in Texas and Kansas) he
# a state in northwestern United States on the Pacific was
# quantifier; used with either mass or count nouns to indicate the whole number or amount of or every one of a class all
# isolated from others alone
# a unit of length equal to one twelfth of a foot in
# the side that is forward or prominent front
# of
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# and
# move fast rushed
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# to go or travel towards headed
# earnest and conscientious activity intended to do or accomplish something effort
# that
# Alireza
# Beiranvand
# a unit of length equal to one twelfth of a foot in
# the
# Iran
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# discover or come upon accidentally, suddenly, or unexpectedly; catch somebody doing something or in a certain state caught
# with
# freedom from difficulty or hardship or effort ease
# .
#
#
#
# in operation or operational On
# the
# one of two equal parts of a divisible whole half
# a period of time equal to 1/24th of a day hour
# a number or letter indicating quality (especially of a student's performance) mark
# ,
# Weah
# on one occasion once
# again
# carry out took
# raise up
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# of surpassing excellence brilliant
# the particular portion of space occupied by something position
# the region that is inside of something inside
# the
# a (usually rectangular) container; may have a lid box
# but
# skied
# his
# earnest and conscientious activity intended to do or accomplish something effort
# a deep hole or shaft dug or drilled to obtain water or oil or gas or brine well
# (cricket) the division of play during which six balls are bowled at the batsman by one player from the other team from the same end of the pitch over
# the
# a horizontal bar that goes across something crossbar
# located farther aft after
# the state or fact of existing being
# a group of things of the same kind that belong together and are so used set
# raise up
# so as to pass a given point by
# Sargeant
# .
#
#
#
# The
# USMNT
# ’s
# the force applied to a unit area of surface; measured in pascals (SI unit) or in dynes (cgs unit) pressure
# eventually
# express in words told
# the cardinal number that is the sum of six and one seven
# a written account of what transpired at a meeting minutes
# earlier in time; previously before
# one of two equal parts of a divisible whole half
# an instance or single occasion for some event time
# ,
# the act of someone who picks up or takes something taking
# the
# an advantage held by a competitor in a race lead
# a group of followers or enthusiasts following
# an
# having or demonstrating ability to recognize or draw fine distinctions incisive
# a cooperative unit (especially in sports) team
# the act of deciding to do something move
# .
#
#
#
# Weston
# McKennie
# ’s
# a very brief moment pinpoint
# a wooden structure consisting of an upright post with a transverse piece cross
# a piece of land cleared of trees and usually enclosed field
# round object that is hit or thrown or kicked in games ball
# a state in northwestern United States on the Pacific was
# to go or travel towards headed
# the posterior part of a human (or animal) body from the neck to the end of the spine back
# to the opposite side across
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# so as to pass a given point by
# the
# raid and rove in search of booty marauding
# Sergiño
# Dest
# and
# make into a bundle bundled
# where you live at a particular time home
# bravely
# so as to pass a given point by
# Pulisic
# ,
# who
# undergo or be subjected to suffered
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# (of a person) possessing physical strength and weight; rugged and powerful hefty
# (physics) a brief event in which two or more bodies come together collision
# with
# Beiranvand
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# a very light colorless element that is one of the six inert gasses; the most difficult gas to liquefy; occurs in economically extractable amounts in certain natural gases (as those found in Texas and Kansas) he
# change orientation or direction, also in the abstract sense turned
# the
# round object that is hit or thrown or kicked in games ball
# (cricket) the division of play during which six balls are bowled at the batsman by one player from the other team from the same end of the pitch over
# the
# a formation of people or things one beside another line
# .
#
#
#
# The
# USMNT
# ’s
# a feeling of extreme pleasure or satisfaction delight
# swiftly
# change orientation or direction, also in the abstract sense turned
# to
# something or someone that causes anxiety; a source of unhappiness worry
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# it
# a state in northwestern United States on the Pacific was
# clearly revealed to the mind or the senses or judgment evident
# that
# Pulisic
# a state in northwestern United States on the Pacific was
# a unit of length equal to one twelfth of a foot in
# important in effect or meaning significant
# a symptom of some physical hurt or disorder pain
# a group of followers or enthusiasts following
# the
# a loud resonant repeating noise clash
# ,
# disability of walking due to crippling of the legs or feet limping
# to a considerable degree heavily
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# a very light colorless element that is one of the six inert gasses; the most difficult gas to liquefy; occurs in economically extractable amounts in certain natural gases (as those found in Texas and Kansas) he
# a state in northwestern United States on the Pacific was
# give help or assistance; be of service helped
# kill intentionally and with premeditation off
# the
# the property of sound that varies with variation in the frequency of vibration pitch
# so as to pass a given point by
# the cardinal number that is the sum of one and one or a numeral representing this number two
# any of several Old World herbs of the genus Medicago having small flowers and trifoliate compound leaves medics
# .
#
#
#
# Pulisic
# soon
# a rare heavy polyvalent metallic element that resembles manganese chemically and is used in some alloys; is obtained as a by-product in refining molybdenum re
# -
# to come or go into entered
# the
# the property of sound that varies with variation in the frequency of vibration pitch
# ,
# but
# the
# Chelsea
# an adult person who is male (as opposed to a woman) man
# a state in northwestern United States on the Pacific was
# without doubt or question clearly
# a static photograph (especially one taken from a movie and used for advertising purposes) still
# make a strenuous or labored effort struggling
# with
# the
# the sound of knocking (as on a door or in an engine or bearing) knock
# .
#
#
#
# a religious person who believes Jesus is the Christ and who is a member of a Christian denomination Christian
# Pulisic
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# extend on all sides of simultaneously; encircle surrounded
# so as to pass a given point by
# teammates
# located farther aft after
# the act of departing going
# soft fine feathers down
# cause injuries or bodily harm to injured
# a group of followers or enthusiasts following
# his
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# .
#
#
#
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar As
# the
# USMNT
# pass into a condition gradually, take on a specific property or attribute; become grew
# a unit of length equal to one twelfth of a foot in
# freedom from doubt; belief in yourself and your abilities confidence
# ,
# the unlimited expanse in which everything is located spaces
# take the first step or steps in carrying out an action began
# to
# a clear or unobstructed space or expanse of land or water open
# raise up
# a unit of length equal to one twelfth of a foot in
# Iran
# ’s
# (military) military action or resources protecting a country against potential enemies defense
# and
# Weah
# the content of cognition; the main thing you are thinking about thought
# a very light colorless element that is one of the six inert gasses; the most difficult gas to liquefy; occurs in economically extractable amounts in certain natural gases (as those found in Texas and Kansas) he
# ’d
# increase twofold doubled
# his
# a cooperative unit (especially in sports) team
# ’s
# an advantage held by a competitor in a race lead
# used especially of what is legally or ethically right or proper or fitting; - A.Lincoln just
# earlier in time; previously before
# the
# a definite length of time marked off by two instants interval
# ,
# a decorative texture or appearance of a surface (or the substance that gives it that appearance) finishing
# wonderfully
# with
# the
# the region that is outside of something outside
# of
# his
# footwear that covers the whole foot and lower leg boot
# being the only one; single and isolated from others only
# to
# a light strong brittle grey toxic bivalent metallic element be
# come together met
# so as to pass a given point by
# the
# official (in tennis, soccer, football, etc.) who assists the referee in some way (especially by watching for out of bounds or offside) linesman
# ’s
# emblem usually consisting of a rectangular piece of cloth of distinctive design flag
# for
# the
# not wide narrowest
# of
# (sport) the mistake of occupying an illegal position on the playing field (in football, soccer, ice hockey, field hockey, etc.) offside
# the act of making up your mind about something decisions
# .
#
#
#
# Though
# Iran
# would
# a person who possesses great material wealth have
# have the quality of being; (copula, used with an adjective or a predicate noun) been
# enjoying or showing or marked by joy or pleasure happy
# to
# the atmospheric conditions that comprise the state of the atmosphere in terms of temperature and wind and clouds and precipitation weather
# that
# the first or highest in an ordering or series first
# -
# one of two equal parts of a divisible whole half
# a violent weather condition with winds 64-72 knots (11 on the Beaufort scale) and precipitation and thunder and lightning storm
# ,
# it
# a state in northwestern United States on the Pacific was
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# in a surprising manner surprisingly
# put down by force or intimidation subdued
# a dramatic or musical entertainment performance
# –
# a unit of length equal to one twelfth of a foot in
# a fact about some part (as opposed to general) particular
# a group of followers or enthusiasts following
# Pulisic
# ’s
# the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it goal
# –
# from
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a cooperative unit (especially in sports) team
# that
# have or possess, either in a concrete or an abstract sense had
# give rise to; cause to happen or occur, not always intentionally caused
# both
# England
# and
# one of the four countries that make up the United Kingdom of Great Britain and Northern Ireland; during Roman times the region was known as Cambria Wales
# an attitude of defensiveness (especially in the phrase `on the defensive') defensive
# a state of difficulty that needs to be resolved problems
# a unit of length equal to one twelfth of a foot in
# its
# an open or empty space in or between things opening
# the cardinal number that is the sum of one and one or a numeral representing this number two
# lighter consisting of a thin piece of wood or cardboard tipped with combustible chemical; ignites with friction matches
# .
#
#
#
# Iran
# engage in did
# Israeli statesman (born in Russia) who (as prime minister of Israel) negotiated a peace treaty with Anwar Sadat (then the president of Egypt) (1913-1992) begin
# the
# 1/60 of a minute; the basic unit of time adopted under the Systeme International d'Unites second
# one of two equal parts of a divisible whole half
# with
# English statesman who opposed Henry VIII's divorce from Catherine of Aragon and was imprisoned and beheaded; recalled for his concept of Utopia, the ideal state more
# the power or right to give orders or make decisions authority
# ,
# make or cause to be or to become creating
# the cardinal number that is the sum of one and one or a numeral representing this number two
# of surpassing excellence brilliant
# a possibility due to a favorable combination of circumstances chances
# for
# Saman
# Ghoddos
# but
# the
# Brentford
# the person who plays the position of forward in certain games, such as basketball, soccer, or hockey forward
# a state in northwestern United States on the Pacific was
# (usually followed by `to') not having the necessary means or skill or know-how unable
# to
# a source of difficulty trouble
# USMNT
# the soccer or hockey player assigned to protect the goal goalkeeper
# the property of having little or no contrast; lacking highlights or gloss Matt
# United States slave and insurrectionist who in 1831 led a rebellion of slaves in Virginia; he was captured and executed (1800-1831) Turner
# .
#
#
#
# With
# the
# a timepiece that shows the time of day clock
# a metallic tapping sound ticking
# soft fine feathers down
# ,
# Iran
# have or possess, either in a concrete or an abstract sense had
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# having or deserving or conferring glory glorious
# a possibility due to a favorable combination of circumstances chance
# to
# a position on a scale of intensity or amount or quality level
# the
# a number or letter indicating quality (especially of a student's performance) score
# but
# Morteza
# Pouraliganji
# ’s
# bend one's back forward from the waist on down stooping
# a line of text serving to indicate what the passage below it is about header
# gleam or glow intermittently flashed
# narrowly
# having great (or a certain) extent from one side to the other wide
# of
# the
# a terrorist organization that seeks to overthrow the government dominated by Tutsi and to institute Hutu control again far
# the position where someone (as a guard or sentry) stands or is assigned to stand post
# a great amount or extent much
# to
# the
# the feeling that comes when something burdensome is removed or reduced relief
# of
# the
# a native or inhabitant of the United States American
# a device for creating a current of air by movement of a surface or surfaces fans
# a unit of length equal to one twelfth of a foot in
# the
# a support or foundation stands
# ,
# many
# who
# have or possess, either in a concrete or an abstract sense had
# their
# the upper part of the human body or the front part of the body in animals; contains the face and brains heads
# a unit of length equal to one twelfth of a foot in
# their
# (with `in') guardianship over; in divorce cases it is the right to house and care for and discipline a child hands
# .
#
#
#
# a location other than here; that place There
# have the quality of being; (copula, used with an adjective or a predicate noun) were
# characterized by or producing sound of great volume or intensity loud
# a telephone connection calls
# for
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# the act of punishing penalty
# from
# the
# a native or inhabitant of Iran Iranian
# a person who participates in or is skilled at some game players
# being or occurring at an advanced period of time or after a usual or expected time late
# in operation or operational on
# a unit of length equal to one twelfth of a foot in
# the
# the cardinal number that is the sum of eight and one nine
# a written account of what transpired at a meeting minutes
# of
# make an addition (to); join or combine or unite with others; increase the quality, quantity, size or scope of added
# an instance or single occasion for some event time
# ,
# with
# Mehdi
# Taremi
# continual and persistent demands insisting
# that
# Cameron
# Englishman and Egyptologist who in 1922 discovered and excavated the tomb of Tutankhamen (1873-1939) Carter
# -
# Vickers
# have or possess, either in a concrete or an abstract sense had
# cause to move by pulling pulled
# soft fine feathers down
# the
# Porto
# the person who plays the position of forward in certain games, such as basketball, soccer, or hockey forward
# soft fine feathers down
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# a very light colorless element that is one of the six inert gasses; the most difficult gas to liquefy; occurs in economically extractable amounts in certain natural gases (as those found in Texas and Kansas) he
# make an effort or attempt attempted
# to
# a return on a shot that seemed impossible to reach and would normally have resulted in a point for the opponent get
# in operation or operational on
# the
# either extremity of something that has length end
# of
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a wooden structure consisting of an upright post with a transverse piece cross
# .
#
#
#
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 USA
# a person who participates in or is skilled at some game players
# behave as expected during of holidays or rites celebrate
# a highly unstable radioactive element (the heaviest of the halogen series); a decay product of uranium and thorium at
# the
# the final match between the winners of all previous matches in an elimination tournament final
# the sound made by something moving rapidly or by steam coming out of a small aperture whistle
# .
#
#
#
# located farther aft After
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a document stating the facts and points of law of a client's case brief
# ,
# a grammatical category of verbs used to express distinctions of time tense
# a written order directing a bank to pay money check
# ,
# VAR
# reach, make, or come to a decision about something decided
# it
# a state in northwestern United States on the Pacific was
# n’t
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# the act of punishing penalty
# and
# soon
# located farther aft after
# (sports) the chief official (as in boxing or American football) who is expected to ensure fair play referee
# Mateu
# Lahoz
# exhale hard blew
# his
# the sound made by something moving rapidly or by steam coming out of a small aperture whistle
# to
# either extremity of something that has length end
# the
# a contest with rules to determine a winner game
# .
#
#
#
# Both
# a cooperative unit (especially in sports) teams
# fall or descend to a lower place or level sank
# to
# the
# the inside lower horizontal surface (as of a room, hallway, tent, or other structure) floor
# –
# for
# precisely as stated very
# the quality of being unlike or dissimilar difference
# a rational motive for a belief or action reasons
# –
# but
# the
# USMNT
# the capability of conscious choice and decision and intention; - George Meredith will
# the fact of being aware of information that is known to few people know
# an
# to make better improved
# a dramatic or musical entertainment performance
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# anything indispensable necessary
# if
# it
# a state of extreme poverty wants
# to
# a person who possesses great material wealth have
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a possibility due to a favorable combination of circumstances chance
# of
# move forward, also in the metaphorical sense advancing
# promote the growth of further
# a unit of length equal to one twelfth of a foot in
# an Arab country on the peninsula of Qatar; achieved independence from the United Kingdom in 1971; the economy is dominated by oil Qatar
# .
#
#
#
# ‘
# a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks) I
# a specific instance of feeling hopeful hope
# our
# a device for creating a current of air by movement of a surface or surfaces fans
# …
# stop blaming or grant forgiveness forgive
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 us
# ’
#
#
# a group of followers or enthusiasts Following
# the
# an unsuccessful ending to a struggle or contest defeat
# ,
# an
# determined or actuated by emotion rather than reason emotional
# Saeid
# Ezatolahi
# inquire about asked
# for
# compassionate feelings that support a willingness to forgive forgiveness
# from
# Iran
# a device for creating a current of air by movement of a surface or surfaces fans
# .
#
#
#
# Iran
# a state in northwestern United States on the Pacific was
# a unit of length equal to one twelfth of a foot in
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# having strength or power greater than average or expected strong
# the particular portion of space occupied by something position
# the act of departing going
# into
# the
# the final match between the winners of all previous matches in an elimination tournament final
# a contest with rules to determine a winner game
# a group of followers or enthusiasts following
# that
# of extreme importance; vital to the resolution of a crisis crucial
# the cardinal number that is the sum of one and one or a numeral representing this number 2
# -
# a mathematical element that when added to another number yields the same number 0
# a victory (as in a race or other competition) win
# (cricket) the division of play during which six balls are bowled at the batsman by one player from the other team from the same end of the pitch over
# one of the four countries that make up the United Kingdom of Great Britain and Northern Ireland; during Roman times the region was known as Cambria Wales
# ,
# require as useful, just, or proper needing
# used especially of what is legally or ethically right or proper or fitting; - A.Lincoln just
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a gully that is shallower than a ravine draw
# to
# gradual improvement or growth or development progress
# ,
# but
# the option to sell a given stock (or stock index or commodity future) at a given price before a given date put
# a unit of length equal to one twelfth of a foot in
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# fail to meet the hopes or expectations of disappointing
# a dramatic or musical entertainment performance
# with
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# a point located with respect to surface features of some region place
# a unit of length equal to one twelfth of a foot in
# the
# a very attractive or seductive looking woman knockout
# any distinct time period in a sequence of events stages
# in operation or operational on
# the
# a formation of people or things one beside another line
# .
#
#
#
# “
# a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks) I
# ’m
# in accordance with truth or fact or reality really
# feeling or expressing regret or sorrow or a sense of loss over something done or undone sorry
# in operation or operational on
# as the agent of or on someone's part (usually expressed as  rather than ) behalf
# of
# our
# a person who participates in or is skilled at some game players
# ,
# our
# any number of entities (members) considered as a unit group
# ,
# that
# we
# could
# n’t
# a return on a shot that seemed impossible to reach and would normally have resulted in a point for the opponent get
# our
# opportunity
# to
# prove capable or fit; meet requirements qualify
# for
# the
# immediately following in time or order next
# a charge of ammunition for a single shot round
# ,
# ”
# the
# midfielder
# express in words said
# .
#
#
#
# “
# a characteristic state or mode of living Life
# and
# any of various games played with a ball (round or oval) in which two teams try to kick or carry or propel the ball into each other's goal football
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# the act of departing going
# in operation or operational on
# and
# that
# airtight sealed metal container for food or drink or paint etc. can
# a light strong brittle grey toxic bivalent metallic element be
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# benefit good
# a unit of instruction lesson
# for
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 us
# ,
# a highly unstable radioactive element (the heaviest of the halogen series); a decay product of uranium and thorium at
# something that is of no importance least
# for
# the
# any immature animal young
# a person who participates in or is skilled at some game players
# a similar kind; , like
# me
# for
# the
# the time yet to come future
# .
# the syllable naming the fifth (dominant) note of any musical scale in solmization So
# a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks) I
# a specific instance of feeling hopeful hope
# our
# a device for creating a current of air by movement of a surface or surfaces fans
# and
# our
# (plural) any group of human beings (men or women or children) collectively people
# a unit of length equal to one twelfth of a foot in
# Iran
# ,
# they
# stop blaming or grant forgiveness forgive
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 us
# and
# a nonmetallic element belonging to the halogens; used especially in medicine and photography and in dyes; occurs naturally only in combination in small quantities (as in sea water or rocks) I
# an intuitive awareness;  or feel
# used especially of what is legally or ethically right or proper or fitting; - A.Lincoln just
# feeling or expressing regret or sorrow or a sense of loss over something done or undone sorry
# ,
# that
# ’s
# it
# .
# ”
#
#
#
# Iran
# (sports) someone in charge of training an athlete or a team coach
# Carlos
# Quieroz
# express in words said
# “
# the
# a series of mental images and emotions occurring during sleep dream
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# (cricket) the division of play during which six balls are bowled at the batsman by one player from the other team from the same end of the pitch over
# ”
# but
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# already
# the act of directing the eyes toward something and perceiving it visually looking
# to
# the
# the time yet to come future
# .
#
#
#
# “
# The
# the first or highest in an ordering or series first
# one of two equal parts of a divisible whole half
# a state in northwestern United States on the Pacific was
# North American republic containing 50 states - 48 conterminous states in North America plus Alaska in northwest North America and the Hawaiian Islands in the Pacific Ocean; achieved independence in 1776 US
# and
# the
# 1/60 of a minute; the basic unit of time adopted under the Systeme International d'Unites second
# one of two equal parts of a divisible whole half
# Iran
# ,
# ”
# express in words said
# Quieroz
# ,
# who
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# Iran
# ’s
# primarily temporal sense; being or indicating a relatively great or greater than average duration or passage of time or a duration as specified longest
# -
# an individual quantity of food or drink taken as part of a meal serving
# (sports) someone in charge of training an athlete or a team coach
# ,
# have or possess, either in a concrete or an abstract sense having
# be successful; achieve a goal managed
# the
# a cooperative unit (especially in sports) team
# from
# 2011
# to
# 2019
# ,
# earlier in time; previously before
# go or come back to place, condition, or activity where one has been before returning
# for
# a metric unit of length equal to one ten billionth of a meter (or 0.0001 micron); used to specify wavelengths of electromagnetic radiation a
# 1/60 of a minute; the basic unit of time adopted under the Systeme International d'Unites second
# a psychological state induced by (or as if induced by) a magical incantation spell
# a unit of length equal to one twelfth of a foot in
# an impetuous rush toward someone or something charge
# a unit of length equal to one twelfth of a foot in
# September
# .
#
#
#
# “
# The
# the quality of being unlike or dissimilar difference
# [
# a state in northwestern United States on the Pacific was
# ]
# we
# engage in did
# n’t
# a number or letter indicating quality (especially of a student's performance) score
# a unit of length equal to one twelfth of a foot in
# the
# 1/60 of a minute; the basic unit of time adopted under the Systeme International d'Unites second
# one of two equal parts of a divisible whole half
# a very poisonous metallic element that has three allotropic forms; arsenic and arsenic compounds are used as herbicides and insecticides and various alloys; found in arsenopyrite and orpiment and realgar as
# we
# should
# .
# But
# ,
# the
# a series of mental images and emotions occurring during sleep dream
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# (cricket) the division of play during which six balls are bowled at the batsman by one player from the other team from the same end of the pitch over
# .
# the momentary present Now
# ,
# its
# the process of using your mind to consider something carefully thinking
# on the move about
# the
# immediately following in time or order next
# any maneuver made as part of progress toward a goal step
# for
# Iran
# ,
# ”
# make an addition (to); join or combine or unite with others; increase the quality, quantity, size or scope of added
# Quieroz
# ,
# who
# have the quality of being; (copula, used with an adjective or a predicate noun) is
# the
# being the only one; single and isolated from others only
# (sports) someone in charge of training an athlete or a team coach
# to
# a person who possesses great material wealth have
# diode such that light emitted at a p-n junction is proportional to the bias current; color depends on the material used led
# the
# a cooperative unit (especially in sports) team
# to
# one after the other consecutive
# everything that exists anywhere World
# a small open container usually used for drinking; usually has a handle Cups
# .

# %%
# Tracer du nuage de mots avec les mots du doc ci-dessus
generate_wordcloud(Counter([token.text for token in doc if not token.is_stop and not token.is_punct and "\n" not in token.lemma_]))

# %%
# Tracer du nuage de mots avec les mots du doc ci-dessus
generate_wordcloud(Counter([token.text for token in doc if not token.is_stop and not token.is_punct and "\n" not in token.lemma_ and token.pos_ == "NOUN"]))
